# %% [markdown]
# ##Creazione del grafo
# Importo dati e funzioni utili per lavorare con le comunità

# %%
import google.colab.drive
google.colab.drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import networkx as nx
from matplotlib.colors import to_hex
from matplotlib import cm

# Carica i dati
df = pd.read_csv('/content/drive/MyDrive/social_network/got_new/dati/Workspace_7.csv')
df_edges = pd.read_csv('/content/drive/MyDrive/social_network/got_new/dati/asoiaf-all-edges.csv')

# %%
# Create the graph
G = nx.Graph()

# Add nodes to the graph
for index, row in df.iterrows():
    node_id = row['Id'] # Assuming 'Id' is the column for node identifiers
    G.add_node(node_id, **row.drop('Id').to_dict()) # Add all columns except 'Id' as attributes

# Add edges to the graph
for index, row in df_edges.iterrows():
    G.add_edge(row['Source'], row['Target'])  # Adjust column names as needed

# %%
import matplotlib.pyplot as plt
import networkx as nx
from matplotlib.colors import to_hex

# Definizione delle casate e dei colori associati
houses = ['Arryn', 'Baratheon', 'Bolton', 'Cassel', 'Clegane', 'Frey', 'Greyjoy',
          'Jon-Snow', 'Lannister', 'Martell', 'Other', 'Selmy', 'Stark', 'Targaryen',
          'Tarly', 'Tully', 'Tyrell']
'''
colors = ['#3f95b6', '#e2c508', '#808080', '#2F4F4F', '#000000', '#000080', '#D4AF37',
'#FFFFFF', '#8e0d02', '#864b21', '#D3D3D3', '#52230c', '#3f3f3f', '#9B1B30',
          '#008000', '#04cefd', '#9cb794']
'''
colors = ['blue', 'gold', 'gray', 'dimgray', 'black', 'darkblue', 'goldenrod',
              'whitesmoke', 'firebrick', 'chocolate', 'lightgray', 'darkgreen', 'darkslategray', 'crimson',
              'forestgreen', 'deepskyblue', 'olivedrab']

def visualize_got_graph(G):
    # Verifica che ci siano abbastanza colori per le case
    if len(houses) > len(colors):
        raise ValueError("Non ci sono abbastanza colori per tutte le case definite.")

    # Assegna un colore unico a ciascuna casa
    house_colors = {house: color for house, color in zip(houses, colors)}

    # Crea lista dei colori dei nodi in base alla casa
    node_colors = []
    for node in G.nodes():
        house = G.nodes[node].get('house', 'Other')  # Casa di default "Other" per nodi senza casa
        node_colors.append(house_colors.get(house, '#D3D3D3'))  # Colore di default grigio chiaro

    # Crea lista dei colori degli archi
    edge_colors = []
    edge_alpha = []
    edge_width = []
    for u, v in G.edges():
        house_u = G.nodes[u].get('house', 'Other')
        house_v = G.nodes[v].get('house', 'Other')
        if house_u == house_v and house_u != 'Other':  # Se appartengono alla stessa casa, usa il colore della casa
            edge_colors.append(house_colors.get(house_u, '#D3D3D3'))
            edge_alpha.append(0.7)
            edge_width.append(0.8)
        else:  # Altrimenti usa un colore grigio
            edge_colors.append('#B0B0B0')
            edge_alpha.append(0.1)
            edge_width.append(0.3)

    # Calcola posizione dei nodi
    pos = nx.spring_layout(G, k=0.5, iterations=50)

    # Disegna il grafo
    plt.figure(figsize=(12, 8))
    nx.draw_networkx_edges(G, pos, edge_color=edge_colors, width=edge_width, alpha=edge_alpha)  # Archi
    nx.draw_networkx_nodes(G, pos, node_color=node_colors, node_size=20, alpha=0.7)  # Nodi

    # Aggiungi legenda
    legend_elements = [
        plt.Line2D([], [], marker='o', color='w', markerfacecolor=color, markersize=10, label=house)
        for house, color in house_colors.items()
    ]
    plt.legend(handles=legend_elements, loc='upper right', title="Case", fontsize='small')

    # Finalizza il grafico
    plt.title("Rete di Game of Thrones")
    plt.axis('off')
    plt.show()

# %%
visualize_got_graph(G)

# %%
def visualize_by_modularity(G):
    # Ottieni tutte le classi di modularità presenti nel grafo
    modularity_classes = set(nx.get_node_attributes(G, 'modularity_class').values())

    # Associa un colore a ciascuna classe di modularità
    cmap = plt.get_cmap('tab20')  # Mappa colori con 20 colori distinti
    color_map = {mod_class: cmap(i / len(modularity_classes)) for i, mod_class in enumerate(modularity_classes)}

    # Colori dei nodi basati sulla modularità
    node_colors = [
        color_map[G.nodes[node].get('modularity_class', -1)]  # Colore per la modularità del nodo
        for node in G.nodes()
    ]

    # Colori degli archi basati sulla modularità
    edge_colors = []
    for u, v in G.edges():
        mod_u = G.nodes[u].get('modularity_class', -1)
        mod_v = G.nodes[v].get('modularity_class', -1)
        if mod_u == mod_v and mod_u in color_map:  # Stessa modularità, usa il colore della comunità
            edge_colors.append(color_map[mod_u])
        else:  # Modularità diversa, usa un colore grigio
            edge_colors.append('#B0B0B0')

    # Calcola posizione dei nodi
    pos = nx.spring_layout(G, k=0.5, iterations=50)

    # Disegna il grafo
    plt.figure(figsize=(12, 8))
    nx.draw_networkx_edges(G, pos, edge_color=edge_colors, width=0.8, alpha=0.4)  # Archi
    nx.draw_networkx_nodes(G, pos, node_color=node_colors, node_size=10, alpha=0.9)  # Nodi
    #nx.draw_networkx_labels(G, pos, font_size=8, font_color='black')  # Etichette dei nodi

    # Aggiungi legenda
    legend_elements = [
        plt.Line2D([], [], marker='o', color='w', markerfacecolor=color_map[mod_class], markersize=10, label=f'Class {mod_class}')
        for mod_class in modularity_classes
    ]
    plt.legend(handles=legend_elements, loc='upper right', title="Modularity Classes", fontsize='small')

    # Finalizza il grafico
    plt.title("Rete di Game of Thrones - Classi di Modularità con Archi Colorati")
    plt.axis('off')
    plt.show()

visualize_by_modularity(G)

# %%
def visualize_by_modularity(G):
    # Ottieni tutte le classi di modularità presenti nel grafo
    modularity_classes = set(nx.get_node_attributes(G, 'modularity_class').values())

    # Associa un colore a ciascuna classe di modularità
    cmap = plt.get_cmap('tab20')  # Mappa colori con 20 colori distinti
    color_map = {mod_class: cmap(i / len(modularity_classes)) for i, mod_class in enumerate(modularity_classes)}

    # Colori dei nodi basati sulla modularità
    node_colors = [
        color_map[G.nodes[node].get('modularity_class', -1)]  # Colore per la modularità del nodo
        for node in G.nodes()
    ]

    # Colori degli archi basati sulla modularità
    edge_colors = []
    for u, v in G.edges():
        mod_u = G.nodes[u].get('modularity_class', -1)
        mod_v = G.nodes[v].get('modularity_class', -1)
        if mod_u == mod_v and mod_u in color_map:  # Stessa modularità, usa il colore della comunità
            edge_colors.append(color_map[mod_u])
        else:  # Modularità diversa, usa un colore grigio
            edge_colors.append('#B0B0B0')

    # Calcola posizione dei nodi
    pos = nx.spring_layout(G, k=0.5, iterations=50)

    # Disegna il grafo
    plt.figure(figsize=(12, 8))
    nx.draw_networkx_edges(G, pos, edge_color=edge_colors, width=0.8, alpha=0.4)  # Archi
    nx.draw_networkx_nodes(G, pos, node_color=node_colors, node_size=10, alpha=0.9)  # Nodi
    #nx.draw_networkx_labels(G, pos, font_size=8, font_color='black')  # Etichette dei nodi

    # Aggiungi legenda
    legend_elements = [
        plt.Line2D([], [], marker='o', color='w', markerfacecolor=color_map[mod_class], markersize=10, label=f'Class {mod_class}')
        for mod_class in modularity_classes
    ]
    plt.legend(handles=legend_elements, loc='upper right', title="Modularity Classes", fontsize='small')

    # Finalizza il grafico
    plt.title("Rete di Game of Thrones - Classi di Modularità con Archi Colorati")
    plt.axis('off')
    plt.show()

visualize_by_modularity(G)

# %%
def visualize_separate_modularity_classes(G, top_n=5):
    # Ottieni tutte le classi di modularità presenti nel grafo
    modularity_classes = sorted(set(nx.get_node_attributes(G, 'modularity_class').values()))

    # Associa un colore a ciascuna classe di modularità
    cmap = plt.get_cmap('tab20')  # Usa una mappa colori con 20 colori distinti
    color_map = {mod_class: cmap(i / len(modularity_classes)) for i, mod_class in enumerate(modularity_classes)}

    # Calcola posizione globale dei nodi
    pos = nx.spring_layout(G, k=0.5, iterations=50)

    # Configurazione griglia
    n_classes = len(modularity_classes)
    n_cols = 3
    n_rows = (n_classes + n_cols - 1) // n_cols  # Arrotonda per eccesso
    fig, axes = plt.subplots(n_rows, n_cols, figsize=(18, 6 * n_rows))
    axes = axes.flatten()

    for idx, target_class in enumerate(modularity_classes):
        ax = axes[idx]

        # Trova i nodi più rappresentativi della classe (top_n per grado)
        nodes_in_class = [node for node in G.nodes if G.nodes[node].get('modularity_class') == target_class]
        top_nodes = sorted(nodes_in_class, key=lambda node: G.degree(node), reverse=True)[:top_n]
        representative_label = top_nodes[0] if top_nodes else "Nessun Nodo"


        # Colori e dimensioni dei nodi
        node_colors = []
        node_alpha = []
        for node in G.nodes():
            mod_class = G.nodes[node].get('modularity_class', -1)
            if mod_class == target_class:
                node_colors.append(color_map[target_class])  # Colore della classe selezionata
                node_alpha.append(0.9)  # Opacità massima
            else:
                node_colors.append((0, 0, 0, 0))  # Invisibile
                node_alpha.append(0.0)

        # Colori e alpha degli archi
        edge_colors = []
        edge_alpha = []
        for u, v in G.edges():
            mod_u = G.nodes[u].get('modularity_class', -1)
            mod_v = G.nodes[v].get('modularity_class', -1)
            if mod_u == target_class and mod_v == target_class:
                edge_colors.append(color_map[target_class])  # Archi interni alla stessa classe
                edge_alpha.append(0.5)
            elif mod_u == target_class:
                edge_colors.append(color_map[mod_v])  # Archi verso altre classi
                edge_alpha.append(0.9)
            else:
                edge_colors.append((0, 0, 0, 0))  # Invisibile
                edge_alpha.append(0.0)

        # Disegna il grafo
        nx.draw_networkx_edges(G, pos, edge_color=edge_colors, width=0.5, alpha=edge_alpha, ax=ax)  # Archi
        nx.draw_networkx_nodes(G, pos, node_color=node_colors, node_size=15, alpha=node_alpha, ax=ax)  # Nodi

         # Aggiungi etichette dei nodi più rappresentativi
        for node in top_nodes:
            x, y = pos[node]
            ax.text(x, y, str(node), fontsize=8, ha='center', va='center',bbox=dict(facecolor='white', edgecolor='none', alpha=0.7, pad=0.5))

        # Aggiungi titolo con il rappresentante
        ax.set_title(f"Modularity Class {target_class}\nRappresentante: {representative_label}")
        ax.axis('off')

    # Rimuovi assi inutilizzati
    for idx in range(len(modularity_classes), len(axes)):
        fig.delaxes(axes[idx])

    plt.tight_layout()
    plt.show()

visualize_separate_modularity_classes(G)

# %%
import numpy as np

def create_community_graph_from_modularity(G):
    """
    Crea un grafo delle comunità basato sull'attributo 'modularity_class'.

    Args:
        G (nx.Graph): Il grafo originale.

    Returns:
        nx.Graph: Il grafo delle comunità.
    """
    # Creiamo un nuovo grafo per le comunità
    community_graph = nx.Graph()

    # Raggruppa i nodi per modularity_class
    communities = {}
    for node, data in G.nodes(data=True):
        community = data.get('modularity_class')
        if community not in communities:
            communities[community] = []
        communities[community].append(node)

    # Aggiungi nodi per ogni comunità
    for community, members in communities.items():
        internal_edges_weight = G.subgraph(members).size(weight='weight')  # Somma dei pesi interni
        community_graph.add_node(
            community,
            num_members=len(members),
            total_internal_weight=internal_edges_weight
        )

    # Aggiungi archi tra comunità
    for community_i, members_i in communities.items():
        for community_j, members_j in communities.items():
            if community_i < community_j:  # Considera ogni coppia una sola volta
                # Somma dei pesi degli archi tra i membri delle due comunità
                edge_weight = sum(
                    G[u][v].get('weight', 1)  # Usa peso se presente, altrimenti 1
                    for u in members_i
                    for v in members_j
                    if G.has_edge(u, v)
                )
                if edge_weight > 0:
                    community_graph.add_edge(community_i, community_j, weight=edge_weight)

    return community_graph

def plot_community_graph(community_graph):
    """
    Visualizza il grafo delle comunità.

    Args:
        community_graph (nx.Graph): Il grafo delle comunità.
    """
    pos = nx.spring_layout(community_graph, seed=42)
    node_sizes = [d['num_members'] * 5 for _, d in community_graph.nodes(data=True)]  # Dimensioni proporzionali al numero di membri
    edge_weights = [d['weight'] for _, _, d in community_graph.edges(data=True)]  # Peso degli archi

    # Get total internal weights for color scaling
    # Get total internal weights for color scaling
    total_internal_weights = [d['total_internal_weight'] for _, d in community_graph.nodes(data=True)]
    # Convert the list to a NumPy array for element-wise operations
    total_internal_weights = np.array(total_internal_weights)
    normalized_weights = (total_internal_weights - np.min(total_internal_weights)) / (np.max(total_internal_weights) - np.min(total_internal_weights))
    # Apply colormap to normalized weights
    cmap = plt.get_cmap('Blues')
    node_colors = [cmap(weight) for weight in normalized_weights]

    plt.figure(figsize=(12, 8))
    nx.draw_networkx_nodes(community_graph, pos, node_size=node_sizes, node_color=node_colors, alpha=0.8)
    nx.draw_networkx_edges(community_graph, pos, width=[w / 9 for w in edge_weights], alpha=0.6, edge_color='gray')
    nx.draw_networkx_labels(community_graph, pos, labels={n: f"C{n}" for n in community_graph.nodes()}, font_size=8)
    plt.title("Grafo delle Comunità (Basato su modularity_class)")
    plt.axis('off')
    plt.show()

# Esempio di utilizzo
community_graph = create_community_graph_from_modularity(G)
plot_community_graph(community_graph)

# %% [markdown]
# ## Export data

# %%
import pandas as pd

def create_community_graph_from_modularity(G, output_path):
    """
    Crea un grafo delle comunità basato sull'attributo 'modularity_class'
    e lo esporta in formato CSV per Gephi utilizzando Pandas.

    Args:
        G (nx.Graph): Il grafo originale.
        output_path (str): Directory di output per salvare i file CSV.

    Returns:
        nx.Graph: Il grafo delle comunità.
    """
    # Creiamo un nuovo grafo per le comunità
    community_graph = nx.Graph()

    # Raggruppa i nodi per modularity_class
    communities = {}
    for node, data in G.nodes(data=True):
        community = data.get('modularity_class')
        if community is not None:  # Ignora i nodi senza modularity_class
            if community not in communities:
                communities[community] = []
            communities[community].append(node)


    # Aggiungi nodi per ogni comunità
    nodes_data = []
    for community, members in communities.items():
        internal_edges_weight = G.subgraph(members).size(weight='weight')  # Somma dei pesi interni
        community_graph.add_node(
            community,
            num_members=len(members),
            total_internal_weight=internal_edges_weight
        )
        nodes_data.append({
            'Id': community,
            'NumMembers': len(members),
            'TotalInternalWeight': internal_edges_weight
        })

    # Aggiungi archi tra comunità
    edges_data = []
    for community_i, members_i in communities.items():
        for community_j, members_j in communities.items():
            if community_i < community_j:  # Considera ogni coppia una sola volta
                edge_weight = sum(
                    G[u][v].get('weight', 1)  # Usa peso se presente, altrimenti 1
                    for u in members_i
                    for v in members_j
                    if G.has_edge(u, v)
                )
                if edge_weight > 0:
                    community_graph.add_edge(community_i, community_j, weight=edge_weight)
                    edges_data.append({
                        'Source': community_i,
                        'Target': community_j,
                        'Weight': edge_weight
                    })

    # Esporta nodi in formato CSV
    nodes_df = pd.DataFrame(nodes_data)
    nodes_csv_path = f"{output_path}/nodi.csv"
    nodes_df.to_csv(nodes_csv_path, index=False, encoding='utf-8')

    # Esporta archi in formato CSV
    edges_df = pd.DataFrame(edges_data)
    edges_csv_path = f"{output_path}/archi.csv"
    edges_df.to_csv(edges_csv_path, index=False, encoding='utf-8')

    return community_graph

community_graph = create_community_graph_from_modularity(G, '/content/drive/MyDrive/social_network/got_new/dati')

test_nodes = pd.read_csv('/content/drive/MyDrive/social_network/got_new/dati/nodi.csv')
print(test_nodes)
archi = pd.read_csv('/content/drive/MyDrive/social_network/got_new/dati/archi.csv')
print(archi)
# Out:
#     Id  NumMembers  TotalInternalWeight
# 0   10         176                577.0
# 1    1         115                302.0
# 2    6          89                253.0
# 3   16          16                 32.0
# 4   11         114                349.0
# 5    9          58                 88.0
# 6    2          60                122.0
# 7    7          44                 76.0
# 8   13           3                  3.0
# 9   14          11                 19.0
# 10   4           2                  1.0
# 11   0          63                181.0
# 12  15          23                 52.0
# 13   5           7                  9.0
# 14  12           2                  1.0
# 15  18           3                  3.0
# 16   8           2                  1.0
# 17  19           3                  2.0
# 18   3           3                  3.0
# 19  17           2                  1.0
#     Source  Target  Weight
# 0       10      16      16
# 1       10      11      30
# 2       10      13       8
# 3       10      15      28
# 4       10      12       1
# 5       10      19       2
# 6       10      17       1
# 7        1      10     106
# 8        1       6       1
# 9        1      11      25
# 10       1       9      48
# 11       1       2      24
# 12       1       7      15
# 13       1      15       1
# 14       1      19       1
# 15       6      10      45
# 16       6      16       9
# 17       6      11       2
# 18       6       9       1
# 19       6       7       2
# 20       6      15       5
# 21      11      14       4
# 22      11      18       2
# 23       9      10      76
# 24       9      11       2
# 25       2      10      47
# 26       2       6       1
# 27       2      11      40
# 28       2       9       7
# 29       2       7       9
# 30       2      15       1
# 31       7      10       5
# 32       7      16       1
# 33       7      11       1
# 34       4      10       1
# 35       0      10      96
# 36       0       1      25
# 37       0       6       3
# 38       0      11      11
# 39       0       9      24
# 40       0       2       4
# 41       0      15       5
# 42       5      10       5
# 43       5       6       1
# 44       5       9       1
# 45       8      10       1
# 46       3      10       4

# %%
def create_houses_graph_from_modularity(G, output_path):
    """
    Crea un grafo delle comunità basato sull'attributo 'modularity_class'
    e lo esporta in formato CSV per Gephi utilizzando Pandas.

    Args:
        G (nx.Graph): Il grafo originale.
        output_path (str): Directory di output per salvare i file CSV.

    Returns:
        nx.Graph: Il grafo delle comunità.
    """
    # Creiamo un nuovo grafo per le comunità
    houses_graph = nx.Graph()

    # Raggruppa i nodi per modularity_class
    houses = {}
    for node, data in G.nodes(data=True):
        house = data.get('house')
        if house is not None:  # Ignora i nodi senza modularity_class
            if house not in houses:
                houses[house] = []
            houses[house].append(node)


    # Aggiungi nodi per ogni comunità
    nodes_data = []
    for house, members in houses.items():
        internal_edges_weight = G.subgraph(members).size(weight='weight')  # Somma dei pesi interni
        houses_graph.add_node(
            house,
            num_members=len(members),
            total_internal_weight=internal_edges_weight
        )
        nodes_data.append({
            'Id': house,
            'NumMembers': len(members),
            'TotalInternalWeight': internal_edges_weight
        })

    # Aggiungi archi tra comunità
    edges_data = []
    for house_i, members_i in houses.items():
        for house_j, members_j in houses.items():
            if house_i < house_j:  # Considera ogni coppia una sola volta
                edge_weight = sum(
                    G[u][v].get('weight', 1)  # Usa peso se presente, altrimenti 1
                    for u in members_i
                    for v in members_j
                    if G.has_edge(u, v)
                )
                if edge_weight > 0:
                    houses_graph.add_edge(house_i, house_j, weight=edge_weight)
                    edges_data.append({
                        'Source': house_i,
                        'Target': house_j,
                        'Weight': edge_weight
                    })

    # Esporta nodi in formato CSV
    nodes_df = pd.DataFrame(nodes_data)
    nodes_csv_path = f"{output_path}/nodi-houses.csv"
    nodes_df.to_csv(nodes_csv_path, index=False, encoding='utf-8')

    # Esporta archi in formato CSV
    edges_df = pd.DataFrame(edges_data)
    edges_csv_path = f"{output_path}/archi-houses.csv"
    edges_df.to_csv(edges_csv_path, index=False, encoding='utf-8')

    return houses_graph

house_graph = create_houses_graph_from_modularity(G, '/content/drive/MyDrive/social_network/got_new/dati')

test_nodes = pd.read_csv('/content/drive/MyDrive/social_network/got_new/dati/nodi-houses.csv')
print(test_nodes)
archi = pd.read_csv('/content/drive/MyDrive/social_network/got_new/dati/archi-houses.csv')
print(archi)
# Out:
#            Id  NumMembers  TotalInternalWeight
# 0       Other         673                991.0
# 1        Frey          24                 21.0
# 2   Targaryen          21                 21.0
# 3     Greyjoy           8                 17.0
# 4      Tyrell          11                 14.0
# 5       Arryn           5                  4.0
# 6     Martell           8                  7.0
# 7       Stark          12                 33.0
# 8       Selmy           1                  0.0
# 9      Cassel           3                  2.0
# 10      Tully           3                  3.0
# 11  Lannister          12                 22.0
# 12    Clegane           2                  1.0
# 13  Baratheon           8                 18.0
# 14   Jon-Snow           1                  0.0
# 15     Bolton           2                  1.0
# 16      Tarly           2                  1.0
#     Source     Target  Weight
# 0    Other  Targaryen     104
# 1    Other     Tyrell      41
# 2    Other      Stark     244
# 3    Other      Selmy      27
# 4    Other      Tully      15
# ..     ...        ...     ...
# 79  Bolton    Greyjoy       2
# 80  Bolton      Stark       8
# 81  Bolton     Cassel       2
# 82  Bolton  Lannister       3
# 83   Tarly     Tyrell       2
#
# [84 rows x 3 columns]

# %% [markdown]
# ###Calcolo statistiche di base per comunità

# %%
house_colors = {house: color for house, color in zip(houses, colors)}
house_colors
# Out:
# {'Arryn': 'blue',
#  'Baratheon': 'gold',
#  'Bolton': 'gray',
#  'Cassel': 'dimgray',
#  'Clegane': 'black',
#  'Frey': 'darkblue',
#  'Greyjoy': 'goldenrod',
#  'Jon-Snow': 'whitesmoke',
#  'Lannister': 'firebrick',
#  'Martell': 'chocolate',
#  'Other': 'lightgray',
#  'Selmy': 'darkgreen',
#  'Stark': 'darkslategray',
#  'Targaryen': 'crimson',
#  'Tarly': 'forestgreen',
#  'Tully': 'deepskyblue',
#  'Tyrell': 'olivedrab'}

# %%
import networkx as nx
import numpy as np

# Filtriamo i dati per modularity_class
modularity = np.unique(df['modularity_class'])


# Funzione per calcolare le misure di centralità
def calculate_centrality_measures(group_df, group_edges):

  # Creiamo un grafo (graph) basato sulle informazioni contenute nel DataFrame
    G = nx.Graph()

    # Aggiungi i nodi
    for idx, row in group_df.iterrows():
        G.add_node(row['Id'], label=row['Label'], house=row['house'])

    # Aggiungi gli archi se le informazioni sono disponibili (ad esempio, grado o relazioni)
    # Aggiungi gli archi dal file degli archi (df_edges)
    for idx, row in group_edges.iterrows():
        source = row['Source']
        target = row['Target']
        G.add_edge(source, target)


    #print(f"Numero di nodi: {G.number_of_nodes()}")
    #print(f"Numero di archi: {G.number_of_edges()}")
    #plot_graph(G)

    # Misure di centralità
    centrality_measures = {}

    # Degree Centrality
    centrality_measures['degree_centrality'] = nx.degree_centrality(G)

    # Betweenness Centrality
    centrality_measures['betweenness_centrality'] = nx.betweenness_centrality(G)

    # Closeness Centrality
    centrality_measures['closeness_centrality'] = nx.closeness_centrality(G)

    # PageRank
    centrality_measures['pagerank'] = nx.pagerank(G)

    # Coefficiente di clustering (clustering coefficient)
    centrality_measures['clustering_coefficient'] = nx.clustering(G)

    # Calcolo Eigen Vector
    centrality_measures['eigenvector_centrality'] = nx.eigenvector_centrality(G, max_iter=1000, tol=1e-06)

    # Calcolo della densità all'interno della comunità
    num_internal_edges = G.number_of_edges()
    num_possible_edges = len(group_df) * (len(group_df) - 1) / 2
    centrality_measures['intra_density'] = num_internal_edges / num_possible_edges if num_possible_edges > 0 else 0


    return centrality_measures

# %% [markdown]
# Calcolo delle misure rispetto alle modularità

# %%
# Calcola le misure per ciascun valore di 'modularity_class'
results = {}

for modularity_class in modularity:
    # Filtra il DataFrame per ciascun 'modularity_class'
    group_df = df[df['modularity_class'] == modularity_class]
    group_edges = df_edges[df_edges['Source'].isin(group_df['Id']) & df_edges['Target'].isin(group_df['Id'])]

    print("Modularity ", modularity_class)
    # Calcola le misure di centralità per il gruppo filtrato
    centrality_measures = calculate_centrality_measures(group_df, group_edges)

    # Salva i risultati per ogni classe
    results[modularity_class] = centrality_measures
# Out:
# Modularity  0
# Modularity  1
# Modularity  2
# Modularity  3
# Modularity  4
# Modularity  5
# Modularity  6
# Modularity  7
# Modularity  8
# Modularity  9
# Modularity  10
# Modularity  11
# Modularity  12
# Modularity  13
# Modularity  14
# Modularity  15
# Modularity  16
# Modularity  17
# Modularity  18
# Modularity  19

# %%
# Print ignorante
# Mostra i risultati
for modularity_class, measures in results.items():
    print(f"Modularity Class: {modularity_class}")
    for measure, values in measures.items():
        print(f"  {measure}: {values}")
    print()
# Out:
# Modularity Class: 0
#   degree_centrality: {'Amabel': 0.03225806451612903, 'Amory-Lorch': 0.2096774193548387, 'Anguy': 0.14516129032258063, 'Aron-Santagar': 0.016129032258064516, 'Arya-Stark': 0.8064516129032258, 'Bellegere-Otherys': 0.016129032258064516, 'Beric-Dondarrion': 0.16129032258064516, 'Biter': 0.06451612903225806, 'Brea': 0.04838709677419355, 'Brusco': 0.03225806451612903, 'Chiswyck': 0.1774193548387097, 'Cutjack': 0.04838709677419355, 'Denyo-Terys': 0.03225806451612903, 'Dobber': 0.016129032258064516, 'Dunsen': 0.1774193548387097, 'Garth-Greyfeather': 0.03225806451612903, 'Gendry': 0.25806451612903225, 'Greenbeard': 0.11290322580645161, 'Gregor-Clegane': 0.1935483870967742, 'Hairy-Hal': 0.03225806451612903, 'Harra': 0.03225806451612903, 'Harren-Hoare': 0.016129032258064516, 'Harwin': 0.11290322580645161, 'Hot-Pie': 0.1774193548387097, 'Husband': 0.03225806451612903, 'Ilyn-Payne': 0.16129032258064516, 'Jack-Be-Lucky': 0.016129032258064516, 'Jack-Bulwer': 0.06451612903225806, 'Jaqen-Hghar': 0.0967741935483871, 'Kindly-Man': 0.03225806451612903, 'Koss': 0.03225806451612903, 'Kurz': 0.016129032258064516, 'Lem': 0.2096774193548387, 'Lommy-Greenhands': 0.0967741935483871, 'Mad-Huntsman': 0.016129032258064516, 'Mebble': 0.016129032258064516, 'Meralyn': 0.016129032258064516, 'Merrit': 0.016129032258064516, 'Meryn-Trant': 0.1774193548387097, 'Mordane': 0.016129032258064516, 'Mycah': 0.03225806451612903, 'Pate-(Old)': 0.016129032258064516, 'Polliver': 0.1774193548387097, 'Praed': 0.016129032258064516, 'Rafford': 0.16129032258064516, 'Ravella-Swann': 0.016129032258064516, 'Rorge': 0.06451612903225806, 'Sandor-Clegane': 0.29032258064516125, 'Sharna': 0.06451612903225806, 'Syrio-Forel': 0.04838709677419355, 'Talea': 0.03225806451612903, 'Tarber': 0.016129032258064516, 'Ternesio-Terys': 0.03225806451612903, 'Thoros-of-Myr': 0.11290322580645161, 'Tickler': 0.16129032258064516, 'Tom-of-Sevenstreams': 0.12903225806451613, 'Umma': 0.016129032258064516, 'Waif': 0.03225806451612903, 'Weasel': 0.06451612903225806, 'Weese': 0.11290322580645161, 'Woth': 0.08064516129032258, 'Yoren': 0.1774193548387097, 'Yorko-Terys': 0.016129032258064516}
ella-Swann': 0.004824622317857005, 'Rorge': 0.011858776237665783, 'Sandor-Clegane': 0.040509002164870786, 'Sharna': 0.01104232025400178, 'Syrio-Forel': 0.0088529946624081, 'Talea': 0.008155736156836294, 'Tarber': 0.007099517612905882, 'Ternesio-Terys': 0.008390612708414132, 'Thoros-of-Myr': 0.018558726354716663, 'Tickler': 0.021121016931746908, 'Tom-of-Sevenstreams': 0.02016550003230571, 'Umma': 0.004824622317857005, 'Waif': 0.008390612708414132, 'Weasel': 0.01136198783341912, 'Weese': 0.01670512815031317, 'Woth': 0.01374277979117455, 'Yoren': 0.02853230432760328, 'Yorko-Terys': 0.004824622317857005}
#   clustering_coefficient: {'Amabel': 1.0, 'Amory-Lorch': 0.6666666666666666, 'Anguy': 0.5555555555555556, 'Aron-Santagar': 0, 'Arya-Stark': 0.09224489795918367, 'Bellegere-Otherys': 0, 'Beric-Dondarrion': 0.5555555555555556, 'Biter': 1.0, 'Brea': 0.6666666666666666, 'Brusco': 1.0, 'Chiswyck': 0.8909090909090909, 'Cutjack': 0, 'Denyo-Terys': 1.0, 'Dobber': 0, 'Dunsen': 0.8909090909090909, 'Garth-Greyfeather': 1.0, 'Gendry': 0.3333333333333333, 'Greenbeard': 0.7619047619047619, 'Gregor-Clegane': 0.7727272727272727, 'Hairy-Hal': 1.0, 'Harra': 1.0, 'Harren-Hoare': 0, 'Harwin': 0.8571428571428571, 'Hot-Pie': 0.4, 'Husband': 1.0, 'Ilyn-Payne': 1.0, 'Jack-Be-Lucky': 0, 'Jack-Bulwer': 0.3333333333333333, 'Jaqen-Hghar': 0.6, 'Kindly-Man': 1.0, 'Koss': 1.0, 'Kurz': 0, 'Lem': 0.44871794871794873, 'Lommy-Greenhands': 0.8, 'Mad-Huntsman': 0, 'Mebble': 0, 'Meralyn': 0, 'Merrit': 0, 'Meryn-Trant': 0.8363636363636363, 'Mordane': 0, 'Mycah': 1.0, 'Pate-(Old)': 0, 'Polliver': 0.8909090909090909, 'Praed': 0, 'Rafford': 1.0, 'Ravella-Swann': 0, 'Rorge': 1.0, 'Sandor-Clegane': 0.43137254901960786, 'Sharna': 0.8333333333333334, 'Syrio-Forel': 0.6666666666666666, 'Talea': 1.0, 'Tarber': 0, 'Ternesio-Terys': 1.0, 'Thoros-of-Myr': 0.6666666666666666, 'Tickler': 1.0, 'Tom-of-Sevenstreams': 0.6785714285714286, 'Umma': 0, 'Waif': 1.0, 'Weasel': 0.6666666666666666, 'Weese': 0.5714285714285714, 'Woth': 1.0, 'Yoren': 0.4, 'Yorko-Terys': 0}
#   eigenvector_centrality: {'Amabel': 0.04021578338109458, 'Amory-Lorch': 0.2480260709828574, 'Anguy': 0.12205207682256011, 'Aron-Santagar': 0.024247053564381314, 'Arya-Stark': 0.43527684024394947, 'Bellegere-Otherys': 0.03681444001013557, 'Beric-Dondarrion': 0.15251079719230543, 'Biter': 0.05972756414726979, 'Brea': 0.04366649574190276, 'Brusco': 0.04050763682356579, 'Chiswyck': 0.22257607394511766
af': 1.0, 'Leobald-Tallhart': 0.3333333333333333, 'Lorren': 0.2, 'Lothar-Frey': 0.6111111111111112, 'Luton': 0, 'Luwin': 0.3897058823529412, 'Maege-Mormont': 0.8, 'Marq-Piper': 0.7, 'Martyn-Rivers': 0, 'Masha-Heddle': 0, 'Meera-Reed': 0.5277777777777778, 'Mikken': 0.5, 'Moreo-Tumitis': 0, 'Murch': 0, 'Mychel-Redfort': 0, 'Nan': 1.0, 'Olyvar-Frey': 0, 'Osha': 0.6944444444444444, 'Palla': 1.0, 'Perwyn-Frey': 1.0, 'Poxy-Tym': 0, 'Ramsay-Snow': 0.22058823529411764, 'Raynald-Westerling': 0.6666666666666666, 'Reek': 1.0, 'Rickard-Karstark': 0.5555555555555556, 'Rickard-Stark': 0, 'Rickon-Stark': 0.6727272727272727, 'Robb-Stark': 0.12403100775193798, 'Robin-Flint': 1.0, 'Rodrik-Cassel': 0.3161764705882353, 'Roger-Ryswell': 1.0, 'Rollam-Westerling': 1.0, 'Rolph-Spicer': 0, 'Roose-Bolton': 0.37362637362637363, 'Roslin-Frey': 1.0, 'Rowan': 0.8333333333333334, 'Shadd': 0, 'Skinner': 0.6, 'Sour-Alyn': 0.6666666666666666, 'Squint': 0.6666666666666666, 'Squirrel': 1.0, 'Stafford-Lannister': 1.0, 'Stevron-Frey': 1.0, 'Stiv': 1.0, 'Stygg': 0.6666666666666666, 'Sybelle-Glover': 0, 'Tansy': 1.0, 'Theon-Greyjoy': 0.0786308973172988, 'Tristifer-IV-Mudd': 0, 'Urzen': 1.0, 'Utherydes-Wayn': 1.0, 'Vyman': 1.0, 'Walda-Frey-(daughter-of-Merrett)': 1.0, 'Walder-Frey': 0.46153846153846156, 'Walder-Frey-(son-of-Jammos)': 1.0, 'Walder-Frey-(son-of-Merrett)': 0.5714285714285714, 'Wendel-Manderly': 0.38095238095238093, 'Werlag': 1.0, 'Wex-Pyke': 0.3333333333333333, 'Willis-Wode': 1.0, 'Willow-Witch-eye': 0, 'Yellow-Dick': 1.0}
#   eigenvector_centrality: {'Aegon-Frey-(son-of-Stevron)': 0.07355688551404904, 'Aggar': 0.012707546112033417, 'Alebelly': 0.03669251274401307, 'Barbrey-Dustin': 0.0583715738181453, 'Ben-Bones': 0.03692293539699558, 'Benfred-Tallhart': 0.0288842920098193, 'Beth-Cassel': 0.06390728576765964, 'Bran-Stark': 0.29147280560580746, 'Brenett': 0.025405501502032336, 'Brynden-Rivers': 0.030035106821638492, 'Brynden-Tully': 0.1204314934210574, 'Captain-Myraham': 0.024677839330745962, 'Captain-Myraham-Daughter': 0.024677839330745962, 'Catelyn-Stark': 0.3230715954817484, 'Chayle': 0.02791587080753079, 'Clement-Piper': 0.001233071078504815, 'Cley-Cerwyn': 0.045069507906640244, 'Coldhands': 0.04058605832076556, 'Colen-of-Greenpools': 0.025405501502032336, 'Dacey-Mormont': 0.06126492274877848, 'Damon-Dance-for-Me': 0.046909619677926076, 'Desmond-Grell': 0.06909506679055423, 'Donella-Hornwood': 0.07426342727632419, 'Donnel-Waynwood':
31380904817438354, 'Tristifer-IV-Mudd': 0.029263677661282683, 'Urzen': 0.027226116930038898, 'Utherydes-Wayn': 0.060102575257726304, 'Vyman': 0.0323983342907136, 'Walda-Frey-(daughter-of-Merrett)': 0.03881753849052105, 'Walder-Frey': 0.166631689057532, 'Walder-Frey-(son-of-Jammos)': 0.05664078750242443, 'Walder-Frey-(son-of-Merrett)': 0.11497681820849705, 'Wendel-Manderly': 0.08490 ...
#   intra_density: 0.04607170099160946
#
# Modularity Class: 2
#   degree_centrality: {'Aenys-Frey': 0.03389830508474576, 'Alester-Florent': 0.1016949152542373, 'Allard-Seaworth': 0.05084745762711865, 'Andrew-Estermont': 0.05084745762711865, 'Ardrian-Celtigar': 0.01694915254237288, 'Arnolf-Karstark': 0.05084745762711865, 'Arthor-Karstark': 0.01694915254237288, 'Axell-Florent': 0.15254237288135594, 'Azor-Ahai': 0.01694915254237288, 'Bartimus': 0.01694915254237288, 'Benethon-Scales': 0.03389830508474576, 'Brus-Buckler': 0.05084745762711865, 'Clayton-Suggs': 0.03389830508474576, 'Corliss-Penny': 0.01694915254237288, 'Cortnay-Penrose': 0.05084745762711865, 'Cressen': 0.11864406779661017, 'Daeron-I-Targaryen': 0.01694915254237288, 'Danwell-Frey': 0.03389830508474576, 'Davos-Seaworth': 0.4915254237288136, 'Devan-Seaworth': 0.06779661016949153, 'Edric-Storm': 0.0847457627118644, 'Garth-(Wolfs-Den)': 0.03389830508474576, 'Gawen-Westerling': 0.01694915254237288, 'Gerald-Gower': 0.01694915254237288, 'Godric-Borrell': 0.01694915254237288, 'Godry-Farring': 0.05084745762711865, 'Guncer-Sunglass': 0.03389830508474576, 'Helman-Tallhart': 0.01694915254237288, 'Hosteen-Frey': 0.06779661016949153, 'Hother-Umber': 0.03389830508474576, 'Imry-Florent': 0.01694915254237288, 'Jared-Frey': 0.05084745762711865, 'Khorane-Sathmantes': 0.05084745762711865, 'Lamprey': 0.06779661016949153, 'Leona-Woolfield': 0.03389830508474576, 'Lyanna-Mormont': 0.01694915254237288, 'Malegorn': 0.05084745762711865, 'Marlon-Manderly': 0.03389830508474576, 'Marya-Seaworth': 0.03389830508474576, 'Matthos-Seaworth': 0.01694915254237288, 'Melisandre': 0.15254237288135594, 'Monford-Velaryon': 0.05084745762711865, 'Mors-Umber': 0.05084745762711865, 'Narbert-Grandison': 0.0847457627118644, 'Patchface': 0.06779661016949153, 'Patrek-of-Kings-Mountain': 0.03389830508474576, 'Porridge': 0.05084745762711865, 'Pylos': 0.1016949152542373, 'Rhaegar-Frey': 0.03389830508474576, 'Robett-Glover': 0.05084745762711865, 'Roose-Ryswell': 0.01694915254237288, 'Salladhor-Saan': 0.0847457627118644, 'Selyse-Florent': 0.22033898305084745, 'Shireen-Baratheon': 0.15254237288135594, 'Stannis-Baratheon': 0.5254237288135594, 'Steffon-Baratheon': 0.01694915254237288, 'Sybell-Spicer': 0.06779661016949153, 'Theomore': 0.03389830508474576, 'William-Foxglove': 0.01694915254237288, 'Wyman-Manderly': 0.15254237288135594}
hosteen-Frey': 0.0198363351709265, 'Hother-Umber': 0.010239200130477173, 'Imry-Florent': 0.005634446714173876, 'Jared-Frey': 0.0160330294891491, 'Khorane-Sathmantes': 0.011927255516700255, 'Lamprey': 0.014758247607325154, 'Leona-Woolfield': 0.009249505921654879, 'Lyanna-Mormont': 0.005731805915257649, 'Malegorn': 0.012207674804532786, 'Marlon-Manderly': 0.008866252629431524, 'Marya-Seaworth': 0.0093723314959051, 'Matthos-Seaworth': 0.005634446714173876, 'Melisandre': 0.030884012416192402, 'Monford-Velaryon': 0.014478216127812124, 'Mors-Umber': 0.014555391798893674, 'Narbert-Grandison': 0.01974597828085186, 'Patchface': 0.01446727423820623, 'Patrek-of-Kings-Mountain': 0.008749113734937, 'Porridge': 0.011614782860332035, 'Pylos': 0.0210615892548352, 'Rhaegar-Frey': 0.01065864068896055, 'Robett-Glover': 0.014478216127812124, 'Roose-Ryswell': 0.005731805915257649, 'Salladhor-Saan': 0.01800655053441471, 'Selyse-Florent': 0.0442429745613492, 'Shireen-Baratheon': 0.0313986576017022, 'Stannis-Baratheon': 0.11786214879395132, 'Steffon-Baratheon': 0.005731805915257649, 'Sybell-Spicer': 0.018886629832005106, 'Theomore': 0.009346865122738652, 'William-Foxglove': 0.005731805915257649, 'Wyman-Manderly': 0.03827364978670594}
#   clustering_coefficient: {'Aenys-Frey': 1.0, 'Alester-Florent': 0.6666666666666666, 'Allard-Seaworth': 0.6666666666666666, 'Andrew-Estermont': 0.3333333333333333, 'Ardrian-Celtigar': 0, 'Arnolf-Karstark': 0.3333333333333333, 'Arthor-Karstark': 0, 'Axell-Florent': 0.5277777777777778, 'Azor-Ahai': 0, 'Bartimus': 0, 'Benethon-Scales': 1.0, 'Brus-Buckler': 1.0, 'Clayton-Suggs': 1.0, 'Corliss-Penny': 0, 'Cortnay-Penrose': 1.0, 'Cressen': 0.7142857142857143, 'Daeron-I-Targaryen': 0, 'Danwell-Frey': 1.0, 'Davos-Seaworth': 0.11330049261083744, 'Devan-Seaworth': 0.8333333333333334, 'Edric-Storm': 0.7, 'Garth-(Wolfs-Den)': 1.0, 'Gawen-Westerling': 0, 'Gerald-Gower': 0, 'Godric-Borrell': 0, 'Godry-Farring': 0.6666666666666666, 'Guncer-Sunglass': 1.0, 'Helman-Tallhart': 0, 'Hosteen-Frey': 0.3333333333333333, 'Hother-Umber': 0, 'Imry-Florent': 0, 'Jared-Frey': 0.3333333333333333, 'Khorane-Sathmantes': 1.0, 'Lamprey': 0.8333333333333334, 'Leona-Woolfield': 1.0, 'Lyanna-Mormont': 0, 'Malegorn': 1.0, 'Marlon-Manderly': 1.0, 'Marya-Seaworth': 1.0, 'Matthos-Seaworth': 0, 'Melisandre': 0.4444444444444444, 'Monford-Velaryon': 0.3333333333333333, 'Mors-Umber': 0.3333333333333333, 'Narbert-Grandison': 0.5, 'Patchface': 1.0, 'Patrek-of-Kings-Mountain': 1.0, 'Porridge': 1.0, 'Pylos': 0.7333333333333333, 'Rhaegar-Frey':
#   degree_centrality: {'Moelle': 1.0, 'Scolera': 1.0, 'Unella': 1.0}
#   betweenness_centrality: {'Moelle': 0.0, 'Scolera': 0.0, 'Unella': 0.0}
#   closeness_centrality: {'Moelle': 1.0, 'Scolera': 1.0, 'Unella': 1.0}
#   pagerank: {'Moelle': 0.3333333333333333, 'Scolera': 0.3333333333333333, 'Unella': 0.3333333333333333}
#   clustering_coefficient: {'Moelle': 1.0, 'Scolera': 1.0, 'Unella': 1.0}
#   eigenvector_centrality: {'Moelle': 0.5773502691896258, 'Scolera': 0.5773502691896258, 'Unella': 0.5773502691896258}
#   intra_density: 1.0
#
# Modularity Class: 4
#   degree_centrality: {'Alys-Arryn': 1.0, 'Elys-Waynwood': 1.0}
#   betweenness_centrality: {'Alys-Arryn': 0.0, 'Elys-Waynwood': 0.0}
#   closeness_centrality: {'Alys-Arryn': 1.0, 'Elys-Waynwood': 1.0}
#   pagerank: {'Alys-Arryn': 0.5, 'Elys-Waynwood': 0.5}
#   clustering_coefficient: {'Alys-Arryn': 0, 'Elys-Waynwood': 0}
#   eigenvector_centrality: {'Alys-Arryn': 0.7071067811865476, 'Elys-Waynwood': 0.7071067811865476}
#   intra_density: 1.0
#
# Modularity Class: 5
#   degree_centrality: {'Arthur-Dayne': 0.5, 'Gerold-Hightower': 0.5, 'Jonothor-Darry': 0.3333333333333333, 'Lewyn-Martell': 0.6666666666666666, 'Oswell-Whent': 0.5, 'Simon-Toyne': 0.16666666666666666, 'Smiling-Knight': 0.3333333333333333}
#   betweenness_centrality: {'Arthur-Dayne': 0.5333333333333333, 'Gerold-Hightower': 0.1, 'Jonothor-Darry': 0.0, 'Lewyn-Martell': 0.3333333333333333, 'Oswell-Whent': 0.03333333333333333, 'Simon-Toyne': 0.0, 'Smiling-Knight': 0.3333333333333333}
# ...
#   intra_density: 0.054184132898618224
#
# Modularity Class: 12
#   degree_centrality: {'Florian-the-Fool': 1.0, 'Jonquil': 1.0}
#   betweenness_centrality: {'Florian-the-Fool': 0.0, 'Jonquil': 0.0}
#   closeness_centrality: {'Florian-the-Fool': 1.0, 'Jonquil': 1.0}
#   pagerank: {'Florian-the-Fool': 0.5, 'Jonquil': 0.5}
#   clustering_coefficient: {'Florian-the-Fool': 0, 'Jonquil': 0}
#   eigenvector_centrality: {'Florian-the-Fool': 0.7071067811865476, 'Jonquil': 0.7071067811865476}
#   intra_density: 1.0
#
# Modularity Class: 13
#   degree_centrality: {'Alla-Tyrell': 1.0, 'Elinor-Tyrell': 1.0, 'Megga-Tyrell': 1.0}
#   betweenness_centrality: {'Alla-Tyrell': 0.0, 'Elinor-Tyrell': 0.0, 'Megga-Tyrell': 0.0}
#   closeness_centrality: {'Alla-Tyrell': 1.0, 'Elinor-Tyrell': 1.0, 'Megga-Tyrell': 1.0}
#   pagerank: {'Alla-Tyrell': 0.3333333333333333, 'Elinor-Tyrell': 0.3333333333333333, 'Megga-Tyrell': 0.3333333333333333}
#   clustering_coefficient: {'Alla-Tyrell': 1.0, 'Elinor-Tyrell': 1.0, 'Megga-Tyrell': 1.0}
#   eigenvector_centrality: {'Alla-Tyrell': 0.5773502691896258, 'Elinor-Tyrell': 0.5773502691896258, 'Megga-Tyrell': 0.5773502691896258}
#   intra_density: 1.0
#
# Modularity Class: 14
#   degree_centrality: {'Alleras': 0.6000000000000001, 'Armen': 0.6000000000000001, 'Gormon-Tyrell': 0.1, 'Leo-Tyrell': 0.4, 'Marwyn': 0.2, 'Mollander': 0.4, 'Pate-(novice)': 0.7000000000000001, 'Quill': 0.1, 'Roone': 0.4, 'Rosey': 0.1, 'Walgrave': 0.2}
#   betweenness_centrality: {'Alleras': 0.12222222222222223, 'Armen': 0.12222222222222223, 'Gormon-Tyrell': 0.0, 'Leo-Tyrell': 0.02777777777777778, 'Marwyn': 0.0, 'Mollander': 0.02777777777777778, 'Pate-(novice)': 0.65, 'Quill': 0.0, 'Roone': 0.005555555555555556, 'Rosey': 0.0, 'Walgrave': 0.2}
#   closeness_centrality: {'Alleras': 0.6666666666666666, 'Armen': 0.6666666666666666, 'Gormon-Tyrell': 0.3448275862068966, 'Leo-Tyrell': 0.5882352941176471, 'Marwyn': 0.43478260869565216, 'Mollander': 0.5882352941176471, 'Pate-(novice)': 0.7692307692307693, 'Quill': 0.45454545454545453, 'Roone': 0.47619047619047616, 'Rosey': 0.45454545454545453, 'Walgrave': 0.5}
#   pagerank: {'Alleras': 0.13960180053518045, 'Armen': 0.13960180053518045, 'Gormon-Tyrell': 0.045604547110375655, 'Leo-Tyrell': 0.09598106255423527, 'Marwyn': 0.05319011597457612, 'Mollander': 0.09598106255423527, 'Pate-(novice)': 0.18792471932732402, 'Quill': 0.036456086380652876, 'Roone': 0.09398188631882952, 'Rosey': 0.036456086380652876, 'Walgrave': 0.07522083232875748}
#   clustering_coefficient: {'Alleras': 0.6, 'Armen': 0.6, 'Gormon-Tyrell': 0, 'Leo-Tyrell': 0.8333333333333334, 'Marwyn': 1.0, 'Mollander': 0.8333333333333334, 'Pate-(novice)': 0.23809523809523808, 'Quill': 0, 'Roone': 0.8333333333333334, 'Rosey': 0, 'Walgrave': 0}
#   eigenvector_centrality: {'Alleras': 0.4510139214314166, 'Armen': 0.4510139214314166, 'Gormon-Tyrell': 0.019431505108979195, 'Leo-Tyrell': 0.35419476468683847, 'Marwyn': 0.1936383134873482, 'Mollander': 0.35419476468683847, 'Pate-(novice)': 0.40221135219719123, 'Quill': 0.08634338603123023, 'Roone': 0.3457084331206171, 'Rosey': 0.08634338603123023, 'Walgrave': 0.09051513495695702}
#   intra_density: 0.34545454545454546
#
# Modularity Class: 15
#   degree_centrality: {'Andrey-Dalt': 0.2272727272727273, 'Areo-Hotah': 0.2727272727272727, 'Arianne-Martell': 0.7272727272727273, 'Arys-Oakheart': 0.2727272727272727, 'Caleotte': 0.13636363636363635, 'Cedra': 0.09090909090909091, 'Daemon-Sand': 0.045454545454545456, 'Doran-Martell': 0.4090909090909091, 'Franklyn-Fowler': 0.045454545454545456, 'Garin-(
#   clustering_coefficient: {'Andrey-Dalt': 0.9, 'Areo-Hotah': 0.6666666666666666, 'Arianne-Martell': 0.20833333333333334, 'Arys-Oakheart': 0.7333333333333333, 'Caleotte': 1.0, 'Cedra': 1.0, 'Daemon-Sand': 0, 'Doran-Martell': 0.3888888888888889, 'Franklyn-Fowler': 0, 'Garin-(orphan)': 0.4444444444444444, 'Gerold-Dayne': 1.0, 'Manfrey-Martell': 0, 'Mellei': 1.0, 'Morra': 1.0, 'Myrcella-Baratheon': 0.4444444444444444, 'Nymeria-Sand': 0.6666666666666666, 'Obara-Sand': 0.6, 'Ricasso': 0, 'Sarella-Sand': 0, 'Sylva-Santagar': 0.9, 'Timoth': 0, 'Trystane-Martell': 0, 'Tyene-Sand': 0.42857142857142855}
#   eigenvector_centrality: {'Andrey-Dalt': 0.23385132607946776, 'Areo-Hotah': 0.24258045072788026, 'Arianne-Martell': 0.4467966696578041, 'Arys-Oakheart': 0.2664637015643242, 'Caleotte': 0.11105536312567424, 'Cedra': 0.11145741045032301, 'Daemon-Sand': 0.04387548226816179, 'Doran-Martell': 0.30459749360382143, 'Franklyn-Fowler': 0.06435799223695607, 'Garin-(orphan)': 0.3269826034352432, 'Gerold-Dayne': 0.19756975954504394, 'Manfrey-Martell': 0.009466744865583665, 'Mellei': 0.0751883583058403, 'Morra': 0.0751883583058403, 'Myrcella-Baratheon': 0.33136010153433476, 'Nymeria-Sand': 0.16419182525401288, 'Obara-Sand': 0.2238029778457233, 'Ricasso': 0.06572161447965509, 'Sarella-Sand': 0.040979333927077095, 'Sylva-Santagar': 0.23385132607946776, 'Timoth': 0.06435799223695607, 'Trystane-Martell': 0.04773006572462154, 'Tyene-Sand': 0.2844931606075213}
#   intra_density: 0.20553359683794467
#
# Modularity Class: 16
#   degree_centrality: {'Aegon-Targaryen-(son-of-Rhaegar)': 0.6, 'Benerro': 0.06666666666666667, 'Black-Balaq': 0.06666666666666667, 'Franklyn-Flowers': 0.2, 'Haldon': 0.5333333333333333, 'Harry-Strickland': 0.2, 'Jon-Connington': 0.6, 'Lemore': 0.4, 'Malaquo-Maegyr': 0.06666666666666667, 'Myles-Toyne': 0.13333333333333333, 'Nyessos-Vhassar': 0.13333333333333333, 'Qavo-Nogarys': 0.06666666666666667, 'Rhaenys-Targaryen-(daughter-of-Rhaegar)': 0.06666666666666667, 'Rolly-Duckfield': 0.4, 'Yandry': 0.4, 'Ysilla': 0.3333333333333333}
#   betweenness_centrality: {'Aegon-Targaryen-(son-of-Rhaegar)': 0.266031746031746, 'Benerro': 0.0, 'Black-Balaq': 0.0, 'Franklyn-Flowers': 0.13333333333333336, 'Haldon': 0.2644444444444445, 'Harry-Strickland': 0.011111111111111112, 'Jon-Connington': 0.43650793650793657, 'Lemore': 0.007301587301587302, 'Malaquo-Maegyr': 0.0, 'Myles-Toyne': 0.0, 'Nyessos-Vhassar': 0.13333333333333336, 'Qavo-Nogarys': 0.0, 'Rhaenys-Targaryen-(daughter-of-Rhaegar)': 0.0, 'Rolly-Duckfield': 0.007301587301587302, 'Yandry': 0.007301587301587302, 'Ysilla': 0.0}
#   closeness_centrality: {'Aegon-Targaryen-(son-of-Rhaegar)': 0.6818181818181818, 'Benerro': 0.39473684210526316, 'Black-Balaq': 0.3409090909090909, 'Franklyn-Flowers': 0.5, 'Haldon': 0.625, 'Harry-Strickland': 0.4838709677419355, 'Jon-Connington': 0.7142857142857143, 'Lemore': 0.5769230769230769, 'Malaquo-Maegyr': 0.3191489361702128, 'Myles-Toyne': 0.4411764705882353, 'Nyessos-Vhassar': 0.45454545454545453, 'Qavo-Nogarys': 0.39473684210526316, 'Rhaenys-Targaryen-(daughter-of-Rhaegar)': 0.4166666666666667, 'Rolly-Duckfield': 0.5769230769230769, 'Yandry': 0.5769230769230769, 'Ysilla': 0.5}
#   pagerank: {'Aegon-Targaryen-(son-of-Rhaegar)': 0.12874697089278136, 'Benerro': 0.0218649754261402, 'Black-Balaq': 0.02509362853527881, 'Franklyn-Flowers': 0.05547886111717115, 'Haldon': 0.11755390311125483, 'Harry-Strickland': 0.04944844694814352, 'Jon-Connington': 0.1335588974246074, 'Lemore': 0.08134898286327918, 'Malaquo-Maegyr': 0.029307743051187638, 'Myles-Toyne': 0.0359995576481405, 'Nyessos-Vhassar': 0.04690310335367022, 'Qavo-Nogarys': 0.0218649754261402, 'Rhaenys-Targaryen-(daughter-of-Rhaegar)': 0.021534481274050138, 'Rolly-Duckfield': 0.08134898286327918, 'Yandry': 0.08134898286327918, 'Ysilla': 0.06859750720159632}
#   clustering_coefficient: {'Aegon-Targaryen-(son-of-Rhaegar)': 0.4444444444444444, 'Benerro': 0, 'Black-Balaq': 0, 'Franklyn-Flowers': 0.3333333333333333, 'Haldon': 0.5, 'Harry-Strickland': 0.6666666666666666, 'Jon-Connington': 0.3611111111111111, 'Lemore': 0.9333333333333333, 'Malaquo-Maegyr': 0, 'Myles-Toyne': 1.0, 'Nyessos-Vhassar': 0, 'Qavo-Nogarys': 0, 'Rhaenys-Targaryen-(daughter-of-Rhaegar)': 0, 'Rolly-Duckfield': 0.9333333333333333, 'Yandry': 0.9333333333333333, 'Ysilla': 1.0}
#   eigenvector_centrality: {'Aegon-Targaryen-(son-of-Rhaegar)': 0.40916410371489065, 'Benerro': 0.062186374874714255, 'Black-Balaq': 0.021855234813843098, 'Franklyn-Flowers': 0.1329178717603366, 'Haldon': 0.37820747291970275, 'Harry-Strickland': 0.1434037274540887, 'Jon-Connington': 0.37735953477299283, 'Lemore': 0.36064532319942616, 'Malaquo-Maegyr': 0.01048586210195389, 'Myles-Toyne': 0.08562697478821045, 'Nyessos-Vhassar': 0.06377174638256913, 'Qavo-Nogarys': 0.062186374874714255, 'Rhaenys-Targaryen-(daughter-of-Rhaegar)': 0.06727669643685803, 'Rolly-Duckfield': 0.36064532319942616, 'Yandry': 0.36064532319942616, 'Ysilla': 0.3073594389188109}
#   intra_density: 0.26666666666666666
#
# Modularity Class: 17
#   degree_centrality: {'Raynard': 1.0, 'Torbert': 1.0}
#   betweenness_centrality: {'Raynard': 0.0, 'Torbert': 0.0}
#   closeness_centrality: {'Raynard': 1.0, 'Torbert': 1.0}
#   pagerank: {'Raynard': 0.5, 'Torbert': 0.5}
#   clustering_coefficient: {'Raynard': 0, 'Torbert': 0}
#   eigenvector_centrality: {'Raynard': 0.7071067811865476, 'Torbert': 0.7071067811865476}
#   intra_density: 1.0
#
# Modularity Class: 18
#   degree_centrality: {'Gared': 1.0, 'Waymar-Royce': 1.0, 'Will-(prologue)': 1.0}
#   betweenness_centrality: {'Gared': 0.0, 'Waymar-Royce': 0.0, 'Will-(prologue)': 0.0}
#   closeness_centrality: {'Gared': 1.0, 'Waymar-Royce': 1.0, 'Will-(prologue)': 1.0}
#   pagerank: {'Gared': 0.3333333333333333, 'Waymar-Royce': 0.3333333333333333, 'Will-(prologue)': 0.3333333333333333}
#   clustering_coefficient: {'Gared': 1.0, 'Waymar-Royce': 1.0, 'Will-(prologue)': 1.0}
#   eigenvector_centrality: {'Gared': 0.5773502691896258, 'Waymar-Royce': 0.5773502691896258, 'Will-(prologue)': 0.5773502691896258}
#   intra_density: 1.0
#
# Modularity Class: 19
#   degree_centrality: {'Martyn-Lannister': 0.5, 'Tion-Frey': 0.5, 'Willem-Lannister': 1.0}
#   betweenness_centrality: {'Martyn-Lannister': 0.0, 'Tion-Frey': 0.0, 'Willem-Lannister': 1.0}
#   closeness_centrality: {'Martyn-Lannister': 0.6666666666666666, 'Tion-Frey': 0.6666666666666666, 'Willem-Lannister': 1.0}
#   pagerank: {'Martyn-Lannister': 0.25675708783778944, 'Tion-Frey': 0.25675708783778944, 'Willem-Lannister': 0.48648582432442095}
#   clustering_coefficient: {'Martyn-Lannister': 0, 'Tion-Frey': 0, 'Willem-Lannister': 0}
#   eigenvector_centrality: {'Martyn-Lannister': 0.5000000644180599, 'Tion-Frey': 0.5000000644180599, 'Willem-Lannister': 0.707106690085642}
#   intra_density: 0.6666666666666666

# %% [markdown]
# Calcolo delle misure rispetto alle casate

# %%
# Calcola le misure per ciascun valore di 'modularity_class'
resultsHouses = {}
houses = np.unique(df['house'])
houses = houses[houses != 'Other']

for house in houses:
    # Filtra il DataFrame per ciascun 'modularity_class'
    group_df = df[df['house'] == house]
    group_edges = df_edges[df_edges['Source'].isin(group_df['Id']) & df_edges['Target'].isin(group_df['Id'])]

    print("House", house)
    # Calcola le misure di centralità per il gruppo filtrato
    centrality_measures = calculate_centrality_measures(group_df, group_edges)

    # Salva i risultati per ogni classe
    resultsHouses[house] = centrality_measures
# Out:
# House Arryn
# House Baratheon
# House Bolton
# House Cassel
# House Clegane
# House Frey
# House Greyjoy
# House Jon-Snow
# House Lannister
# House Martell
# House Selmy
# House Stark
# House Targaryen
# House Tarly
# House Tully
# House Tyrell

# %%
# Print ignorante
# Mostra i risultati
for house, measures in resultsHouses.items():
    print(f"House: {house}")
    for measure, values in measures.items():
        print(f"  {measure}: {values}")
    print()
# Out:
# House: Arryn
#   degree_centrality: {'Alys-Arryn': 0.25, 'Elbert-Arryn': 0.0, 'Jon-Arryn': 0.75, 'Lysa-Arryn': 0.5, 'Robert-Arryn': 0.5}
#   betweenness_centrality: {'Alys-Arryn': 0.0, 'Elbert-Arryn': 0.0, 'Jon-Arryn': 0.3333333333333333, 'Lysa-Arryn': 0.0, 'Robert-Arryn': 0.0}
#   closeness_centrality: {'Alys-Arryn': 0.44999999999999996, 'Elbert-Arryn': 0.0, 'Jon-Arryn': 0.75, 'Lysa-Arryn': 0.5625, 'Robert-Arryn': 0.5625}
#   pagerank: {'Alys-Arryn': 0.13629777039596325, 'Elbert-Arryn': 0.03614457831325302, 'Jon-Arryn': 0.35347942441816593, 'Lysa-Arryn': 0.23703911343630887, 'Robert-Arryn': 0.23703911343630887}
#   clustering_coefficient: {'Alys-Arryn': 0, 'Elbert-Arryn': 0, 'Jon-Arryn': 0.3333333333333333, 'Lysa-Arryn': 1.0, 'Robert-Arryn': 1.0}
#   eigenvector_centrality: {'Alys-Arryn': 0.28184664735759357, 'Elbert-Arryn': 1.579489577304808e-07, 'Jon-Arryn': 0.6116289079988952, 'Lysa-Arryn': 0.5227200714882385, 'Robert-Arryn': 0.5227200714882385}
#   intra_density: 0.4
#
# House: Baratheon
#   degree_centrality: {'Joffrey-Baratheon': 0.8571428571428571, 'Myrcella-Baratheon': 0.5714285714285714, 'Renly-Baratheon': 0.5714285714285714, 'Robert-Baratheon': 0.7142857142857142, 'Shireen-Baratheon': 0.42857142857142855, 'Stannis-Baratheon': 1.0, 'Steffon-Baratheon': 0.2857142857142857, 'Tommen-Baratheon': 0.7142857142857142}
#   betweenness_centrality: {'Joffrey-Baratheon': 0.0873015873015873, 'Myrcella-Baratheon': 0.0, 'Renly-Baratheon': 0.047619047619047616, 'Robert-Baratheon': 0.031746031746031744, 'Shireen-Baratheon': 0.0, 'Stannis-Baratheon': 0.27777777777777773, 'Steffon-Baratheon': 0.0, 'Tommen-Baratheon': 0.031746031746031744}
#   closeness_centrality: {'Joffrey-Baratheon': 0.875, 'Myrcella-Baratheon': 0.7, 'Renly-Baratheon': 0.7, 'Robert-Baratheon': 0.7777777777777778, 'Shireen-Baratheon': 0.6363636363636364, 'Stannis-Baratheon': 1.0, 'Steffon-Baratheon': 0.5833333333333334, 'Tommen-Baratheon': 0.7777777777777778}
#   pagerank: {'Joffrey-Baratheon': 0.16056129452940798, 'Myrcella-Baratheon': 0.11049157819228625, 'Renly-Baratheon': 0.11556126259252339, 'Robert-Baratheon': 0.13549367639182774, 'Shireen-Baratheon': 0.08745753931199396, 'Stannis-Baratheon': 0.18854839097238363, 'Steffon-Baratheon': 0.06620170255040804, 'Tommen-Baratheon': 0.1356845554591689}
#   clustering_coefficient: {'Joffrey-Baratheon': 0.6666666666666666, 'Myrcella-Baratheon': 1.0, 'Renly-Baratheon': 0.6666666666666666, 'Robert-Baratheon': 0.8, 'Shireen-Baratheon': 1.0, 'Stannis-Baratheon': 0.5238095238095238, 'Steffon-Baratheon': 1.0, 'Tommen-Baratheon': 0.8}
#   eigenvector_centrality: {'Joffrey-Baratheon': 0.4355540432539794, 'Myrcella-Baratheon': 0.3414088455613351, 'Renly-Baratheon': 0.2941828371853095, 'Robert-Baratheon': 0.39123895274029635, 'Shireen-Baratheon': 0.26162498211864055, 'Stannis-Baratheon': 0.4616626214066491, 'Steffon-Baratheon': 0.15413712598858892, 'Tommen-Baratheon': 0.38572393607501826}
#   intra_density: 0.6428571428571429
#
# House: Bolton
#   degree_centrality: {'Ramsay-Snow': 1.0, 'Roose-Bolton': 1.0}
#   betweenness_centrality: {'Ramsay-Snow': 0.0, 'Roose-Bolton': 0.0}
#   closeness_centrality: {'Ramsay-Snow': 1.0, 'Roose-Bolton': 1.0}
#   pagerank: {'Ramsay-Snow': 0.5, 'Roose-Bolton': 0.5}
#   clustering_coefficient: {'Ramsay-Snow': 0, 'Roose-Bolton': 0}
#   eigenvector_centrality: {'Ramsay-Snow': 0.7071067811865476, 'Roose-Bolton': 0.7071067811865476}
#   intra_density: 1.0
#
# House: Cassel
#   degree_centrality: {'Beth-Cassel': 0.5, 'Jory-Cassel': 0.5, 'Rodrik-Cassel': 1.0}
#   betweenness_centrality: {'Beth-Cassel': 0.0, 'Jory-Cassel': 0.0, 'Rodrik-Cassel': 1.0}
#   closeness_centrality: {'Beth-Cassel': 0.6666666666666666, 'Jory-Cassel': 0.6666666666666666, 'Rodrik-Cassel': 1.0}
#   pagerank: {'Beth-Cassel': 0.25675708783778944, 'Jory-Cassel': 0.25675708783778944, 'Rodrik-Cassel': 0.48648582432442095}
#   clustering_coefficient: {'Beth-Cassel': 0, 'Jory-Cassel': 0, 'Rodrik-Cassel': 0}
#   eigenvector_centrality: {'Beth-Cassel': 0.5000000644180599, 'Jory-Cassel': 0.5000000644180599, 'Rodrik-Cassel': 0.707106690085642}
#   intra_density: 0.6666666666666666
#
# House: Clegane
#   degree_centrality: {'Gregor-Clegane': 1.0, 'Sandor-Clegane': 1.0}
#   betweenness_centrality: {'Gregor-Clegane': 0.0, 'Sandor-Clegane': 0.0}
#   closeness_centrality: {'Gregor-Clegane': 1.0, 'Sandor-Clegane': 1.0}
#   pagerank: {'Gregor-Clegane': 0.5, 'Sandor-Clegane': 0.5}
#   clustering_coefficient: {'Gregor-Clegane': 0, 'Sandor-Clegane': 0}
#   eigenvector_centrality: {'Gregor-Clegane': 0.7071067811865476, 'Sandor-Clegane': 0.7071067811865476}
#   intra_density: 1.0
#
# House: Frey
#   degree_centrality: {'Aegon-Frey-(son-of-Stevron)': 0.08695652173913043, 'Aenys-Frey': 0.043478260869565216, 'Amerei-Frey': 0.0, 'Cleos-Frey': 0.0, 'Danwell-Frey': 0.13043478260869565, 'Edwyn-Frey': 0.043478260869565216, 'Elmar-Frey': 0.043478260869565216, 'Emmon-Frey': 0.043478260869565216, 'Hosteen-Frey': 0.13043478260869565, 'Jared-Frey': 0.13043478260869565, 'Lothar-Frey': 0.13043478260869565, 'Merrett-Frey': 0.043478260869565216, 'Olyvar-Frey': 0.043478260869565216, 'Perwyn-Frey': 0.0, 'Petyr-Frey': 0.08695652173913043, 'Rhaegar-Frey': 0.043478260869565216, 'Roslin-Frey': 0.08695652173913043, 'Ryman-Frey': 0.21739130434782608, 'Stevron-Frey': 0.13043478260869565, 'Tion-Frey': 0.0, 'Walda-Frey-(daughter-of-Merrett)': 0.0, 'Walder-Frey': 0.30434782608695654, 'Walder-Frey-(son-of-Jammos)': 0.043478260869565216, 'Walder-Frey-(son-of-Merrett)': 0.043478260869565216}
#   betweenness_centrality: {'Aegon-Frey-(son-of-Stevron)': 0
#   closeness_centrality: {'Aeron-Greyjoy': 0.7346938775510203, 'Asha-Greyjoy': 0.7346938775510203, 'Balon-Greyjoy': 0.7346938775510203, 'Euron-Greyjoy': 0.8571428571428571, 'Maron-Greyjoy': 0.0, 'Quellon-Greyjoy': 0.5142857142857142, 'Theon-Greyjoy': 0.7346938775510203, 'Victarion-Greyjoy': 0.8571428571428571}
#   pagerank: {'Aeron-Greyjoy': 0.14179572373118998, 'Asha-Greyjoy': 0.14179572373118998, 'Balon-Greyjoy': 0.14179572373118998, 'Euron-Greyjoy': 0.1711789744171679, 'Maron-Greyjoy': 0.020979020979236294, 'Quellon-Greyjoy': 0.0694801352616681, 'Theon-Greyjoy': 0.14179572373118998, 'Victarion-Greyjoy': 0.1711789744171679}
#   clustering_coefficient: {'Aeron-Greyjoy': 1.0, 'Asha-Greyjoy': 1.0, 'Balon-Greyjoy': 1.0, 'Euron-Greyjoy': 0.7333333333333333, 'Maron-Greyjoy': 0, 'Quellon-Greyjoy': 1.0, 'Theon-Greyjoy': 1.0, 'Victarion-Greyjoy': 0.7333333333333333}
#   eigenvector_centrality: {'Aeron-Greyjoy': 0.3936514815328554, 'Asha-Greyjoy': 0.3936514815328554, 'Balon-Greyjoy': 0.3936514815328554, 'Euron-Greyjoy': 0.42033183822962805, 'Maron-Greyjoy': 3.146828821732721e-08, 'Quellon-Greyjoy': 0.1636958639946492, 'Theon-Greyjoy': 0.3936514815328554, 'Victarion-Greyjoy': 0.42033183822962805}
#   intra_density: 0.6071428571428571
#
# House: Jon-Snow
#   degree_centrality: {'Jon-Snow': 1}
#   betweenness_centrality: {'Jon-Snow': 0.0}
#   closeness_centrality: {'Jon-Snow': 0.0}
#   pagerank: {'Jon-Snow': 1.0}
#   clustering_coefficient: {'Jon-Snow': 0}
#   eigenvector_centrality: {'Jon-Snow': 1.0}
#   intra_density: 0
#
# House: Lannister
#   degree_centrality: {'Cersei-Lannister': 0.4545454545454546, 'Daven-Lannister': 0.09090909090909091, 'Genna-Lannister': 0.18181818181818182, 'Jaime-Lannister': 0.7272727272727273, 'Joanna-Lannister': 0.09090909090909091, 'Kevan-Lannister': 0.5454545454545454, 'Lancel-Lannister': 0.36363636363636365, 'Martyn-Lannister': 0.18181818181818182, 'Stafford-Lannister': 0.09090909090909091, 'Tyrion-Lannister': 0.4545454545454546, 'Tywin-Lannister': 0.6363636363636364, 'Willem-Lannister': 0.18181818181818182}
#   betweenness_centrality: {'Cersei-Lannister': 0.012727272727272726, 'Daven-Lannister': 0.0, 'Genna-Lannister': 0.0, 'Jaime-Lannister': 0.4096969696969697, 'Joanna-Lannister': 0.0, 'Kevan-Lannister': 0.15575757575757573, 'Lancel-Lannister': 0.0, 'Martyn-Lannister': 0.02424242424242424, 'Stafford-Lannister': 0.0, 'Tyrion-Lannister': 0.012727272727272726, 'Tywin-Lannister': 0.3539393939393939, 'Willem-Lannister': 0.012727272727272726}
#   closeness_centrality: {'Cersei-Lannister': 0.6470588235294118, 'Daven-Lannister': 0.4583333333333333, 'Genna-Lannister': 0.5238095238095238, 'Jaime-Lannister': 0.7857142857142857, 'Joanna-Lannister': 0.44, 'Kevan-Lannister': 0.6875, 'Lancel-Lannister': 0.55, 'Martyn-Lannister': 0.4782608695652174, 'Stafford-Lannister': 0.4583333333333333, 'Tyrion-Lannister': 0.6470588235294118, 'Tywin-Lannister': 0.7333333333333333, 'Willem-Lannister': 0.4583333333333333}
#   pagerank: {'Cersei-Lannister': 0.10342441071499468, 'Daven-Lannister': 0.03127396909298522, 'Genna-Lannister': 0.05011220980147159, 'Jaime-Lannister': 0.17669551982708206, 'Joanna-Lannister': 0.03133824070848637, 'Kevan-Lannister': 0.12581971696528516, 'Lancel-Lannister': 0.08426242164941172, 'Martyn-Lannister': 0.053975707053596625, 'Stafford-Lannister': 0.03127396909298522, 'Tyrion-Lannister': 0.1034244107149947, 'Tywin-Lannister': 0.15513606430065777, 'Willem-Lannister': 0.053263360078048855}
#   clustering_coefficient: {'Cersei-Lannister': 0.9, 'Daven-Lannister': 0, 'Genna-Lannister': 1.0, 'Jaime-Lannister': 0.35714285714285715, 'Joanna-Lannister': 0, 'Kevan-Lannister': 0.6, 'Lancel-Lannister': 1.0, 'Martyn-Lannister': 0, 'Stafford-Lannister': 0, 'Tyrion-Lannister': 0.9, 'Tywin-Lannister': 0.3333333333333333, 'Willem-Lannister': 0}
#   eigenvector_centrality: {'Cersei-Lannister': 0.39018524105321095, 'Daven-Lannister': 0.08894623575378365, 'Genna-Lannister': 0.1671273446637092, 'Jaime-Lannister': 0.44740226792668175, 'Joanna-Lannister': 0.07818110893404856, 'Kevan-Lannister': 0.40683423939703867, 'Lancel-Lannister': 0.3249695973222284, 'Martyn-Lannister': 0.09814019469544805, 'Stafford-Lannister': 0.08894623575378365, 'Tyrion-Lannister': 0.3901852410532109, 'Tywin-Lannister': 0.3932504853284661, 'Willem-Lannister': 0.10039265704746138}
#   intra_density: 0.3333333333333333
#
# House: Martell
#   degree_centrality: {'Arianne-Martell': 0.42857142857142855, 'Doran-Martell': 0.42857142857142855, 'Elia-Martell': 0.14285714285714285, 'Lewyn-Martell': 0.0, 'Manfrey-Martell': 0.0, 'Oberyn-Martell': 0.42857142857142855, 'Quentyn-Martell': 0.42857142857142855, 'Trystane-Martell': 0.14285714285714285}
#   betweenness_centrality: {'Arianne-Martell': 0.09523809523809523, 'Doran-Martell': 0.09523809523809523, 'Elia-Martell': 0.0, 'Lewyn-Martell': 0.0, 'Manfrey-Martell': 0.0, 'Oberyn-Martell': 0.19047619047619047, 'Quentyn-Martell': 0.19047619047619047, 'Trystane-Martell': 0.0}
#   closeness_centrality: {'Arianne-Martell': 0.5102040816326531, 'Doran-Martell': 0.5102040816326531, 'Elia-Martell': 0.2976190476190476, 'Lewyn-Martell': 0.0, 'Manfrey-Martell': 0.0, 'Oberyn-Martell': 0.44642857142857145, 'Quentyn-Martell': 0.44642857142857145, 'Trystane-Martell': 0.2976190476190476}
 'Rhaenys-Targaryen-(daughter-of-Rhaegar)': 0, 'Visenya-Targaryen': 1.0, 'Viserys-Targaryen': 0.5}
#   eigenvector_centrality: {'Aegon-I-Targaryen': 0.14501100286967622, 'Aegon-Targaryen-(son-of-Rhaegar)': 0.3926703080334549, 'Aegon-V-Targaryen': 0.010144945386320403, 'Aemon-Targaryen-(Dragonknight)': 2.7342133052621005e-18, 'Aemon-Targaryen-(Maester-Aemon)': 0.038833512254444646, 'Aerys-I-Targaryen': 2.7342133052621005e-18, 'Aerys-II-Targaryen': 0.24765644418790783, 'Baelor-I-Targaryen': 2.7342133052621005e-18, 'Daenerys-Targaryen': 0.45253286027697764, 'Daeron-I-Targaryen': 2.7342133052621005e-18, 'Daeron-II-Targaryen': 0.12836199165769063, 'Jaehaerys-I-Targaryen': 9.174497442491239e-11, 'Maegor-I-Targaryen': 9.174497442491239e-11, 'Maekar-I-Targaryen': 0.010144945386320403, 'Rhaegar-Targaryen': 0.4740152450518622, 'Rhaegel-Targaryen': 0.11821704627137024, 'Rhaella-Targaryen': 0.24765644418790783, 'Rhaenys-Targaryen': 0.05127979699789798, 'Rhaenys-Targaryen-(daughter-of-Rhaegar)': 0.10257839551719904, 'Visenya-Targaryen': 0.05127979699789798, 'Viserys-Targaryen': 0.4740152450518622}
#   intra_density: 0.1
#
# House: Tarly
#   degree_centrality: {'Randyll-Tarly': 1.0, 'Samwell-Tarly': 1.0}
#   betweenness_centrality: {'Randyll-Tarly': 0.0, 'Samwell-Tarly': 0.0}
#   closeness_centrality: {'Randyll-Tarly': 1.0, 'Samwell-Tarly': 1.0}
#   pagerank: {'Randyll-Tarly': 0.5, 'Samwell-Tarly': 0.5}
#   clustering_coefficient: {'Randyll-Tarly': 0, 'Samwell-Tarly': 0}
#   eigenvector_centrality: {'Randyll-Tarly': 0.7071067811865476, 'Samwell-Tarly': 0.7071067811865476}
#   intra_density: 1.0
#
# House: Tully
#   degree_centrality: {'Brynden-Tully': 1.0, 'Edmure-Tully': 1.0, 'Hoster-Tully': 1.0}
#   betweenness_centrality: {'Brynden-Tully': 0.0, 'Edmure-Tully': 0.0, 'Hoster-Tully': 0.0}
#   closeness_centrality: {'Brynden-Tully': 1.0, 'Edmure-Tully': 1.0, 'Hoster-Tully': 1.0}
#   pagerank: {'Brynden-Tully': 0.3333333333333333, 'Edmure-Tully': 0.3333333333333333, 'Hoster-Tully': 0.3333333333333333}
#   clustering_coefficient: {'Brynden-Tully': 1.0, 'Edmure-Tully': 1.0, 'Hoster-Tully': 1.0}
#   eigenvector_centrality: {'Brynden-Tully': 0.5773502691896258, 'Edmure-Tully': 0.5773502691896258, 'Hoster-Tully': 0.5773502691896258}
#   intra_density: 1.0
#
# House: Tyrell
#   degree_centrality: {'Alla-Tyrell': 0.30000000000000004, 'Elinor-Tyrell': 0.30000000000000004, 'Garlan-Tyrell': 0.2, 'Garth-Tyrell': 0.0, 'Gormon-Tyrell': 0.0, 'Leo-Tyrell': 0.0, 'Loras-Tyrell': 0.4, 'Mace-Tyrell': 0.30000000000000004, 'Margaery-Tyrell': 0.6000000000000001, 'Megga-Tyrell': 0.30000000000000004, 'Willas-Tyrell': 0.4}
#   betweenness_centrality: {'Alla-Tyrell': 0.0, 'Elinor-Tyrell': 0.0, 'Garlan-Tyrell': 0.0, 'Garth-Tyrell': 0.0, 'Gormon-Tyrell': 0.0, 'Leo-Tyrell': 0.0, 'Loras-Tyrell': 0.05555555555555556, 'Mace-Tyrell': 0.0, 'Margaery-Tyrell': 0.26666666666666666, 'Megga-Tyrell': 0.0, 'Willas-Tyrell': 0.05555555555555556}
#   closeness_centrality: {'Alla-Tyrell': 0.4083333333333333, 'Elinor-Tyrell': 0.4083333333333333, 'Garlan-Tyrell': 0.32666666666666666, 'Garth-Tyrell': 0.0, 'Gormon-Tyrell': 0.0, 'Leo-Tyrell': 0.0, 'Loras-Tyrell': 0.48999999999999994, 'Mace-Tyrell': 0.44545454545454544, 'Margaery-Tyrell': 0.6124999999999999, 'Megga-Tyrell': 0.4083333333333333, 'Willas-Tyrell': 0.48999999999999994}
#   pagerank: {'Alla-Tyrell': 0.10359657422291585, 'Elinor-Tyrell': 0.10359657422291585, 'Garlan-Tyrell': 0.07467598950777823, 'Garth-Tyrell': 0.017751479698426626, 'Gormon-Tyrell': 0.017751479698426626, 'Leo-Tyrell': 0.017751479698426626, 'Loras-Tyrell': 0.1339410542887008, 'Mace-Tyrell': 0.10181674214388284, 'Margaery-Tyrell': 0.19158099800690956, 'Megga-Tyrell': 0.10359657422291585, 'Willas-Tyrell': 0.1339410542887008}
#   clustering_coefficient: {'Alla-Tyrell': 1.0, 'Elinor-Tyrell': 1.0, 'Garlan-Tyrell': 1.0, 'Garth-Tyrell': 0, 'Gormon-Tyrell': 0, 'Leo-Tyrell': 0, 'Loras-Tyrell': 0.6666666666666666, 'Mace-Tyrell': 1.0, 'Margaery-Tyrell': 0.4, 'Megga-Tyrell': 1.0, 'Willas-Tyrell': 0.6666666666666666}
#   eigenvector_centrality: {'Alla-Tyrell': 0.29586367412982434, 'Elinor-Tyrell': 0.29586367412982434, 'Garlan-Tyrell': 0.2038624671698625, 'Garth-Tyrell': 3.983081089173807e-16, 'Gormon-Tyrell': 3.983081089173807e-16, 'Leo-Tyrell': 3.983081089173807e-16, 'Loras-Tyrell': 0.38607995697908704, 'Mace-Tyrell': 0.3434991262733175, 'Margaery-Tyrell': 0.5288922738688286, 'Megga-Tyrell': 0.29586367412982434, 'Willas-Tyrell': 0.386079956979087}
#   intra_density: 0.2545454545454545

# %% [markdown]
# # **ANALISI DELLE COMUNITA'**

# %% [markdown]
# ##**Identificazione delle principali fazioni e alleanze**
# ####**Identificazione delle comunità principali**
# L'obiettivo è determinare i gruppi principali o le fazioni presenti nella rete sociale di Game of Thrones. Questo è essenziale per comprendere come i personaggi si organizzano in sottoreti e per analizzare le dinamiche sociali tra gruppi come casate, alleanze e fazioni politiche.
#
#
# Metriche usate:
# * **Louvain Modularity**: Algoritmo utilizzato per rilevare le comunità massimizzando la modularità, che misura la densità delle connessioni all'interno delle comunità rispetto a quelle tra comunità diverse. Questo aiuta a identificare cluster di personaggi che interagiscono principalmente tra loro.
# * **Inter- e intra-community density**: Misura il rapporto tra le connessioni all'interno di una comunità e quelle tra comunità diverse, utile per verificare la coesione di ogni gruppo.

# %% [markdown]
# ###Sviluppo
# Identificazione e calcolo misure di centralità delle comunità.

# %%
# Calcola le misure per ciascun valore di 'modularity_class'
resultsComunities = {}

for modularity_class in modularity:
    # Filtra il DataFrame per ciascun 'modularity_class'
    group_df = df[df['modularity_class'] == modularity_class]

    rappresentante = group_df.loc[group_df['Authority'].idxmax()]

    group_edges = df_edges[df_edges['Source'].isin(group_df['Id']) & df_edges['Target'].isin(group_df['Id'])]

    print("Modularity", modularity_class, "- rappresentante:", rappresentante['Label'])
    # Calcola le misure di centralità per il gruppo filtrato
    centrality_measures = calculate_centrality_measures(group_df, group_edges)

    # Salva i risultati per ogni classe
    resultsComunities[modularity_class] = centrality_measures
    resultsComunities[modularity_class]['Authority'] = rappresentante['Label']
# Out:
# Modularity 0 - rappresentante: Arya Stark
# Modularity 1 - rappresentante: Catelyn Stark
# Modularity 2 - rappresentante: Stannis Baratheon
# Modularity 3 - rappresentante: Unella
# Modularity 4 - rappresentante: Alys Arryn
# Modularity 5 - rappresentante: Gerold Hightower
# Modularity 6 - rappresentante: Barristan Selmy
# Modularity 7 - rappresentante: Balon Greyjoy
# Modularity 8 - rappresentante: Horas Redwyne
# Modularity 9 - rappresentante: Jaime Lannister
# Modularity 10 - rappresentante: Tyrion Lannister
# Modularity 11 - rappresentante: Jon Snow
# Modularity 12 - rappresentante: Florian the Fool
# Modularity 13 - rappresentante: Alla Tyrell
# Modularity 14 - rappresentante: Alleras
# Modularity 15 - rappresentante: Myrcella Baratheon
# Modularity 16 - rappresentante: Jon Connington
# Modularity 17 - rappresentante: Raynard
# Modularity 18 - rappresentante: Waymar Royce
# Modularity 19 - rappresentante: Willem Lannister

# %% [markdown]
# Calcolo della densità intra e inter comunitaria delle densità

# %%
from collections import defaultdict

# Creiamo un grafo (graph) basato sulle informazioni contenute nel DataFrame
G = nx.Graph()

# Aggiungi i nodi
for idx, row in df.iterrows():
    G.add_node(row['Id'], label=row['Label'], house=row['house'], modularity=row['modularity_class'])

# Aggiungi gli archi se le informazioni sono disponibili (ad esempio, grado o relazioni)
# Aggiungi gli archi dal file degli archi (df_edges)
for idx, row in df_edges.iterrows():
    source = row['Source']
    target = row['Target']
    G.add_edge(source, target)

# Analizza connessioni inter-comunitarie
inter_connections = defaultdict(int)

for u, v in G.edges():
    comm_u = G.nodes[u]['modularity']
    comm_v = G.nodes[v]['modularity']
    if comm_u != comm_v:
        inter_connections[(comm_u, comm_v)] += 1


# Stampa i risultati
print("Densità intra-comunitaria:")
for modularity_class, measures in resultsComunities.items():
    print(f"Comunità {modularity_class} {measures['Authority']}: {measures['intra_density']:.2f}")


print("\nConnessioni inter-comunitarie:")
for (comm_u, comm_v), count in inter_connections.items():
   print(f"Tra Comunità {comm_u} e {comm_v}: {count} collegamenti")
# Out:
# Densità intra-comunitaria:
# Comunità 0 Arya Stark: 0.09
# Comunità 1 Catelyn Stark: 0.05
# Comunità 2 Stannis Baratheon: 0.07
# Comunità 3 Unella: 1.00
# Comunità 4 Alys Arryn: 1.00
# Comunità 5 Gerold Hightower: 0.43
# Comunità 6 Barristan Selmy: 0.06
# Comunità 7 Balon Greyjoy: 0.08
# Comunità 8 Horas Redwyne: 1.00
# Comunità 9 Jaime Lannister: 0.05
# Comunità 10 Tyrion Lannister: 0.04
# Comunità 11 Jon Snow: 0.05
# Comunità 12 Florian the Fool: 1.00
# Comunità 13 Alla Tyrell: 1.00
# Comunità 14 Alleras: 0.35
# Comunità 15 Myrcella Baratheon: 0.21
# Comunità 16 Jon Connington: 0.27
# Comunità 17 Raynard: 1.00
# Comunità 18 Waymar Royce: 1.00
# Comunità 19 Willem Lannister: 0.67
#
# Connessioni inter-comunitarie:
# Tra Comunità 10 e 1: 38 collegamenti
# Tra Comunità 10 e 9: 21 collegamenti
# Tra Comunità 6 e 10: 36 collegamenti
# Tra Comunità 6 e 0: 3 collegamenti
# Tra Comunità 6 e 1: 1 collegamenti
# Tra Comunità 6 e 2: 1 collegamenti
# Tra Comunità 16 e 6: 5 collegamenti
# Tra Comunità 16 e 10: 14 collegamenti
# Tra Comunità 11 e 14: 1 collegamenti
# Tra Comunità 11 e 6: 2 collegamenti
# Tra Comunità 11 e 10: 20 collegamenti
# Tra Comunità 11 e 2: 26 collegamenti
# Tra Comunità 2 e 0: 2 collegamenti
# Tra Comunità 2 e 1: 8 collegamenti
# Tra Comunità 7 e 1: 14 collegamenti
# Tra Comunità 10 e 5: 3 collegamenti
# Tra Comunità 10 e 6: 9 collegamenti
# Tra Comunità 2 e 10: 17 collegamenti
# Tra Comunità 13 e 10: 7 collegamenti
# Tra Comunità 10 e 11: 10 collegamenti
# Tra Comunità 14 e 11: 3 collegamenti
# Tra Comunità 10 e 0: 42 collegamenti
# Tra Comunità 4 e 10: 1 collegamenti
# Tra Comunità 7 e 2: 7 collegamenti
# Tra Comunità 9 e 10: 55 collegamenti
# Tra Comunità 0 e 10: 54 collegamenti
# Tra Comunità 0 e 9: 15 collegamenti
# Tra Comunità 0 e 1: 20 collegamenti
# Tra Comunità 15 e 10: 21 collegamenti
# Tra Comunità 15 e 6: 3 collegamenti
# Tra Comunità 2 e 7: 2 collegamenti
# Tra Comunità 5 e 10: 2 collegamenti
# Tra Comunità 0 e 11: 7 collegamenti
# Tra Comunità 0 e 2: 2 collegamenti
# Tra Comunità 0 e 15: 2 collegamenti
# Tra Comunità 7 e 10: 5 collegamenti
# Tra Comunità 7 e 11: 1 collegamenti
# Tra Comunità 10 e 2: 30 collegamenti
# Tra Comunità 2 e 11: 14 collegamenti
# Tra Comunità 10 e 15: 7 collegamenti
# Tra Comunità 1 e 2: 16 collegamenti
# Tra Comunità 6 e 5: 1 collegamenti
# Tra Comunità 6 e 9: 1 collegamenti
# Tra Comunità 16 e 7: 1 collegamenti
# Tra Comunità 11 e 1: 17 collegamenti
# Tra Comunità 11 e 18: 1 collegamenti
# Tra Comunità 11 e 0: 4 collegamenti
# Tra Comunità 1 e 10: 68 collegamenti
# Tra Comunità 1 e 11: 8 collegamenti
# Tra Comunità 1 e 0: 5 collegamenti
# Tra Comunità 9 e 1: 17 collegamenti
# Tra Comunità 9 e 0: 9 collegamenti
# Tra Comunità 9 e 2: 5 collegamenti
# Tra Comunità 1 e 9: 31 collegamenti
# Tra Comunità 15 e 0: 3 collegamenti
# Tra Comunità 10 e 3: 4 collegamenti
# Tra Comunità 10 e 17: 1 collegamenti
# Tra Comunità 6 e 15: 2 collegamenti
# Tra Comunità 6 e 16: 4 collegamenti
# Tra Comunità 6 e 7: 2 collegamenti
# Tra Comunità 12 e 10: 1 collegamenti
# Tra Comunità 18 e 11: 1 collegamenti
# Tra Comunità 5 e 9: 1 collegamenti
# Tra Comunità 2 e 9: 2 collegamenti
# Tra Comunità 8 e 10: 1 collegamenti
# Tra Comunità 9 e 11: 2 collegamenti
# Tra Comunità 10 e 19: 1 collegamenti
# Tra Comunità 10 e 13: 1 collegamenti
# Tra Comunità 19 e 10: 1 collegamenti
# Tra Comunità 15 e 1: 1 collegamenti
# Tra Comunità 15 e 2: 1 collegamenti
# Tra Comunità 1 e 19: 1 collegamenti
# Tra Comunità 1 e 7: 1 collegamenti
# Tra Comunità 10 e 16: 2 collegamenti

# %% [markdown]
# Winner and losers nelle comunità

# %%
# Trova le 5 casate con maggiore densità intra-comunitaria
top_5_density_comm = sorted(resultsComunities.items(), key=lambda x: x[1]['intra_density'], reverse=True)[:5]
##fai pesato rispetto al numero di nodi


# Trova le 5 coppie con il maggior numero di connessioni inter-comunitarie
top_5_connected_comm = sorted(inter_connections.items(), key=lambda x: x[1], reverse=True)[:5]

# Stampa i risultati
print("Top 5 casate con maggiore densità intra-comunitaria:")
for comm, measures in top_5_density_comm:
    print(f"Comunità {comm} {measures['Authority']}: {measures['intra_density']:.2f}")

print("\nTop 5 coppie di casate con il numero massimo di connessioni inter-comunitarie:")
for (comm_u, comm_v), count in top_5_connected_comm:
    print(f"Tra Comunità {comm_u} e {comm_v}: {count} collegamenti")
# Out:
# Top 5 casate con maggiore densità intra-comunitaria:
# Comunità 3 Unella: 1.00
# Comunità 4 Alys Arryn: 1.00
# Comunità 8 Horas Redwyne: 1.00
# Comunità 12 Florian the Fool: 1.00
# Comunità 13 Alla Tyrell: 1.00
#
# Top 5 coppie di casate con il numero massimo di connessioni inter-comunitarie:
# Tra Comunità 1 e 10: 68 collegamenti
# Tra Comunità 9 e 10: 55 collegamenti
# Tra Comunità 0 e 10: 54 collegamenti
# Tra Comunità 10 e 0: 42 collegamenti
# Tra Comunità 10 e 1: 38 collegamenti

# %% [markdown]
# Identificazione delle casate e calcolo delle metriche rispetto alle casate

# %%
# Calcola le misure per ciascun valore delle casate
resultsHouses = {}
houses = np.unique(df['house'])
houses = houses[houses != 'Other']

for house in houses:
    # Filtra il DataFrame per ciascun 'house'
    group_df = df[df['house'] == house]
    group_edges = df_edges[df_edges['Source'].isin(group_df['Id']) & df_edges['Target'].isin(group_df['Id'])]

    # Calcola le misure di centralità per il gruppo filtrato
    centrality_measures = calculate_centrality_measures(group_df, group_edges)

    # Salva i risultati per ogni classe
    resultsHouses[house] = centrality_measures

# %% [markdown]
# Calcolo misure della densità intra e iter casate.

# %%
# Analizza connessioni inter-comunitarie
inter_house_connections = defaultdict(int)

# Creiamo un nuovo grafo
G_houses = nx.Graph()

# Ripulisco dai bastardi (inteso come nati fuori dal matrimonio)
df_no_Other = df[df['house'] != 'Other']
df_edges_no_Other = df_edges[df_edges['Source'].isin(df_no_Other['Id']) & df_edges['Target'].isin(df_no_Other['Id'])]

# Aggiungi i nodi
for idx, row in df_no_Other.iterrows():
    G_houses.add_node(row['Id'], label=row['Label'], house=row['house'], modularity=row['modularity_class'])

# Aggiungi gli archi
for idx, row in df_edges_no_Other.iterrows():
    source = row['Source']
    target = row['Target']
    G_houses.add_edge(source, target)

#plot_graph(G_houses)

# Calcolo la densità intra-comunitaria
for u, v in G_houses.edges():
    comm_u = G_houses.nodes[u]['house']
    comm_v = G_houses.nodes[v]['house']
    if comm_u != comm_v:
        inter_house_connections[(comm_u, comm_v)] += 1


# Stampa i risultati
print("Densità intra-comunitaria:")
for house, measures in resultsHouses.items():
    print(f"Casata {house}: {measures['intra_density']:.2f}")


#print("\nConnessioni inter-comunitarie:")
#for (comm_u, comm_v), count in inter_house_connections.items():
#    print(f"Tra Comunità {comm_u} e {comm_v}: {count} collegamenti")
# Out:
# Densità intra-comunitaria:
# Casata Arryn: 0.40
# Casata Baratheon: 0.64
# Casata Bolton: 1.00
# Casata Cassel: 0.67
# Casata Clegane: 1.00
# Casata Frey: 0.08
# Casata Greyjoy: 0.61
# Casata Jon-Snow: 0.00
# Casata Lannister: 0.33
# Casata Martell: 0.25
# Casata Selmy: 0.00
# Casata Stark: 0.50
# Casata Targaryen: 0.10
# Casata Tarly: 1.00
# Casata Tully: 1.00
# Casata Tyrell: 0.25

# %% [markdown]
# Casata migliore

# %%
# Trova la casata con maggiore densità intra-comunitaria
max_density_house = max(resultsHouses.items(), key=lambda x: x[1]['intra_density'])

# Trova le casate con il numero massimo di connessioni inter-comunitarie
max_connections = max(inter_house_connections.values())
most_connected_houses = [pair for pair, count in inter_house_connections.items() if count == max_connections]

# Stampa i risultati
print("Casata con maggiore densità intra-comunitaria:")
print(f"Casata {max_density_house[0]}: {max_density_house[1]['intra_density']:.2f}")

print("\nCoppie di casate con il numero massimo di connessioni inter-comunitarie:")
for comm_u, comm_v in most_connected_houses:
    print(f"Tra Comunità {comm_u} e {comm_v}: {max_connections} collegamenti")
# Out:
# Casata con maggiore densità intra-comunitaria:
# Casata Bolton: 1.00
#
# Coppie di casate con il numero massimo di connessioni inter-comunitarie:
# Tra Comunità Stark e Lannister: 24 collegamenti

# %% [markdown]
# Casata peggiore
#
# *La casata Greyjoy è connessa a tantissime casate, grazie a Theon che fa da bridge*

# %%
# Trova la casata con minore densità intra-comunitaria
min_density_house = min(resultsHouses.items(), key=lambda x: x[1]['intra_density'])

# Trova le casate con il numero minimo di connessioni inter-comunitarie
min_connections = min(inter_house_connections.values())
least_connected_houses = [pair for pair, count in inter_house_connections.items() if count == min_connections]

# Stampa i risultati
print("Casata con minore densità intra-comunitaria:")
print(f"Casata {min_density_house[0]}: {min_density_house[1]['intra_density']:.2f}")

print("\nCoppie di casate con il numero minimo di connessioni inter-comunitarie:")
for comm_u, comm_v in least_connected_houses:
    print(f"Tra Comunità {comm_u} e {comm_v}: {min_connections} collegamenti")
# Out:
# Casata con minore densità intra-comunitaria:
# Casata Jon-Snow: 0.00
#
# Coppie di casate con il numero minimo di connessioni inter-comunitarie:
# Tra Comunità Targaryen e Jon-Snow: 1 collegamenti
# Tra Comunità Targaryen e Tarly: 1 collegamenti
# Tra Comunità Frey e Greyjoy: 1 collegamenti
# Tra Comunità Targaryen e Selmy: 1 collegamenti
# Tra Comunità Selmy e Arryn: 1 collegamenti
# Tra Comunità Selmy e Martell: 1 collegamenti
# Tra Comunità Selmy e Clegane: 1 collegamenti
# Tra Comunità Tully e Greyjoy: 1 collegamenti
# Tra Comunità Targaryen e Tyrell: 1 collegamenti
# Tra Comunità Targaryen e Greyjoy: 1 collegamenti
# Tra Comunità Clegane e Tyrell: 1 collegamenti
# Tra Comunità Clegane e Martell: 1 collegamenti
# Tra Comunità Lannister e Bolton: 1 collegamenti
# Tra Comunità Lannister e Greyjoy: 1 collegamenti
# Tra Comunità Baratheon e Jon-Snow: 1 collegamenti
# Tra Comunità Baratheon e Cassel: 1 collegamenti
# Tra Comunità Jon-Snow e Tarly: 1 collegamenti
# Tra Comunità Jon-Snow e Greyjoy: 1 collegamenti
# Tra Comunità Jon-Snow e Lannister: 1 collegamenti
# Tra Comunità Lannister e Tarly: 1 collegamenti
# Tra Comunità Tyrell e Cassel: 1 collegamenti
# Tra Comunità Tyrell e Clegane: 1 collegamenti
# Tra Comunità Tyrell e Martell: 1 collegamenti
# Tra Comunità Baratheon e Arryn: 1 collegamenti
# Tra Comunità Martell e Stark: 1 collegamenti
# Tra Comunità Bolton e Stark: 1 collegamenti
# Tra Comunità Bolton e Cassel: 1 collegamenti
# Tra Comunità Baratheon e Targaryen: 1 collegamenti
# Tra Comunità Cassel e Bolton: 1 collegamenti
# Tra Comunità Cassel e Lannister: 1 collegamenti
# Tra Comunità Cassel e Frey: 1 collegamenti
# Tra Comunità Baratheon e Greyjoy: 1 collegamenti

# %%
# Trova le 5 casate con maggiore densità intra-comunitaria
top_5_density_houses = sorted(resultsHouses.items(), key=lambda x: x[1]['intra_density'], reverse=True)[:5]

# Trova le 5 coppie con il maggior numero di connessioni inter-comunitarie
top_5_connected_houses = sorted(inter_house_connections.items(), key=lambda x: x[1], reverse=True)[:5]

# Stampa i risultati
print("Top 5 casate con maggiore densità intra-comunitaria:")
for house, measures in top_5_density_houses:
    print(f"Casata {house}: {measures['intra_density']:.2f}")

print("\nTop 5 coppie di casate con il numero massimo di connessioni inter-comunitarie:")
for (comm_u, comm_v), count in top_5_connected_houses:
    print(f"Tra casa {comm_u} e casa {comm_v}: {count} collegamenti")

print()
print("Rimuoviamo le casate composte da 2 o 3 persone")
# Rimuoviamo outliers
houseFiltered = {} #defaultdict(int)
for h in houses:
  if h != 'Bolton' and h != 'Clegane' and h != 'Tarly' and h != 'Tully':
    houseFiltered[h] = resultsHouses[h]
top_5_density_houses = sorted(houseFiltered.items(), key=lambda x: x[1]['intra_density'], reverse=True)[:5]

# Stampa nuovi risultati
print("Top 5 casate con maggiore densità intra-comunitaria:")
for house, measures in top_5_density_houses:
    print(f"Casata {house}: {measures['intra_density']:.2f}")

# Questa o cambia
#print("\nTop 5 coppie di casate con il numero massimo di connessioni inter-comunitarie:")
#for (comm_u, comm_v), count in top_5_connected_houses:
#    print(f"Tra Comunità {comm_u} e {comm_v}: {count} collegamenti")
# Out:
# Top 5 casate con maggiore densità intra-comunitaria:
# Casata Bolton: 1.00
# Casata Clegane: 1.00
# Casata Tarly: 1.00
# Casata Tully: 1.00
# Casata Cassel: 0.67
#
# Top 5 coppie di casate con il numero massimo di connessioni inter-comunitarie:
# Tra casa Stark e casa Lannister: 24 collegamenti
# Tra casa Stark e casa Baratheon: 23 collegamenti
# Tra casa Stark e casa Frey: 15 collegamenti
# Tra casa Lannister e casa Baratheon: 14 collegamenti
# Tra casa Baratheon e casa Lannister: 13 collegamenti
#
# Rimuoviamo le casate composte da 2 o 3 persone
# Top 5 casate con maggiore densità intra-comunitaria:
# Casata Cassel: 0.67
# Casata Baratheon: 0.64
# Casata Greyjoy: 0.61
# Casata Stark: 0.50
# Casata Arryn: 0.40

# %%
# Trova le 5 casate con minore densità intra-comunitaria
bottom_5_density_houses = sorted(resultsHouses.items(), key=lambda x: x[1]['intra_density'])[:5]

# Trova le 5 coppie con il minor numero di connessioni inter-comunitarie
bottom_5_connected_houses = sorted(inter_house_connections.items(), key=lambda x: x[1])[:5]

# Stampa i risultati
print("Top 5 casate con minore densità intra-comunitaria:")
for house, measures in bottom_5_density_houses:
    print(f"Casata {house}: {measures['intra_density']:.2f}")

print("\nTop 5 coppie di casate con il numero minore di connessioni inter-comunitarie:")
for (comm_u, comm_v), count in bottom_5_connected_houses:
    print(f"Tra casa {comm_u} e casa {comm_v}: {count} collegamenti")
# Out:
# Top 5 casate con minore densità intra-comunitaria:
# Casata Jon-Snow: 0.00
# Casata Selmy: 0.00
# Casata Frey: 0.08
# Casata Targaryen: 0.10
# Casata Martell: 0.25
#
# Top 5 coppie di casate con il numero minore di connessioni inter-comunitarie:
# Tra casa Targaryen e casa Jon-Snow: 1 collegamenti
# Tra casa Targaryen e casa Tarly: 1 collegamenti
# Tra casa Frey e casa Greyjoy: 1 collegamenti
# Tra casa Targaryen e casa Selmy: 1 collegamenti
# Tra casa Selmy e casa Arryn: 1 collegamenti

# %% [markdown]
# ##**Determinazione del ruolo dei personaggi nelle comunità**
#
# Chi sono i personaggi più influenti o centrali all'interno di ciascuna comunità? Questo è fondamentale per comprendere chi guida o coordina le attività e le dinamiche interne di un gruppo.
#
#
# Metriche usate:
# * **Degree centrality intra-comunità**: Misura i nodi con il maggior numero di connessioni all'interno della comunità, individuando i leader locali.
# * **Betweenness centrality**: Individua i personaggi che collegano diverse comunità, facilitando l'interazione o la mediazione tra fazioni.

# %% [markdown]
# Degree identifica il numero di nodi a cui sono connesso, mentre l'authority è quante connessioni *importanti* ha il nodo.
# Chiedi a mila:
# - pagerank?
# - ha senso rianalizzare i valori delle authority tagliando il dataset, o comunque analizzando solo un sottoinsieme dei dati (da gephi)

# %%
# Dizionari per i risultati
leaders_by_degree = {}
mediators_by_betweenness = {}


# Calcola le metriche per ogni comunità
for community, nodes in resultsComunities.items():
    # Calcolo della degree centrality intra-comunità
    degree_centrality = resultsComunities[community]['degree_centrality']
    leader = max(degree_centrality.items(), key=lambda x: x[1])  # Nodo con massimo degree centrality
    leaders_by_degree[community] = leader

    # Calcolo della betweenness centrality (sull'intero grafo)
    betweenness_centrality = resultsComunities[community]['betweenness_centrality']
    mediator = max(betweenness_centrality.items(), key=lambda x: x[1])  # Nodo con massimo betweenness centrality
    mediators_by_betweenness[community] = mediator



# Stampa dei risultati
print("Leader locali (degree centrality):")
for community, (node, centrality) in leaders_by_degree.items():
    print(f"Comunità {community} - Authority: {resultsComunities[community]['Authority']} : Nodo {node} con centralità {centrality:.2f} ")

print("\nMediatori globali (betweenness centrality):")
for community, (node, centrality) in mediators_by_betweenness.items():
    print(f"Comunità {community}: Nodo {node} con centralità {centrality:.2f}")
# Out:
# Leader locali (degree centrality):
# Comunità 0 - Authority: Arya Stark : Nodo Arya-Stark con centralità 0.81
# Comunità 1 - Authority: Catelyn Stark : Nodo Theon-Greyjoy con centralità 0.41
# Comunità 2 - Authority: Stannis Baratheon : Nodo Stannis-Baratheon con centralità 0.53
# Comunità 3 - Authority: Unella : Nodo Moelle con centralità 1.00
# Comunità 4 - Authority: Alys Arryn : Nodo Alys-Arryn con centralità 1.00
# Comunità 5 - Authority: Gerold Hightower : Nodo Lewyn-Martell con centralità 0.67
# Comunità 6 - Authority: Barristan Selmy : Nodo Daenerys-Targaryen con centralità 0.66
# Comunità 7 - Authority: Balon Greyjoy : Nodo Victarion-Greyjoy con centralità 0.51
# Comunità 8 - Authority: Horas Redwyne : Nodo Hobber-Redwyne con centralità 1.00
# Comunità 9 - Authority: Jaime Lannister : Nodo Jaime-Lannister con centralità 0.60
# Comunità 10 - Authority: Tyrion Lannister : Nodo Tyrion-Lannister con centralità 0.43
# Comunità 11 - Authority: Jon Snow : Nodo Jon-Snow con centralità 0.73
# Comunità 12 - Authority: Florian the Fool : Nodo Florian-the-Fool con centralità 1.00
# Comunità 13 - Authority: Alla Tyrell : Nodo Alla-Tyrell con centralità 1.00
# Comunità 14 - Authority: Alleras : Nodo Pate-(novice) con centralità 0.70
# Comunità 15 - Authority: Myrcella Baratheon : Nodo Arianne-Martell con centralità 0.73
# Comunità 16 - Authority: Jon Connington : Nodo Aegon-Targaryen-(son-of-Rhaegar) con centralità 0.60
# Comunità 17 - Authority: Raynard : Nodo Raynard con centralità 1.00
# Comunità 18 - Authority: Waymar Royce : Nodo Gared con centralità 1.00
# Comunità 19 - Authority: Willem Lannister : Nodo Willem-Lannister con centralità 1.00
#
# Mediatori globali (betweenness centrality):
# Comunità 0: Nodo Arya-Stark con centralità 0.71
# Comunità 1: Nodo Theon-Greyjoy con centralità 0.45
# Comunità 2: Nodo Stannis-Baratheon con centralità 0.49
# Comunità 3: Nodo Moelle con centralità 0.00
# Comunità 4: Nodo Alys-Arryn con centralità 0.00
# Comunità 5: Nodo Arthur-Dayne con centralità 0.53
# Comunità 6: Nodo Daenerys-Targaryen con centralità 0.68
# Comunità 7: Nodo Victarion-Greyjoy con centralità 0.47
# Comunità 8: Nodo Hobber-Redwyne con centralità 0.00
# Comunità 9: Nodo Jaime-Lannister con centralità 0.77
# Comunità 10: Nodo Tyrion-Lannister con centralità 0.38
# Comunità 11: Nodo Jon-Snow con centralità 0.70
# Comunità 12: Nodo Florian-the-Fool con centralità 0.00
# Comunità 13: Nodo Alla-Tyrell con centralità 0.00
# Comunità 14: Nodo Pate-(novice) con centralità 0.65
# Comunità 15: Nodo Arianne-Martell con centralità 0.57
# Comunità 16: Nodo Jon-Connington con centralità 0.44
# Comunità 17: Nodo Raynard con centralità 0.00
# Comunità 18: Nodo Gared con centralità 0.00
# Comunità 19: Nodo Willem-Lannister con centralità 1.00

# %% [markdown]
# *Unella e Moelle sono due suore (quelle che rasano Cersei)*

# %% [markdown]
# ##**Esplorazione delle relazioni tra comunità**
# Come interagiscono le diverse comunità tra loro? Identificare le relazioni tra fazioni permette di analizzare alleanze, conflitti e legami deboli o forti tra i gruppi principali.
#
#
# Metriche usate:
# * **Edge weight tra comunità**: Calcola la somma dei pesi degli archi tra membri di comunità diverse per analizzare la forza delle connessioni inter-gruppo.
# * **Overlap tra nodi condivisi**: Misura il numero di personaggi che appartengono o interagiscono con più comunità, suggerendo possibili ponti tra gruppi rivali o alleati.

# %%
from collections import defaultdict

def analyze_community_interactions(G):
    # Dizionario per somma dei pesi degli archi tra comunità
    inter_community_weights = defaultdict(float)

    # Dizionario per il conteggio di nodi che interagiscono con più comunità
    overlapping_nodes = defaultdict(set)

    # Itera sugli archi per calcolare i pesi tra comunità
    for u, v, data in G.edges(data=True):
        # Ottieni le comunità dei nodi u e v
        community_u = G.nodes[u]['modularity']
        community_v = G.nodes[v]['modularity']

        # Se appartengono a comunità diverse, somma il peso
        if community_u != community_v:
            weight = data.get('weight', 1)  # Usa il peso dell'arco, default 1
            inter_community_weights[(community_u, community_v)] += weight

    # Identifica i nodi che interagiscono con più comunità
    for node in G.nodes():
        # Ottieni la comunità del nodo
        node_community = G.nodes[node]['modularity']
        # Cerca vicini appartenenti a comunità diverse
        connected_communities = set(G.nodes[neighbor]['modularity'] for neighbor in G.neighbors(node))
        if len(connected_communities) > 1:  # Se interagisce con più comunità
            overlapping_nodes[node] = connected_communities

    return inter_community_weights, overlapping_nodes

# G grafo complessivo
inter_weights, overlap_nodes = analyze_community_interactions(G)

# Stampa dei risultati
print("Pesi degli archi tra comunità:")
sorted_inter_weights = sorted(inter_weights.items(), key=lambda x: x[1], reverse=True)

for (comm_u, comm_v), weight in sorted_inter_weights:
    print(f"Tra Comunità {comm_u} e {comm_v}: peso totale {weight:.2f}")
    print(f"Comunità di {resultsComunities[comm_u]['Authority']} e di {resultsComunities[comm_v]['Authority']}")
    print("-")


print("\nNodi che interagiscono con più comunità:")
for node, communities in overlap_nodes.items():
    print(f"Nodo {node} interagisce con le comunità: ")
    for community in communities:  # Itera sulle singole comunità
        authority = resultsComunities[community]['Authority']  # Ottieni il valore di Authority
        print(f"  Comunità {community}: Authority {authority}")
# Out:
# Pesi degli archi tra comunità:
# Tra Comunità 1 e 10: peso totale 68.00
# Comunità di Catelyn Stark e di Tyrion Lannister
# -
# Tra Comunità 9 e 10: peso totale 55.00
# Comunità di Jaime Lannister e di Tyrion Lannister
# -
# Tra Comunità 0 e 10: peso totale 54.00
# Comunità di Arya Stark e di Tyrion Lannister
# -
# Tra Comunità 10 e 0: peso totale 42.00
# Comunità di Tyrion Lannister e di Arya Stark
# -
# Tra Comunità 10 e 1: peso totale 38.00
# Comunità di Tyrion Lannister e di Catelyn Stark
# -
# Tra Comunità 6 e 10: peso totale 36.00
# Comunità di Barristan Selmy e di Tyrion Lannister
# -
# Tra Comunità 1 e 9: peso totale 31.00
# Comunità di Catelyn Stark e di Jaime Lannister
# -
# Tra Comunità 10 e 2: peso totale 30.00
# Comunità di Tyrion Lannister e di Stannis Baratheon
# -
# Tra Comunità 11 e 2: peso totale 26.00
# Comunità di Jon Snow e di Stannis Baratheon
# -
# Tra Comunità 10 e 9: peso totale 21.00
# Comunità di Tyrion Lannister e di Jaime Lannister
# -
# Tra Comunità 15 e 10: peso totale 21.00
# Comunità di Myrcella Baratheon e di Tyrion Lannister
# -
# Tra Comunità 11 e 10: peso totale 20.00
# Comunità di Jon Snow e di Tyrion Lannister
# -
# Tra Comunità 0 e 1: peso totale 20.00
# Comunità di Arya Stark e di Catelyn Stark
# -
# Tra Comunità 2 e 10: peso totale 17.00
# Comunità di Stannis Baratheon e di Tyrion Lannister
# -
# Tra Comunità 11 e 1: peso totale 17.00
# Comunità di Jon Snow e di Catelyn Stark
# -
# Tra Comunità 9 e 1: peso totale 17.00
# Comunità di Jaime Lannister e di Catelyn Stark
# -
# Tra Comunità 1 e 2: peso totale 16.00
# Comunità di Catelyn Stark e di Stannis Baratheon
# -
# Tra Comunità 0 e 9: peso totale 15.00
# Comunità di Arya Stark e di Jaime Lannister
# -
# Tra Comunità 16 e 10: peso totale 14.00
# Comunità di Jon Connington e di Tyrion Lannister
# -
# Tra Comunità 7 e 1: peso totale 14.00
# Comunità di Balon Greyjoy e di Catelyn Stark
# -
# Tra Comunità 2 e 11: peso totale 14.00
# Comunità di Stannis Baratheon e di Jon Snow
# -
# Tra Comunità 10 e 11: peso totale 10.00
# Comunità di Tyrion Lannister e di Jon Snow
# -
# Tra Comunità 10 e 6: peso totale 9.00
# Comunità di Tyrion Lannister e di Barristan Selmy
# -
# Tra Comunità 9 e 0: peso totale 9.00
# Comunità di Jaime Lannister e di Arya Stark
# -
# Tra Comunità 2 e 1: peso totale 8.00
# Comunità di Stannis Baratheon e di Catelyn Stark
# -
# Tra Comunità 1 e 11: peso totale 8.00
# Comunità di Catelyn Stark e di Jon Snow
# -
# Tra Comunità 13 e 10: peso totale 7.00
# Comunità di Alla Tyrell e di Tyrion Lannister
# -
# Tra Comunità 7 e 2: peso totale 7.00
# Comunità di Balon Greyjoy e di Stannis Baratheon
# -
# Tra Comunità 0 e 11: peso totale 7.00
# Comunità di Arya Stark e di Jon Snow
# -
# Tra Comunità 10 e 15: peso totale 7.00
# Comunità di Tyrion Lannister e di Myrcella Baratheon
# -
# Tra Comunità 16 e 6: peso totale 5.00
# Comunità di Jon Connington e di Barristan Selmy
# -
# Tra Comunità 7 e 10: peso totale 5.00
# Comunità di Balon Greyjoy e di Tyrion Lannister
# -
# Tra Comunità 1 e 0: peso totale 5.00
# Comunità di Catelyn Stark e di Arya Stark
# -
# Tra Comunità 9 e 2: peso totale 5.00
# Comunità di Jaime Lannister e di Stannis Baratheon
# -
# Tra Comunità 11 e 0: peso totale 4.00
# Comunità di Jon Snow e di Arya Stark
# -
# Tra Comunità 10 e 3: peso totale 4.00
# Comunità di Tyrion Lannister e di Unella
# -
# Tra Comunità 6 e 16: peso totale 4.00
# Comunità di Barristan Selmy e di Jon Connington
# -
# Tra Comunità 6 e 0: peso totale 3.00
# Comunità di Barristan Selmy e di Arya Stark
# -
# Tra Comunità 10 e 5: peso totale 3.00
# Comunità di Tyrion Lannister e di Gerold Hightower
# -
# Tra Comunità 14 e 11: peso totale 3.00
# Comunità di Alleras e di Jon Snow
# -
# Tra Comunità 15 e 6: peso totale 3.00
# Comunità di Myrcella Baratheon e di Barristan Selmy
# -
# Tra Comunità 15 e 0: peso totale 3.00
# Comunità di Myrcella Baratheon e di Arya Stark
# -
# Tra Comunità 11 e 6: peso totale 2.00
# Comunità di Jon Snow e di Barristan Selmy
# -
# Tra Comunità 2 e 0: peso totale 2.00
# Comunità di Stannis Baratheon e di Arya Stark
# -
# Tra Comunità 2 e 7: peso totale 2.00
# Comunità di Stannis Baratheon e di Balon Greyjoy
# -
# Tra Comunità 5 e 10: peso totale 2.00
# Comunità di Gerold Hightower e di Tyrion Lannister
# -
# Tra Comunità 0 e 2: peso totale 2.00
# Comunità di Arya Stark e di Stannis Baratheon
# -
# Tra Comunità 0 e 15: peso totale 2.00
# Comunità di Arya Stark e di Myrcella Baratheon
# -
# Tra Comunità 6 e 15: peso totale 2.00
# Comunità di Barristan Selmy e di Myrcella Baratheon
# -
# Tra Comunità 6 e 7: peso totale 2.00
# Comunità di Barristan Selmy e di Balon Greyjoy
# -
# Tra Comunità 2 e 9: peso totale 2.00
# Comunità di Stannis Baratheon e di Jaime Lannister
# -
# Tra Comunità 9 e 11: peso totale 2.00
# Comunità di Jaime Lannister e di Jon Snow
# -
# Tra Comunità 10 e 16: peso totale 2.00
# Comunità di Tyrion Lannister e di Jon Connington
# -
# Tra Comunità 6 e 1: peso totale 1.00
# Comunità di Barristan Selmy e di Catelyn Stark
# -
# Tra Comunità 6 e 2: peso totale 1.00
# Comunità di Barristan Selmy e di Stannis Baratheon
# -
# Tra Comunità 11 e 14: peso totale 1.00
# Comunità di Jon Snow e di Alleras
# -
# Tra Comunità 4 e 10: peso totale 1.00
# Comunità di Alys Arryn e di Tyrion Lannister
# -
# Tra Comunità 7 e 11: peso totale 1.00
# Comunità di Balon Greyjoy e di Jon Snow
# -
# Tra Comunità 6 e 5: peso totale 1.00
# Comunità di Barristan Selmy e di Gerold Hightower
# -
# Tra Comunità 6 e 9: peso totale 1.00
# Comunità di Barristan Selmy e di Jaime Lannister
# -
# Tra Comunità 16 e 7: peso totale 1.00
# Comunità di Jon Connington e di Balon Greyjoy
# -
# Tra Comunità 11 e 18: peso totale 1.00
# Comunità di Jon Snow e di Waymar Royce
# -
# Tra Comunità 10 e 17: peso totale 1.00
# Comunità di Tyrion Lannister e di Raynard
# -
# Tra Comunità 12 e 10: peso totale 1.00
# Comunità di Florian the Fool e di Tyrion Lannister
# -
# Tra Comunità 18 e 11: peso totale 1.00
# Comunità di Waymar Royce e di Jon Snow
# -
# Tra Comunità 5 e 9: peso totale 1.00
# Comunità di Gerold Hightower e di Jaime Lannister
# -
# Tra Comunità 8 e 10: peso totale 1.00
# Comunità di Horas Redwyne e di Tyrion Lannister
# -
# Tra Comunità 10 e 19: peso totale 1.00
# Comunità di Tyrion Lannister e di Willem Lannister
# -
# Tra Comunità 10 e 13: peso totale 1.00
# Comunità di Tyrion Lannister e di Alla Tyrell
# -
# Tra Comunità 19 e 10: peso totale 1.00
# Comunità di Willem Lannister e di Tyrion Lannister
# -
# Tra Comunità 15 e 1: peso totale 1.00
# Comunità di Myrcella Baratheon e di Catelyn Stark
# -
# Tra Comunità 15 e 2: peso totale 1.00
# Comunità di Myrcella Baratheon e di Stannis Baratheon
# -
# Tra Comunità 1 e 19: peso totale 1.00
# Comunità di Catelyn Stark e di Willem Lannister
# -
# Tra Comunità 1 e 7: peso totale 1.00
# Comunità di Catelyn Stark e di Balon Greyjoy
# -
#
# Nodi che interagiscono con più comunità:
# Nodo Addam-Marbrand interagisce con le comunità:
#   Comunità 1: Authority Catelyn Stark
#   Comunità 10: Authority Tyrion Lannister
#   Comunità 9: Authority Jaime Lannister
# Nodo Aegon-I-Targaryen interagisce con le comunità:
#   Comunità 0: Authority Arya Stark
#   Comunità 1: Authority Catelyn Stark
#   Comunità 2: Authority Stannis Baratheon
#   Comunità 6: Authority Barristan Selmy
#   Comunità 10: Authority Tyrion Lannister
# Nodo Aegon-Targaryen-(son-of-Rhaegar) interagisce con le comunità:
#   Comunità 16: Authority Jon Connington
#   Comunità 10: Authority Tyrion Lannister
#   Comunità 6: Authority Barristan Selmy
# Nodo Aemon-Targaryen-(Maester-Aemon) interagisce con le comunità:
#   Comunità 2: Authority Stannis Baratheon
#   Comunità 6: Authority Barristan Selmy
#   Comunità 10: Authority Tyrion Lannister
#   Comunità 11: Authority Jon Snow
#   Comunità 14: Authority Alleras
# Nodo Aenys-Frey interagisce con le comunità:
#   Comunità 0: Authority Arya Stark
#   Comunità 1: Authority Catelyn Stark
#   Comunità 2: Authority Stannis Baratheon
# Nodo Aeron-Greyjoy interagisce con le comunità:
#   Comunità 1: Authority Catelyn Stark
#   Comunità 7: Authority Balon Greyjoy
# Nodo Aerys-II-Targaryen interagisce con le comunità:
#   Comunità 9: Authority Jaime Lannister
#   Comunità 10: Authority Tyrion Lannister
#   Comunità 5: Authority Gerold Hightower
#   Comunità 6: Authority Barristan Selmy
# Nodo Alester-Florent interagisce con le comunità:
#   Comunità 2: Authority Stannis Baratheon
#   Comunità 10: Authority Tyrion Lannister
# Nodo Alla-Tyrell interagisce con le comunità:
#   Comunità 10: Authority Tyrion Lannister
#   Comunità 13: Authority Alla Tyrell
# Nodo Allar-Deem interagisce con le comunità:
#   Comunità 10: Authority Tyrion Lannister
#   Comunità 11: Authority Jon Snow
# Nodo Alleras interagisce con le comunità:
#   Comunità 11: Authority Jon Snow
#   Comunità 14: Authority Alleras
# Nodo Alliser-Thorne interagisce con le comunità:
#   Comunità 2: Authority Stannis Baratheon
#   Comunità 10: Authority Tyrion Lannister
#   Comunità 11: Authority Jon Snow
# Nodo Alyn interagisce con le comunità:
#   Comunità 0: Authority Arya Stark
#   Comunità 10: Authority Tyrion Lannister
# Nodo Alys-Arryn interagisce con le comunità:
#   Comunità 10: Authority Tyrion Lannister
#   Comunità 4: Authority Alys Arryn
# Nodo Alys-Karstark interagisce con le comunità:
#   Comunità 2: Authority Stannis Baratheon
#   Comunità 11: Authority Jon Snow
# Nodo Alysane-Mormont interagisce con le comunità:
#   Comunità 2: Authority Stannis Baratheon
#   Comunità 7: Authority Balon Greyjoy
# Nodo Amerei-Frey interagisce con le comunità:
#   Comunità 9: Authority Jaime Lannister
#   Comunità 10: Authority Tyrion Lannister
# Nodo Amory-Lorch interagisce con le comunità:
#   Comunità 0: Authority Arya Stark
#   Comunità 9: Authority Jaime Lannister
#   Comunità 10: Authority Tyrion Lannister
#   Comunità 1: Authority Catelyn Stark
# Nodo Anders-Yronwood interagisce con le comunità:
#   Comunità 10: Authority Tyrion Lannister
#   Comunità 6: Authority Barristan Selmy
# Nodo Areo-Hotah interagisce con le comunità:
#   Comunità 10: Authority Tyrion Lannister
#   Comunità 15: Authority Myrcella Baratheon
# Nodo Arianne-Martell interagisce con le comunità:
#   Comunità 10: Authority Tyrion Lannister
#   Comunità 6: Authority Barristan Selmy
#   Comunità 15: Authority Myrcella Baratheon
# Nodo Arnolf-Karstark interagisce con le comunità:
#   Comunità 1: Authority Catelyn Stark
#   Comunità 2: Authority Stannis Baratheon
#   Comunità 7: Authority Balon Greyjoy
# Nodo Arstan interagisce con le comunità:
#   Comunità 10: Authority Tyrion Lannister
#   Comunità 6: Authority Barristan Selmy
# Nodo Arthur-Dayne interagisce con le comunità:
#   Comunità 10: Authority Tyrion Lannister
#   Comunità 5: Authority Gerold Hightower
# Nodo Arya-Stark interagisce con le comunità:
#   Comunità 0: Authority Arya Stark
#   Comunità 1: Authority Catelyn Stark
#   Comunità 2: Authority Stannis Baratheon
#   Comunità 9: Authority Jaime Lannister
#   Comunità 10: Authority Tyrion Lannister
#   Comunità 11: Authority Jon Snow
#   Comunità 15: Authority Myrcella Baratheon
# Nodo Arys-Oakheart interagisce con le comunità:
#   Comunità 10: Authority Tyrion Lannister
#   Comunità 15: Authority Myrcella Baratheon
# Nodo Asha-Greyjoy interagisce con le comunità:
#   Comunità 1: Authority Catelyn Stark
#   Comunità 2: Authority Stannis Baratheon
#   Comunità 7: Authority Balon Greyjoy
#   Comunità 10: Authority Tyrion Lannister
#   Comunità 11: Authority Jon Snow
# Nodo Aurane-Waters interagisce con le comunità:
#   Comunità 10: Authority Tyrion Lannister
#   Comunità 2: Authority Stannis Baratheon
# Nodo Axell-Florent interagisce con le comunità:
#   Comunità 2: Authority Stannis Baratheon
#   Comunità 11: Authority Jon Snow
# Nodo Ballabar interagisce con le comunità:
#   Comunità 9: Authority Jaime Lannister
#   Comunità 10: Authority Tyrion Lannister
# Nodo Balon-Greyjoy interagisce con le comunità:
#   Comunità 1: Authority Catelyn Stark
#   Comunità 10: Authority Tyrion Lannister
#   Comunità 2: Authority Stannis Baratheon
#   Comunità 7: Authority Balon Greyjoy
# Nodo Balon-Swann interagisce con le comunità:
#   Comunità 0: Authority Arya Stark
#   Comunità 9: Authority Jaime Lannister
#   Comunità 10: Authority Tyrion Lannister
#   Comunità 15: Authority Myrcella Baratheon
# Nodo Barbrey-Dustin interagisce con le comunità:
#   Comunità 1: Authority Catelyn Stark
#   Comunità 2: Authority Stannis Baratheon
# Nodo Barristan-Selmy interagisce con le comunità:
#   Comunità 0: Authority Arya Stark
#   Comunità 5: Authority Gerold Hightower
#   Comunità 6: Authority Barristan Selmy
#   Comunità 9: Authority Jaime Lannister
#   Comunità 10: Authority Tyrion Lannister
# Nodo Ben-Plumm interagisce con le comunità:
#   Comunità 10: Authority Tyrion Lannister
#   Comunità 6: Authority Barristan Selmy
# Nodo Benerro interagisce con le comunità:
#   Comunità 16: Authority Jon Connington
#   Comunità 10: Authority Tyrion Lannister
#   Comunità 6: Authority Barristan Selmy
#   Comunità 7: Authority Balon Greyjoy
# Nodo Benfred-Tallhart interagisce con le comunità:
#   Comunità 1: Authority Catelyn Stark
#   Comunità 2: Authority Stannis Baratheon
# Nodo Benjen-Stark interagisce con le comunità:
#   Comunità 0: Authority Arya Stark
#   Comunità 1: Authority Catelyn Stark
#   Comunità 10: Authority Tyrion Lannister
#   Comunità 11: Authority Jon Snow
#   Comunità 18: Authority Waymar Royce
# Nodo Beric-Dondarrion interagisce con le comunità:
#   Comunità 0: Authority Arya Stark
#   Comunità 1: Authority Catelyn Stark
#   Comunità 10: Authority Tyrion Lannister
#   Comunità 9: Authority Jaime Lannister
# Nodo Biter interagisce con le comunità:
#   Comunità 0: Authority Arya Stark
#   Comunità 9: Authority Jaime Lannister
# Nodo Boros-Blount interagisce con le comunità:
#   Comunità 0: Authority Arya Stark
#   Comunità 9: Authority Jaime Lannister
#   Comunità 10: Authority Tyrion Lannister
#   Comunità 6: Authority Barristan Selmy
# Nodo Bowen-Marsh interagisce con le comunità:
#   Comunità 2: Authority Stannis Baratheon
#   Comunità 11: Authority Jon Snow
# Nodo Bran-Stark interagisce con le comunità:
#   Comunità 0: Authority Arya Stark
#   Comunità 1: Authority Catelyn Stark
#   Comunità 2: Authority Stannis Baratheon
#   Comunità 10: Authority Tyrion Lannister
#   Comunità 11: Authority Jon Snow
# Nodo Brandon-Stark interagisce con le comunità:
#   Comunità 1: Authority Catelyn Stark
#   Comunità 10: Authority Tyrion Lannister
# Nodo Brienne-of-Tarth interagisce con le comunità:
#   Comunità 0: Authority Arya Stark
#   Comunità 1: Authority Catelyn Stark
#   Comunità 2: Authority Stannis Baratheon
#   Comunità 9: Authority Jaime Lannister
#   Comunità 10: Authority Tyrion Lannister
# Nodo Bronn interagisce con le comunità:
#   Comunità 0: Authority Arya Stark
#   Comunità 1: Authority Catelyn Stark
#   Comunità 2: Authority Stannis Baratheon
#   Comunità 9: Authority Jaime Lannister
#   Comunità 10: Authority Tyrion Lannister
# Nodo Bryce-Caron interagisce con le comunità:
#   Comunità 2: Authority Stannis Baratheon
#   Comunità 10: Authority Tyrion Lannister
# Nodo Brynden-Tully interagisce con le comunità:
#   Comunità 0: Authority Arya Stark
#   Comunità 1: Authority Catelyn Stark
#   Comunità 10: Authority Tyrion Lannister
#   Comunità 9: Authority Jaime Lannister
# Nodo Caleotte interagisce con le comunità:
#   Comunità 0: Authority Arya Stark
#   Comunità 15: Authority Myrcella Baratheon
# Nodo Catelyn-Stark interagisce con le comunità:
#   Comunità 0: Authority Arya Stark
#   Comunità 1: Authority Catelyn Stark
#   Comunità 2: Authority Stannis Baratheon
#   Comunità 7: Authority Balon Greyjoy
#   Comunità 9: Authority Jaime Lannister
#   Comunità 10: Authority Tyrion Lannister
#   Comunità 11: Authority Jon Snow
# Nodo Cersei-Lannister interagisce con le comunità:
#   Comunità 0: Authority Arya Stark
#   Comunità 1: Authority Catelyn Stark
#   Comunità 2: Authority Stannis Baratheon
#   Comunità 3: Authority Unella
#   Comunità 6: Authority Barristan Selmy
#   Comunità 9: Authority Jaime Lannister
#   Comunità 10: Authority Tyrion Lannister
#   Comunità 11: Authority Jon Snow
#   Comunità 15: Authority Myrcella Baratheon
#   Comunità 17: Authority Raynard
# Nodo Chiggen interagisce con le comunità:
#   Comunità 1: Authority Catelyn Stark
#   Comunità 10: Authority Tyrion Lannister
# Nodo Chiswyck interagisce con le comunità:
#   Comunità 0: Authority Arya Stark
#   Comunità 10: Authority Tyrion Lannister
# Nodo Clayton-Suggs interagisce con le comunità:
#   Comunità 2: Authority Stannis Baratheon
#   Comunità 7: Authority Balon Greyjoy
# Nodo Clement-Piper interagisce con le comunità:
#   Comunità 9: Authority Jaime Lannister
#   Comunità 1: Authority Catelyn Stark
# Nodo Cleos-Frey interagisce con le comunità:
#   Comunità 9: Authority Jaime Lannister
#   Comunità 10: Authority Tyrion Lannister
#   Comunità 1: Authority Catelyn Stark
# Nodo Clydas interagisce con le comunità:
#   Comunità 2: Authority Stannis Baratheon
#   Comunità 11: Authority Jon Snow
# Nodo Coldhands interagisce con le comunità:
#   Comunità 1: Authority Catelyn Stark
#   Comunità 11: Authority Jon Snow
# Nodo Colemon interagisce con le comunità:
#   Comunità 1: Authority Catelyn Stark
#   Comunità 10: Authority Tyrion Lannister
# Nodo Colen-of-Greenpools interagisce con le comunità:
#   Comunità 1: Authority Catelyn Stark
#   Comunità 10: Authority Tyrion Lannister
# Nodo Cortnay-Penrose interagisce con le comunità:
#   Comunità 2: Authority Stannis Baratheon
#   Comunità 10: Authority Tyrion Lannister
# Nodo Cotter-Pyke interagisce con le comunità:
#   Comunità 2: Authority Stannis Baratheon
#   Comunità 11: Authority Jon Snow
# Nodo Craster interagisce con le comunità:
#   Comunità 1: Authority Catelyn Stark
#   Comunità 11: Authority Jon Snow
# Nodo Cressen interagisce con le comunità:
#   Comunità 2: Authority Stannis Baratheon
#   Comunità 10: Authority Tyrion Lannister
# Nodo Daemon-Sand interagisce con le comunità:
#   Comunità 10: Authority Tyrion Lannister
#   Comunità 15: Authority Myrcella Baratheon
# Nodo Daenerys-Targaryen interagisce con le comunità:
#   Comunità 6: Authority Barristan Selmy
#   Comunità 7: Authority Balon Greyjoy
#   Comunità 10: Authority Tyrion Lannister
#   Comunità 15: Authority Myrcella Baratheon
#   Comunità 16: Authority Jon Connington
# Nodo Daeron-II-Targaryen interagisce con le comunità:
#   Comunità 11: Authority Jon Snow
#   Comunità 6: Authority Barristan Selmy
# Nodo Dagmer interagisce con le comunità:
#   Comunità 1: Authority Catelyn Stark
#   Comunità 7: Authority Balon Greyjoy
# Nodo Dalla interagisce con le comunità:
#   Comunità 2: Authority Stannis Baratheon
#   Comunità 11: Authority Jon Snow
# Nodo Danwell-Frey interagisce con le comunità:
#   Comunità 1: Authority Catelyn Stark
#   Comunità 2: Authority Stannis Baratheon
# Nodo Dareon interagisce con le comunità:
#   Comunità 0: Authority Arya Stark
#   Comunità 11: Authority Jon Snow
# Nodo Daven-Lannister interagisce con le comunità:
#   Comunità 1: Authority Catelyn Stark
#   Comunità 9: Authority Jaime Lannister
# Nodo Davos-Seaworth interagisce con le comunità:
#   Comunità 1: Authority Catelyn Stark
#   Comunità 2: Authority Stannis Baratheon
#   Comunità 10: Authority Tyrion Lannister
# Nodo Desmond interagisce con le comunità:
#   Comunità 0: Authority Arya Stark
#   Comunità 10: Authority Tyrion Lannister
# Nodo Devan-Seaworth interagisce con le comunità:
#   Comunità 10: Authority Tyrion Lannister
#   Comunità 2: Authority Stannis Baratheon
#   Comunità 11: Authority Jon Snow
# Nodo Dick-Crabb interagisce con le comunità:
#   Comunità 9: Authority Jaime Lannister
#   Comunità 10: Authority Tyrion Lannister
# Nodo Donal-Noye interagisce con le comunità:
#   Comunità 2: Authority Stannis Baratheon
#   Comunità 11: Authority Jon Snow
# Nodo Donella-Hornwood interagisce con le comunità:
#   Comunità 1: Authority Catelyn Stark
#   Comunità 2: Authority Stannis Baratheon
# Nodo Dontos-Hollard interagisce con le comunità:
#   Comunità 9: Authority Jaime Lannister
#   Comunità 10: Authority Tyrion Lannister
#   Comunità 2: Authority Stannis Baratheon
# Nodo Doran-Martell interagisce con le comunità:
#   Comunità 0: Authority Arya Stark
#   Comunità 10: Authority Tyrion Lannister
#   Comunità 6: Authority Barristan Selmy
#   Comunità 15: Authority Myrcella Baratheon
# Nodo Drogo interagisce con le comunità:
#   Comunità 10: Authority Tyrion Lannister
#   Comunità 6: Authority Barristan Selmy
# Nodo Dunsen interagisce con le comunità:
#   Comunità 0: Authority Arya Stark
#   Comunità 10: Authority Tyrion Lannister
# Nodo Eddard-Stark interagisce con le comunità:
#   Comunità 0: Authority Arya Stark
#   Comunità 1: Authority Catelyn Stark
#   Comunità 2: Authority Stannis Baratheon
#   Comunità 5: Authority Gerold Hightower
#   Comunità 6: Authority Barristan Selmy
#   Comunità 7: Authority Balon Greyjoy
#   Comunità 9: Authority Jaime Lannister
#   Comunità 10: Authority Tyrion Lannister
#   Comunità 11: Authority Jon Snow
# Nodo Edmure-Tully interagisce con le comunità:
#   Comunità 0: Authority Arya Stark
#   Comunità 9: Authority Jaime Lannister
#   Comunità 10: Authority Tyrion Lannister
#   Comunità 1: Authority Catelyn Stark
# Nodo Edric-Storm interagisce con le comunità:
#   Comunità 2: Authority Stannis Baratheon
#   Comunità 10: Authority Tyrion Lannister
# Nodo Edwyn-Frey interagisce con le comunità:
#   Comunità 1: Authority Catelyn Stark
#   Comunità 9: Authority Jaime Lannister
# Nodo Elia-Martell interagisce con le comunità:
#   Comunità 16: Authority Jon Connington
#   Comunità 0: Authority Arya Stark
#   Comunità 10: Authority Tyrion Lannister
#   Comunità 9: Authority Jaime Lannister
# Nodo Elinor-Tyrell interagisce con le comunità:
#   Comunità 10: Authority Tyrion Lannister
#   Comunità 13: Authority Alla Tyrell
# Nodo Ellaria-Sand interagisce con le comunità:
#   Comunità 10: Authority Tyrion Lannister
#   Comunità 15: Authority Myrcella Baratheon
# Nodo Elmar-Frey interagisce con le comunità:
#   Comunità 0: Authority Arya Stark
#   Comunità 9: Authority Jaime Lannister
#   Comunità 10: Authority Tyrion Lannister
#   Comunità 1: Authority Catelyn Stark
# Nodo Emmon-Cuy interagisce con le comunità:
#   Comunità 9: Authority Jaime Lannister
#   Comunità 10: Authority Tyrion Lannister
# Nodo Emmon-Frey interagisce con le comunità:
#   Comunità 1: Authority Catelyn Stark
#   Comunità 10: Authority Tyrion Lannister
#   Comunità 9: Authority Jaime Lannister
# Nodo Eon-Hunter interagisce con le comunità:
#   Comunità 1: Authority Catelyn Stark
#   Comunità 10: Authority Tyrion Lannister
# Nodo Euron-Greyjoy interagisce con le comunità:
#   Comunità 1: Authority Catelyn Stark
#   Comunità 7: Authority Balon Greyjoy
# Nodo Florian-the-Fool interagisce con le comunità:
#   Comunità 10: Authority Tyrion Lannister
#   Comunità 12: Authority Florian the Fool
# Nodo Forley-Prester interagisce con le comunità:
#   Comunità 1: Authority Catelyn Stark
#   Comunità 9: Authority Jaime Lannister
# Nodo Galbart-Glover interagisce con le comunità:
#   Comunità 1: Authority Catelyn Stark
#   Comunità 2: Authority Stannis Baratheon
#   Comunità 7: Authority Balon Greyjoy
#   Comunità 9: Authority Jaime Lannister
#   Comunità 10: Authority Tyrion Lannister
# Nodo Gared interagisce con le comunità:
#   Comunità 18: Authority Waymar Royce
#   Comunità 11: Authority Jon Snow
# Nodo Garth-Greyfeather interagisce con le comunità:
#   Comunità 0: Authority Arya Stark
#   Comunità 11: Authority Jon Snow
# Nodo Gawen-Westerling interagisce con le comunità:
#   Comunità 1: Authority Catelyn Stark
#   Comunità 2: Authority Stannis Baratheon
# Nodo Gendry interagisce con le comunità:
#   Comunità 0: Authority Arya Stark
#   Comunità 9: Authority Jaime Lannister
#   Comunità 10: Authority Tyrion Lannister
# Nodo Genna-Lannister interagisce con le comunità:
#   Comunità 9: Authority Jaime Lannister
#   Comunità 10: Authority Tyrion Lannister
# Nodo Gerold-Dayne interagisce con le comunità:
#   Comunità 10: Authority Tyrion Lannister
#   Comunità 15: Authority Myrcella Baratheon
# Nodo Gerold-Hightower interagisce con le comunità:
#   Comunità 9: Authority Jaime Lannister
#   Comunità 10: Authority Tyrion Lannister
#   Comunità 5: Authority Gerold Hightower
#   Comunità 6: Authority Barristan Selmy
# Nodo Gilly interagisce con le comunità:
#   Comunità 1: Authority Catelyn Stark
#   Comunità 2: Authority Stannis Baratheon
#   Comunità 11: Authority Jon Snow
# Nodo Godry-Farring interagisce con le comunità:
#   Comunità 2: Authority Stannis Baratheon
#   Comunità 11: Authority Jon Snow
#   Comunità 7: Authority Balon Greyjoy
# Nodo Gregor-Clegane interagisce con le comunità:
#   Comunità 0: Authority Arya Stark
#   Comunità 1: Authority Catelyn Stark
#   Comunità 2: Authority Stannis Baratheon
#   Comunità 9: Authority Jaime Lannister
#   Comunità 10: Authority Tyrion Lannister
#   Comunità 15: Authority Myrcella Baratheon
# Nodo Grimtongue interagisce con le comunità:
#   Comunità 1: Authority Catelyn Stark
#   Comunità 7: Authority Balon Greyjoy
# Nodo Hagen interagisce con le comunità:
#   Comunità 1: Authority Catelyn Stark
#   Comunità 7: Authority Balon Greyjoy
# Nodo Hairy-Hal interagisce con le comunità:
#   Comunità 0: Authority Arya Stark
#   Comunità 11: Authority Jon Snow
# Nodo Haldon interagisce con le comunità:
#   Comunità 16: Authority Jon Connington
#   Comunità 10: Authority Tyrion Lannister
#   Comunità 6: Authority Barristan Selmy
# Nodo Harren-Hoare interagisce con le comunità:
#   Comunità 0: Authority Arya Stark
#   Comunità 1: Authority Catelyn Stark
#   Comunità 6: Authority Barristan Selmy
# Nodo Harwin interagisce con le comunità:
#   Comunità 0: Authority Arya Stark
#   Comunità 1: Authority Catelyn Stark
#   Comunità 10: Authority Tyrion Lannister
# Nodo Harys-Swyft interagisce con le comunità:
#   Comunità 9: Authority Jaime Lannister
#   Comunità 10: Authority Tyrion Lannister
#   Comunità 2: Authority Stannis Baratheon
# Nodo Helman-Tallhart interagisce con le comunità:
#   Comunità 0: Authority Arya Stark
#   Comunità 1: Authority Catelyn Stark
#   Comunità 2: Authority Stannis Baratheon
#   Comunità 9: Authority Jaime Lannister
# Nodo High-Sparrow interagisce con le comunità:
#   Comunità 10: Authority Tyrion Lannister
#   Comunità 3: Authority Unella
# Nodo Hobb interagisce con le comunità:
#   Comunità 2: Authority Stannis Baratheon
#   Comunità 11: Authority Jon Snow
# Nodo Hodor interagisce con le comunità:
#   Comunità 1: Authority Catelyn Stark
#   Comunità 2: Authority Stannis Baratheon
# Nodo Horas-Redwyne interagisce con le comunità:
#   Comunità 8: Authority Horas Redwyne
#   Comunità 10: Authority Tyrion Lannister
# Nodo Hoster-Tully interagisce con le comunità:
#   Comunità 1: Authority Catelyn Stark
#   Comunità 10: Authority Tyrion Lannister
#   Comunità 9: Authority Jaime Lannister
# Nodo Hother-Umber interagisce con le comunità:
#   Comunità 1: Authority Catelyn Stark
#   Comunità 2: Authority Stannis Baratheon
# Nodo Howland-Reed interagisce con le comunità:
#   Comunità 1: Authority Catelyn Stark
#   Comunità 10: Authority Tyrion Lannister
# Nodo Hullen interagisce con le comunità:
#   Comunità 0: Authority Arya Stark
#   Comunità 1: Authority Catelyn Stark
#   Comunità 10: Authority Tyrion Lannister
# Nodo Hyle-Hunt interagisce con le comunità:
#   Comunità 0: Authority Arya Stark
#   Comunità 9: Authority Jaime Lannister
#   Comunità 10: Authority Tyrion Lannister
#   Comunità 1: Authority Catelyn Stark
# Nodo Illyrio-Mopatis interagisce con le comunità:
#   Comunità 16: Authority Jon Connington
#   Comunità 10: Authority Tyrion Lannister
#   Comunità 6: Authority Barristan Selmy
# Nodo Ilyn-Payne interagisce con le comunità:
#   Comunità 0: Authority Arya Stark
#   Comunità 1: Authority Catelyn Stark
#   Comunità 10: Authority Tyrion Lannister
#   Comunità 9: Authority Jaime Lannister
# Nodo Jacelyn-Bywater interagisce con le comunità:
#   Comunità 10: Authority Tyrion Lannister
#   Comunità 11: Authority Jon Snow
# Nodo Jack-Bulwer interagisce con le comunità:
#   Comunità 0: Authority Arya Stark
#   Comunità 11: Authority Jon Snow
# Nodo Jaime-Lannister interagisce con le comunità:
#   Comunità 0: Authority Arya Stark
#   Comunità 1: Authority Catelyn Stark
#   Comunità 2: Authority Stannis Baratheon
#   Comunità 5: Authority Gerold Hightower
#   Comunità 6: Authority Barristan Selmy
#   Comunità 9: Authority Jaime Lannister
#   Comunità 10: Authority Tyrion Lannister
#   Comunità 11: Authority Jon Snow
# Nodo Janos-Slynt interagisce con le comunità:
#   Comunità 2: Authority Stannis Baratheon
#   Comunità 10: Authority Tyrion Lannister
#   Comunità 11: Authority Jon Snow
# Nodo Jason-Mallister interagisce con le comunità:
#   Comunità 1: Authority Catelyn Stark
#   Comunità 9: Authority Jaime Lannister
# Nodo Jeor-Mormont interagisce con le comunità:
#   Comunità 0: Authority Arya Stark
#   Comunità 1: Authority Catelyn Stark
#   Comunità 6: Authority Barristan Selmy
#   Comunità 10: Authority Tyrion Lannister
#   Comunità 11: Authority Jon Snow
#   Comunità 18: Authority Waymar Royce
# Nodo Jeyne-Poole interagisce con le comunità:
#   Comunità 0: Authority Arya Stark
#   Comunità 1: Authority Catelyn Stark
#   Comunità 10: Authority Tyrion Lannister
# Nodo Jeyne-Westerling interagisce con le comunità:
#   Comunità 1: Authority Catelyn Stark
#   Comunità 2: Authority Stannis Baratheon
# Nodo Joffrey-Baratheon interagisce con le comunità:
#   Comunità 0: Authority Arya Stark
#   Comunità 1: Authority Catelyn Stark
#   Comunità 2: Authority Stannis Baratheon
#   Comunità 6: Authority Barristan Selmy
#   Comunità 8: Authority Horas Redwyne
#   Comunità 9: Authority Jaime Lannister
#   Comunità 10: Authority Tyrion Lannister
#   Comunità 11: Authority Jon Snow
#   Comunità 15: Authority Myrcella Baratheon
# Nodo Jojen-Reed interagisce con le comunità:
#   Comunità 1: Authority Catelyn Stark
#   Comunità 11: Authority Jon Snow
# Nodo Jon-Arryn interagisce con le comunità:
#   Comunità 1: Authority Catelyn Stark
#   Comunità 2: Authority Stannis Baratheon
#   Comunità 4: Authority Alys Arryn
#   Comunità 6: Authority Barristan Selmy
#   Comunità 9: Authority Jaime Lannister
#   Comunità 10: Authority Tyrion Lannister
# Nodo Jon-Connington interagisce con le comunità:
#   Comunità 16: Authority Jon Connington
#   Comunità 10: Authority Tyrion Lannister
#   Comunità 6: Authority Barristan Selmy
# Nodo Jon-Snow interagisce con le comunità:
#   Comunità 0: Authority Arya Stark
#   Comunità 1: Authority Catelyn Stark
#   Comunità 2: Authority Stannis Baratheon
#   Comunità 9: Authority Jaime Lannister
#   Comunità 10: Authority Tyrion Lannister
#   Comunità 11: Authority Jon Snow
# Nodo Jon-Umber-(Greatjon) interagisce con le comunità:
#   Comunità 1: Authority Catelyn Stark
#   Comunità 2: Authority Stannis Baratheon
#   Comunità 10: Authority Tyrion Lannister
# Nodo Jorah-Mormont interagisce con le comunità:
#   Comunità 10: Authority Tyrion Lannister
#   Comunità 11: Authority Jon Snow
#   Comunità 6: Authority Barristan Selmy
# Nodo Joramun interagisce con le comunità:
#   Comunità 2: Authority Stannis Baratheon
#   Comunità 11: Authority Jon Snow
# Nodo Jory-Cassel interagisce con le comunità:
#   Comunità 0: Authority Arya Stark
#   Comunità 1: Authority Catelyn Stark
#   Comunità 2: Authority Stannis Baratheon
#   Comunità 9: Authority Jaime Lannister
#   Comunità 10: Authority Tyrion Lannister
#   Comunità 11: Authority Jon Snow
# Nodo Justin-Massey interagisce con le comunità:
#   Comunità 2: Authority Stannis Baratheon
#   Comunità 7: Authority Balon Greyjoy
# Nodo Karyl-Vance interagisce con le comunità:
#   Comunità 1: Authority Catelyn Stark
#   Comunità 9: Authority Jaime Lannister
# Nodo Kasporio interagisce con le comunità:
#   Comunità 10: Authority Tyrion Lannister
#   Comunità 6: Authority Barristan Selmy
# Nodo Kevan-Lannister interagisce con le comunità:
#   Comunità 19: Authority Willem Lannister
#   Comunità 9: Authority Jaime Lannister
#   Comunità 10: Authority Tyrion Lannister
#   Comunità 2: Authority Stannis Baratheon
# Nodo Lancel-Lannister interagisce con le comunità:
#   Comunità 9: Authority Jaime Lannister
#   Comunità 10: Authority Tyrion Lannister
# Nodo Lem interagisce con le comunità:
#   Comunità 0: Authority Arya Stark
#   Comunità 9: Authority Jaime Lannister
#   Comunità 1: Authority Catelyn Stark
# Nodo Lemore interagisce con le comunità:
#   Comunità 16: Authority Jon Connington
#   Comunità 10: Authority Tyrion Lannister
# Nodo Leo-Tyrell interagisce con le comunità:
#   Comunità 11: Authority Jon Snow
#   Comunità 14: Authority Alleras
# Nodo Loras-Tyrell interagisce con le comunità:
#   Comunità 0: Authority Arya Stark
#   Comunità 1: Authority Catelyn Stark
#   Comunità 2: Authority Stannis Baratheon
#   Comunità 9: Authority Jaime Lannister
#   Comunità 10: Authority Tyrion Lannister
# Nodo Lorren interagisce con le comunità:
#   Comunità 1: Authority Catelyn Stark
#   Comunità 7: Authority Balon Greyjoy
# Nodo Lothar-Frey interagisce con le comunità:
#   Comunità 1: Authority Catelyn Stark
#   Comunità 10: Authority Tyrion Lannister
#   Comunità 9: Authority Jaime Lannister
# Nodo Luwin interagisce con le comunità:
#   Comunità 1: Authority Catelyn Stark
#   Comunità 10: Authority Tyrion Lannister
#   Comunità 11: Authority Jon Snow
# Nodo Lyle-Crakehall interagisce con le comunità:
#   Comunità 0: Authority Arya Stark
#   Comunità 9: Authority Jaime Lannister
#   Comunità 10: Authority Tyrion Lannister
#   Comunità 1: Authority Catelyn Stark
# Nodo Lysa-Arryn interagisce con le comunità:
#   Comunità 9: Authority Jaime Lannister
#   Comunità 10: Authority Tyrion Lannister
#   Comunità 2: Authority Stannis Baratheon
#   Comunità 1: Authority Catelyn Stark
# Nodo Mace-Tyrell interagisce con le comunità:
#   Comunità 9: Authority Jaime Lannister
#   Comunità 10: Authority Tyrion Lannister
#   Comunità 2: Authority Stannis Baratheon
#   Comunità 6: Authority Barristan Selmy
# Nodo Malegorn interagisce con le comunità:
#   Comunità 2: Authority Stannis Baratheon
#   Comunità 11: Authority Jon Snow
# Nodo Mance-Rayder interagisce con le comunità:
#   Comunità 0: Authority Arya Stark
#   Comunità 1: Authority Catelyn Stark
#   Comunità 2: Authority Stannis Baratheon
#   Comunità 10: Authority Tyrion Lannister
#   Comunità 11: Authority Jon Snow
# Nodo Mandon-Moore interagisce con le comunità:
#   Comunità 0: Authority Arya Stark
#   Comunità 9: Authority Jaime Lannister
#   Comunità 10: Authority Tyrion Lannister
# Nodo Margaery-Tyrell interagisce con le comunità:
#   Comunità 1: Authority Catelyn Stark
#   Comunità 10: Authority Tyrion Lannister
#   Comunità 13: Authority Alla Tyrell
#   Comunità 9: Authority Jaime Lannister
# Nodo Marillion interagisce con le comunità:
#   Comunità 1: Authority Catelyn Stark
#   Comunità 10: Authority Tyrion Lannister
# Nodo Mariya-Darry interagisce con le comunità:
#   Comunità 0: Authority Arya Stark
#   Comunità 9: Authority Jaime Lannister
# Nodo Marq-Piper interagisce con le comunità:
#   Comunità 0: Authority Arya Stark
#   Comunità 1: Authority Catelyn Stark
#   Comunità 10: Authority Tyrion Lannister
# Nodo Martyn-Lannister interagisce con le comunità:
#   Comunità 10: Authority Tyrion Lannister
#   Comunità 19: Authority Willem Lannister
# Nodo Marwyn interagisce con le comunità:
#   Comunità 11: Authority Jon Snow
#   Comunità 14: Authority Alleras
# Nodo Mathis-Rowan interagisce con le comunità:
#   Comunità 1: Authority Catelyn Stark
#   Comunità 10: Authority Tyrion Lannister
#   Comunità 2: Authority Stannis Baratheon
#   Comunità 9: Authority Jaime Lannister
# Nodo Meera-Reed interagisce con le comunità:
#   Comunità 1: Authority Catelyn Stark
#   Comunità 11: Authority Jon Snow
# Nodo Megga-Tyrell interagisce con le comunità:
#   Comunità 10: Authority Tyrion Lannister
#   Comunità 13: Authority Alla Tyrell
# Nodo Melara-Hetherspoon interagisce con le comunità:
#   Comunità 9: Authority Jaime Lannister
#   Comunità 10: Authority Tyrion Lannister
# Nodo Melisandre interagisce con le comunità:
#   Comunità 0: Authority Arya Stark
#   Comunità 10: Authority Tyrion Lannister
#   Comunità 2: Authority Stannis Baratheon
#   Comunità 11: Authority Jon Snow
# Nodo Merrett-Frey interagisce con le comunità:
#   Comunità 1: Authority Catelyn Stark
#   Comunità 10: Authority Tyrion Lannister
# Nodo Meryn-Trant interagisce con le comunità:
#   Comunità 0: Authority Arya Stark
#   Comunità 9: Authority Jaime Lannister
#   Comunità 10: Authority Tyrion Lannister
#   Comunità 6: Authority Barristan Selmy
# Nodo Moelle interagisce con le comunità:
#   Comunità 10: Authority Tyrion Lannister
#   Comunità 3: Authority Unella
# Nodo Moqorro interagisce con le comunità:
#   Comunità 16: Authority Jon Connington
#   Comunità 10: Authority Tyrion Lannister
#   Comunità 6: Authority Barristan Selmy
#   Comunità 7: Authority Balon Greyjoy
# Nodo Mordane interagisce con le comunità:
#   Comunità 0: Authority Arya Stark
#   Comunità 1: Authority Catelyn Stark
#   Comunità 10: Authority Tyrion Lannister
#   Comunità 11: Authority Jon Snow
#   Comunità 15: Authority Myrcella Baratheon
# Nodo Mors-Umber interagisce con le comunità:
#   Comunità 1: Authority Catelyn Stark
#   Comunità 2: Authority Stannis Baratheon
# Nodo Murenmure interagisce con le comunità:
#   Comunità 1: Authority Catelyn Stark
#   Comunità 7: Authority Balon Greyjoy
# Nodo Mya-Stone interagisce con le comunità:
#   Comunità 1: Authority Catelyn Stark
#   Comunità 10: Authority Tyrion Lannister
# Nodo Mycah interagisce con le comunità:
#   Comunità 0: Authority Arya Stark
#   Comunità 10: Authority Tyrion Lannister
# Nodo Myrcella-Baratheon interagisce con le comunità:
#   Comunità 0: Authority Arya Stark
#   Comunità 1: Authority Catelyn Stark
#   Comunità 2: Authority Stannis Baratheon
#   Comunità 10: Authority Tyrion Lannister
#   Comunità 15: Authority Myrcella Baratheon
# Nodo Nan interagisce con le comunità:
#   Comunità 0: Authority Arya Stark
#   Comunità 1: Authority Catelyn Stark
#   Comunità 11: Authority Jon Snow
#   Comunità 6: Authority Barristan Selmy
# Nodo Narbert-Grandison interagisce con le comunità:
#   Comunità 2: Authority Stannis Baratheon
#   Comunità 11: Authority Jon Snow
# Nodo Nestor-Royce interagisce con le comunità:
#   Comunità 1: Authority Catelyn Stark
#   Comunità 10: Authority Tyrion Lannister
# Nodo Nurse interagisce con le comunità:
#   Comunità 10: Authority Tyrion Lannister
#   Comunità 6: Authority Barristan Selmy
# Nodo Oberyn-Martell interagisce con le comunità:
#   Comunità 0: Authority Arya Stark
#   Comunità 6: Authority Barristan Selmy
#   Comunità 9: Authority Jaime Lannister
#   Comunità 10: Authority Tyrion Lannister
#   Comunità 15: Authority Myrcella Baratheon
# Nodo Olenna-Redwyne interagisce con le comunità:
#   Comunità 9: Authority Jaime Lannister
#   Comunità 10: Authority Tyrion Lannister
# Nodo Olyvar-Frey interagisce con le comunità:
#   Comunità 1: Authority Catelyn Stark
#   Comunità 9: Authority Jaime Lannister
# Nodo Orton-Merryweather interagisce con le comunità:
#   Comunità 10: Authority Tyrion Lannister
#   Comunità 2: Authority Stannis Baratheon
# Nodo Osmund-Kettleblack interagisce con le comunità:
#   Comunità 0: Authority Arya Stark
#   Comunità 9: Authority Jaime Lannister
#   Comunità 10: Authority Tyrion Lannister
# Nodo Osney-Kettleblack interagisce con le comunità:
#   Comunità 10: Authority Tyrion Lannister
#   Comunità 2: Authority Stannis Baratheon
#   Comunità 13: Authority Alla Tyrell
# Nodo Owen interagisce con le comunità:
#   Comunità 10: Authority Tyrion Lannister
#   Comunità 11: Authority Jon Snow
# Nodo Patrek-of-Kings-Mountain interagisce con le comunità:
#   Comunità 2: Authority Stannis Baratheon
#   Comunità 11: Authority Jon Snow
# Nodo Paxter-Redwyne interagisce con le comunità:
#   Comunità 10: Authority Tyrion Lannister
#   Comunità 11: Authority Jon Snow
# Nodo Penny interagisce con le comunità:
#   Comunità 10: Authority Tyrion Lannister
#   Comunità 6: Authority Barristan Selmy
# Nodo Petyr-Baelish interagisce con le comunità:
#   Comunità 0: Authority Arya Stark
#   Comunità 1: Authority Catelyn Stark
#   Comunità 2: Authority Stannis Baratheon
#   Comunità 6: Authority Barristan Selmy
#   Comunità 9: Authority Jaime Lannister
#   Comunità 10: Authority Tyrion Lannister
#   Comunità 11: Authority Jon Snow
# Nodo Petyr-Frey interagisce con le comunità:
#   Comunità 9: Authority Jaime Lannister
#   Comunità 1: Authority Catelyn Stark
# Nodo Pia interagisce con le comunità:
#   Comunità 9: Authority Jaime Lannister
#   Comunità 10: Authority Tyrion Lannister
# Nodo Podrick-Payne interagisce con le comunità:
#   Comunità 9: Authority Jaime Lannister
#   Comunità 10: Authority Tyrion Lannister
# Nodo Polliver interagisce con le comunità:
#   Comunità 0: Authority Arya Stark
#   Comunità 10: Authority Tyrion Lannister
# Nodo Pono interagisce con le comunità:
#   Comunità 16: Authority Jon Connington
#   Comunità 6: Authority Barristan Selmy
# Nodo Pycelle interagisce con le comunità:
#   Comunità 0: Authority Arya Stark
#   Comunità 1: Authority Catelyn Stark
#   Comunità 2: Authority Stannis Baratheon
#   Comunità 6: Authority Barristan Selmy
#   Comunità 9: Authority Jaime Lannister
#   Comunità 10: Authority Tyrion Lannister
#   Comunità 11: Authority Jon Snow
# Nodo Qavo-Nogarys interagisce con le comunità:
#   Comunità 16: Authority Jon Connington
#   Comunità 10: Authority Tyrion Lannister
#   Comunità 6: Authority Barristan Selmy
# Nodo Quentyn-Martell interagisce con le comunità:
#   Comunità 6: Authority Barristan Selmy
#   Comunità 15: Authority Myrcella Baratheon
# Nodo Qyburn interagisce con le comunità:
#   Comunità 0: Authority Arya Stark
#   Comunità 1: Authority Catelyn Stark
#   Comunità 2: Authority Stannis Baratheon
#   Comunità 9: Authority Jaime Lannister
#   Comunità 10: Authority Tyrion Lannister
# Nodo Rafford interagisce con le comunità:
#   Comunità 0: Authority Arya Stark
#   Comunità 9: Authority Jaime Lannister
#   Comunità 10: Authority Tyrion Lannister
# Nodo Ramsay-Snow interagisce con le comunità:
#   Comunità 0: Authority Arya Stark
#   Comunità 1: Authority Catelyn Stark
#   Comunità 2: Authority Stannis Baratheon
#   Comunità 10: Authority Tyrion Lannister
#   Comunità 11: Authority Jon Snow
# Nodo Randyll-Tarly interagisce con le comunità:
#   Comunità 1: Authority Catelyn Stark
#   Comunità 2: Authority Stannis Baratheon
#   Comunità 9: Authority Jaime Lannister
#   Comunità 10: Authority Tyrion Lannister
#   Comunità 11: Authority Jon Snow
# Nodo Rattleshirt interagisce con le comunità:
#   Comunità 2: Authority Stannis Baratheon
#   Comunità 11: Authority Jon Snow
# Nodo Raynard interagisce con le comunità:
#   Comunità 17: Authority Raynard
#   Comunità 10: Authority Tyrion Lannister
# Nodo Renly-Baratheon interagisce con le comunità:
#   Comunità 0: Authority Arya Stark
#   Comunità 1: Authority Catelyn Stark
#   Comunità 2: Authority Stannis Baratheon
#   Comunità 6: Authority Barristan Selmy
#   Comunità 9: Authority Jaime Lannister
#   Comunità 10: Authority Tyrion Lannister
# Nodo Rhaegar-Targaryen interagisce con le comunità:
#   Comunità 5: Authority Gerold Hightower
#   Comunità 6: Authority Barristan Selmy
#   Comunità 9: Authority Jaime Lannister
#   Comunità 10: Authority Tyrion Lannister
#   Comunità 16: Authority Jon Connington
# Nodo Rhaella-Targaryen interagisce con le comunità:
#   Comunità 10: Authority Tyrion Lannister
#   Comunità 6: Authority Barristan Selmy
# Nodo Richard-Horpe interagisce con le comunità:
#   Comunità 2: Authority Stannis Baratheon
#   Comunità 7: Authority Balon Greyjoy
# Nodo Rickard-Karstark interagisce con le comunità:
#   Comunità 1: Authority Catelyn Stark
#   Comunità 2: Authority Stannis Baratheon
#   Comunità 10: Authority Tyrion Lannister
#   Comunità 9: Authority Jaime Lannister
# Nodo Rickard-Stark interagisce con le comunità:
#   Comunità 1: Authority Catelyn Stark
#   Comunità 10: Authority Tyrion Lannister
# Nodo Rickon-Stark interagisce con le comunità:
#   Comunità 0: Authority Arya Stark
#   Comunità 1: Authority Catelyn Stark
#   Comunità 10: Authority Tyrion Lannister
#   Comunità 11: Authority Jon Snow
# Nodo Robar-Royce interagisce con le comunità:
#   Comunità 9: Authority Jaime Lannister
#   Comunità 1: Authority Catelyn Stark
# Nodo Robb-Stark interagisce con le comunità:
#   Comunità 0: Authority Arya Stark
#   Comunità 1: Authority Catelyn Stark
#   Comunità 2: Authority Stannis Baratheon
#   Comunità 7: Authority Balon Greyjoy
#   Comunità 9: Authority Jaime Lannister
#   Comunità 10: Authority Tyrion Lannister
#   Comunità 11: Authority Jon Snow
#   Comunità 15: Authority Myrcella Baratheon
#   Comunità 19: Authority Willem Lannister
# Nodo Robert-Arryn interagisce con le comunità:
#   Comunità 1: Authority Catelyn Stark
#   Comunità 10: Authority Tyrion Lannister
#   Comunità 15: Authority Myrcella Baratheon
# Nodo Robert-Baratheon interagisce con le comunità:
#   Comunità 0: Authority Arya Stark
#   Comunità 1: Authority Catelyn Stark
#   Comunità 2: Authority Stannis Baratheon
#   Comunità 5: Authority Gerold Hightower
#   Comunità 6: Authority Barristan Selmy
#   Comunità 7: Authority Balon Greyjoy
#   Comunità 9: Authority Jaime Lannister
#   Comunità 10: Authority Tyrion Lannister
#   Comunità 11: Authority Jon Snow
#   Comunità 15: Authority Myrcella Baratheon
#   Comunità 16: Authority Jon Connington
# Nodo Robert-Strong interagisce con le comunità:
#   Comunità 9: Authority Jaime Lannister
#   Comunità 10: Authority Tyrion Lannister
# Nodo Robett-Glover interagisce con le comunità:
#   Comunità 0: Authority Arya Stark
#   Comunità 1: Authority Catelyn Stark
#   Comunità 2: Authority Stannis Baratheon
#   Comunità 9: Authority Jaime Lannister
# Nodo Robin-Ryger interagisce con le comunità:
#   Comunità 1: Authority Catelyn Stark
#   Comunità 9: Authority Jaime Lannister
# Nodo Rodrik-Cassel interagisce con le comunità:
#   Comunità 0: Authority Arya Stark
#   Comunità 1: Authority Catelyn Stark
#   Comunità 2: Authority Stannis Baratheon
#   Comunità 7: Authority Balon Greyjoy
#   Comunità 9: Authority Jaime Lannister
#   Comunità 10: Authority Tyrion Lannister
#   Comunità 11: Authority Jon Snow
# Nodo Rolly-Duckfield interagisce con le comunità:
#   Comunità 16: Authority Jon Connington
#   Comunità 10: Authority Tyrion Lannister
#   Comunità 6: Authority Barristan Selmy
# Nodo Ronnet-Connington interagisce con le comunità:
#   Comunità 9: Authority Jaime Lannister
#   Comunità 10: Authority Tyrion Lannister
# Nodo Roose-Bolton interagisce con le comunità:
#   Comunità 0: Authority Arya Stark
#   Comunità 1: Authority Catelyn Stark
#   Comunità 2: Authority Stannis Baratheon
#   Comunità 9: Authority Jaime Lannister
#   Comunità 10: Authority Tyrion Lannister
# Nodo Rorge interagisce con le comunità:
#   Comunità 0: Authority Arya Stark
#   Comunità 9: Authority Jaime Lannister
#   Comunità 2: Authority Stannis Baratheon
# Nodo Rowan interagisce con le comunità:
#   Comunità 1: Authority Catelyn Stark
#   Comunità 11: Authority Jon Snow
# Nodo Ryman-Frey interagisce con le comunità:
#   Comunità 1: Authority Catelyn Stark
#   Comunità 9: Authority Jaime Lannister
# Nodo Samwell-Tarly interagisce con le comunità:
#   Comunità 1: Authority Catelyn Stark
#   Comunità 2: Authority Stannis Baratheon
#   Comunità 9: Authority Jaime Lannister
#   Comunità 10: Authority Tyrion Lannister
#   Comunità 11: Authority Jon Snow
#   Comunità 14: Authority Alleras
# Nodo Sandor-Clegane interagisce con le comunità:
#   Comunità 0: Authority Arya Stark
#   Comunità 6: Authority Barristan Selmy
#   Comunità 9: Authority Jaime Lannister
#   Comunità 10: Authority Tyrion Lannister
#   Comunità 15: Authority Myrcella Baratheon
# Nodo Sansa-Stark interagisce con le comunità:
#   Comunità 0: Authority Arya Stark
#   Comunità 1: Authority Catelyn Stark
#   Comunità 2: Authority Stannis Baratheon
#   Comunità 6: Authority Barristan Selmy
#   Comunità 9: Authority Jaime Lannister
#   Comunità 10: Authority Tyrion Lannister
#   Comunità 11: Authority Jon Snow
#   Comunità 12: Authority Florian the Fool
#   Comunità 13: Authority Alla Tyrell
#   Comunità 15: Authority Myrcella Baratheon
# Nodo Satin interagisce con le comunità:
#   Comunità 2: Authority Stannis Baratheon
#   Comunità 11: Authority Jon Snow
# Nodo Scolera interagisce con le comunità:
#   Comunità 10: Authority Tyrion Lannister
#   Comunità 3: Authority Unella
# Nodo Selyse-Florent interagisce con le comunità:
#   Comunità 10: Authority Tyrion Lannister
#   Comunità 2: Authority Stannis Baratheon
#   Comunità 11: Authority Jon Snow
# Nodo Shae interagisce con le comunità:
#   Comunità 10: Authority Tyrion Lannister
#   Comunità 2: Authority Stannis Baratheon
# Nodo Shagwell interagisce con le comunità:
#   Comunità 0: Authority Arya Stark
#   Comunità 9: Authority Jaime Lannister
# Nodo Shireen-Baratheon interagisce con le comunità:
#   Comunità 11: Authority Jon Snow
#   Comunità 2: Authority Stannis Baratheon
#   Comunità 10: Authority Tyrion Lannister
# Nodo Sigorn interagisce con le comunità:
#   Comunità 2: Authority Stannis Baratheon
#   Comunità 11: Authority Jon Snow
# Nodo Squirrel interagisce con le comunità:
#   Comunità 1: Authority Catelyn Stark
#   Comunità 11: Authority Jon Snow
# Nodo Stafford-Lannister interagisce con le comunità:
#   Comunità 1: Authority Catelyn Stark
#   Comunità 9: Authority Jaime Lannister
# Nodo Stannis-Baratheon interagisce con le comunità:
#   Comunità 1: Authority Catelyn Stark
#   Comunità 2: Authority Stannis Baratheon
#   Comunità 6: Authority Barristan Selmy
#   Comunità 7: Authority Balon Greyjoy
#   Comunità 9: Authority Jaime Lannister
#   Comunità 10: Authority Tyrion Lannister
#   Comunità 11: Authority Jon Snow
#   Comunità 15: Authority Myrcella Baratheon
# Nodo Steffon-Baratheon interagisce con le comunità:
#   Comunità 10: Authority Tyrion Lannister
#   Comunità 2: Authority Stannis Baratheon
# Nodo Stevron-Frey interagisce con le comunità:
#   Comunità 1: Authority Catelyn Stark
#   Comunità 9: Authority Jaime Lannister
# Nodo Sybell-Spicer interagisce con le comunità:
#   Comunità 9: Authority Jaime Lannister
#   Comunità 2: Authority Stannis Baratheon
#   Comunità 1: Authority Catelyn Stark
# Nodo Sybelle-Glover interagisce con le comunità:
#   Comunità 1: Authority Catelyn Stark
#   Comunità 7: Authority Balon Greyjoy
# Nodo Syrio-Forel interagisce con le comunità:
#   Comunità 0: Authority Arya Stark
#   Comunità 10: Authority Tyrion Lannister
# Nodo Taena-of-Myr interagisce con le comunità:
#   Comunità 9: Authority Jaime Lannister
#   Comunità 10: Authority Tyrion Lannister
# Nodo Tallad interagisce con le comunità:
#   Comunità 10: Authority Tyrion Lannister
#   Comunità 13: Authority Alla Tyrell
# Nodo Tansy interagisce con le comunità:
#   Comunità 0: Authority Arya Stark
#   Comunità 1: Authority Catelyn Stark
#   Comunità 10: Authority Tyrion Lannister
# Nodo Theon-Greyjoy interagisce con le comunità:
#   Comunità 0: Authority Arya Stark
#   Comunità 1: Authority Catelyn Stark
#   Comunità 2: Authority Stannis Baratheon
#   Comunità 7: Authority Balon Greyjoy
#   Comunità 9: Authority Jaime Lannister
#   Comunità 10: Authority Tyrion Lannister
#   Comunità 11: Authority Jon Snow
# Nodo Thoros-of-Myr interagisce con le comunità:
#   Comunità 0: Authority Arya Stark
#   Comunità 9: Authority Jaime Lannister
#   Comunità 10: Authority Tyrion Lannister
# Nodo Tickler interagisce con le comunità:
#   Comunità 0: Authority Arya Stark
#   Comunità 10: Authority Tyrion Lannister
# Nodo Timeon interagisce con le comunità:
#   Comunità 0: Authority Arya Stark
#   Comunità 9: Authority Jaime Lannister
# Nodo Tom-of-Sevenstreams interagisce con le comunità:
#   Comunità 0: Authority Arya Stark
#   Comunità 1: Authority Catelyn Stark
# Nodo Tomard interagisce con le comunità:
#   Comunità 0: Authority Arya Stark
#   Comunità 10: Authority Tyrion Lannister
# Nodo Tommen-Baratheon interagisce con le comunità:
#   Comunità 0: Authority Arya Stark
#   Comunità 1: Authority Catelyn Stark
#   Comunità 2: Authority Stannis Baratheon
#   Comunità 9: Authority Jaime Lannister
#   Comunità 10: Authority Tyrion Lannister
#   Comunità 15: Authority Myrcella Baratheon
# Nodo Torrhen-Karstark interagisce con le comunità:
#   Comunità 1: Authority Catelyn Stark
#   Comunità 10: Authority Tyrion Lannister
# Nodo Torrhen-Stark interagisce con le comunità:
#   Comunità 10: Authority Tyrion Lannister
#   Comunità 6: Authority Barristan Selmy
# Nodo Trystane-Martell interagisce con le comunità:
#   Comunità 6: Authority Barristan Selmy
#   Comunità 15: Authority Myrcella Baratheon
# Nodo Tybero-Istarion interagisce con le comunità:
#   Comunità 10: Authority Tyrion Lannister
#   Comunità 6: Authority Barristan Selmy
# Nodo Tycho-Nestoris interagisce con le comunità:
#   Comunità 2: Authority Stannis Baratheon
#   Comunità 11: Authority Jon Snow
#   Comunità 7: Authority Balon Greyjoy
# Nodo Tyene-Sand interagisce con le comunità:
#   Comunità 10: Authority Tyrion Lannister
#   Comunità 15: Authority Myrcella Baratheon
# Nodo Tyrion-Lannister interagisce con le comunità:
#   Comunità 0: Authority Arya Stark
#   Comunità 1: Authority Catelyn Stark
#   Comunità 2: Authority Stannis Baratheon
#   Comunità 6: Authority Barristan Selmy
#   Comunità 7: Authority Balon Greyjoy
#   Comunità 9: Authority Jaime Lannister
#   Comunità 10: Authority Tyrion Lannister
#   Comunità 11: Authority Jon Snow
#   Comunità 15: Authority Myrcella Baratheon
#   Comunità 16: Authority Jon Connington
# Nodo Tysha interagisce con le comunità:
#   Comunità 9: Authority Jaime Lannister
#   Comunità 10: Authority Tyrion Lannister
# Nodo Tytos-Blackwood interagisce con le comunità:
#   Comunità 1: Authority Catelyn Stark
#   Comunità 9: Authority Jaime Lannister
# Nodo Tywin-Lannister interagisce con le comunità:
#   Comunità 0: Authority Arya Stark
#   Comunità 1: Authority Catelyn Stark
#   Comunità 2: Authority Stannis Baratheon
#   Comunità 7: Authority Balon Greyjoy
#   Comunità 9: Authority Jaime Lannister
#   Comunità 10: Authority Tyrion Lannister
#   Comunità 15: Authority Myrcella Baratheon
#   Comunità 16: Authority Jon Connington
#   Comunità 19: Authority Willem Lannister
# Nodo Unella interagisce con le comunità:
#   Comunità 10: Authority Tyrion Lannister
#   Comunità 3: Authority Unella
# Nodo Val interagisce con le comunità:
#   Comunità 2: Authority Stannis Baratheon
#   Comunità 10: Authority Tyrion Lannister
#   Comunità 11: Authority Jon Snow
# Nodo Vardis-Egen interagisce con le comunità:
#   Comunità 1: Authority Catelyn Stark
#   Comunità 10: Authority Tyrion Lannister
# Nodo Vargo-Hoat interagisce con le comunità:
#   Comunità 0: Authority Arya Stark
#   Comunità 1: Authority Catelyn Stark
#   Comunità 2: Authority Stannis Baratheon
#   Comunità 9: Authority Jaime Lannister
#   Comunità 10: Authority Tyrion Lannister
# Nodo Varys interagisce con le comunità:
#   Comunità 0: Authority Arya Stark
#   Comunità 1: Authority Catelyn Stark
#   Comunità 2: Authority Stannis Baratheon
#   Comunità 6: Authority Barristan Selmy
#   Comunità 9: Authority Jaime Lannister
#   Comunità 10: Authority Tyrion Lannister
#   Comunità 11: Authority Jon Snow
#   Comunità 15: Authority Myrcella Baratheon
#   Comunità 16: Authority Jon Connington
# Nodo Vayon-Poole interagisce con le comunità:
#   Comunità 0: Authority Arya Stark
#   Comunità 10: Authority Tyrion Lannister
# Nodo Victarion-Greyjoy interagisce con le comunità:
#   Comunità 1: Authority Catelyn Stark
#   Comunità 6: Authority Barristan Selmy
#   Comunità 7: Authority Balon Greyjoy
# Nodo Viserys-Targaryen interagisce con le comunità:
#   Comunità 16: Authority Jon Connington
#   Comunità 10: Authority Tyrion Lannister
#   Comunità 6: Authority Barristan Selmy
#   Comunità 15: Authority Myrcella Baratheon
# Nodo Vyman interagisce con le comunità:
#   Comunità 9: Authority Jaime Lannister
#   Comunità 1: Authority Catelyn Stark
# Nodo Walder-Frey interagisce con le comunità:
#   Comunità 1: Authority Catelyn Stark
#   Comunità 10: Authority Tyrion Lannister
#   Comunità 2: Authority Stannis Baratheon
#   Comunità 9: Authority Jaime Lannister
# Nodo Walder-Rivers interagisce con le comunità:
#   Comunità 9: Authority Jaime Lannister
#   Comunità 1: Authority Catelyn Stark
# Nodo Walton interagisce con le comunità:
#   Comunità 9: Authority Jaime Lannister
#   Comunità 10: Authority Tyrion Lannister
#   Comunità 1: Authority Catelyn Stark
# Nodo Waymar-Royce interagisce con le comunità:
#   Comunità 18: Authority Waymar Royce
#   Comunità 11: Authority Jon Snow
# Nodo Weese interagisce con le comunità:
#   Comunità 0: Authority Arya Stark
#   Comunità 10: Authority Tyrion Lannister
# Nodo Wex-Pyke interagisce con le comunità:
#   Comunità 1: Authority Catelyn Stark
#   Comunità 7: Authority Balon Greyjoy
# Nodo Willem-Lannister interagisce con le comunità:
#   Comunità 1: Authority Catelyn Stark
#   Comunità 10: Authority Tyrion Lannister
#   Comunità 19: Authority Willem Lannister
# Nodo Willis-Wode interagisce con le comunità:
#   Comunità 1: Authority Catelyn Stark
#   Comunità 10: Authority Tyrion Lannister
# Nodo Willow-Heddle interagisce con le comunità:
#   Comunità 0: Authority Arya Stark
#   Comunità 9: Authority Jaime Lannister
# Nodo Wun-Weg-Wun-Dar-Wun interagisce con le comunità:
#   Comunità 2: Authority Stannis Baratheon
#   Comunità 11: Authority Jon Snow
# Nodo Wyl-(guard) interagisce con le comunità:
#   Comunità 9: Authority Jaime Lannister
#   Comunità 10: Authority Tyrion Lannister
# Nodo Wylis-Manderly interagisce con le comunità:
#   Comunità 9: Authority Jaime Lannister
#   Comunità 10: Authority Tyrion Lannister
# Nodo Wyman-Manderly interagisce con le comunità:
#   Comunità 1: Authority Catelyn Stark
#   Comunità 2: Authority Stannis Baratheon
#   Comunità 10: Authority Tyrion Lannister
# Nodo Yandry interagisce con le comunità:
#   Comunità 16: Authority Jon Connington
#   Comunità 10: Authority Tyrion Lannister
# Nodo Ygritte interagisce con le comunità:
#   Comunità 2: Authority Stannis Baratheon
#   Comunità 11: Authority Jon Snow
# Nodo Yoren interagisce con le comunità:
#   Comunità 0: Authority Arya Stark
#   Comunità 1: Authority Catelyn Stark
#   Comunità 10: Authority Tyrion Lannister
#   Comunità 11: Authority Jon Snow
# Nodo Ysilla interagisce con le comunità:
#   Comunità 16: Authority Jon Connington
#   Comunità 10: Authority Tyrion Lannister
# Nodo Zollo interagisce con le comunità:
#   Comunità 0: Authority Arya Stark
#   Comunità 9: Authority Jaime Lannister

# %% [markdown]
# Top 5

# %%
# Top 5 per pesi degli archi tra comunità
top_5_inter_weights = sorted(inter_weights.items(), key=lambda x: x[1], reverse=True)[:5]

print("Top 5 pesi degli archi tra comunità:")
for (comm_u, comm_v), weight in top_5_inter_weights:
    print(f"Tra Comunità {comm_u} e {comm_v}: peso totale {weight:.2f}")
    print(f"Comunità di Authority {resultsComunities[comm_u]['Authority']} e di Authority {resultsComunities[comm_v]['Authority']}")

# Top 5 per nodi che interagiscono con più comunità
top_5_overlap_nodes = sorted(overlap_nodes.items(), key=lambda x: len(x[1]), reverse=True)[:5]

print("\nTop 5 nodi che interagiscono con più comunità:")
for node, communities in top_5_overlap_nodes:
    print(f"Nodo {node} interagisce con le comunità: {', '.join(map(str, communities))}")
    #for community in communities:  # Itera sulle singole comunità
    #    authority = resultsComunities[community]['Authority']  # Ottieni il valore di Authority
    #    print(f"  Comunità {community}: Authority {authority}")
    print("-")
# Out:
# Top 5 pesi degli archi tra comunità:
# Tra Comunità 1 e 10: peso totale 68.00
# Comunità di Authority Catelyn Stark e di Authority Tyrion Lannister
# Tra Comunità 9 e 10: peso totale 55.00
# Comunità di Authority Jaime Lannister e di Authority Tyrion Lannister
# Tra Comunità 0 e 10: peso totale 54.00
# Comunità di Authority Arya Stark e di Authority Tyrion Lannister
# Tra Comunità 10 e 0: peso totale 42.00
# Comunità di Authority Tyrion Lannister e di Authority Arya Stark
# Tra Comunità 10 e 1: peso totale 38.00
# Comunità di Authority Tyrion Lannister e di Authority Catelyn Stark
#
# Top 5 nodi che interagiscono con più comunità:
# Nodo Robert-Baratheon interagisce con le comunità: 0, 1, 2, 5, 6, 7, 9, 10, 11, 15, 16
# -
# Nodo Cersei-Lannister interagisce con le comunità: 0, 1, 2, 3, 6, 9, 10, 11, 15, 17
# -
# Nodo Sansa-Stark interagisce con le comunità: 0, 1, 2, 6, 9, 10, 11, 12, 13, 15
# -
# Nodo Tyrion-Lannister interagisce con le comunità: 0, 1, 2, 6, 7, 9, 10, 11, 15, 16
# -
# Nodo Eddard-Stark interagisce con le comunità: 0, 1, 2, 5, 6, 7, 9, 10, 11
# -

# %% [markdown]
# #**Individuazione delle comunità isolate o periferiche**
# Quali gruppi sono isolati dal resto della rete? L'analisi delle comunità periferiche è utile per comprendere quali fazioni o gruppi sono meno integrati nella trama principale o rappresentano elementi esterni alla narrazione centrale.
#
#
# Metriche usate:
# * **Modularità locale**: Misura il livello di separazione di una comunità rispetto al resto della rete. Un valore alto indica una comunità isolata.
# * **Closeness inter-comunità**: Analizza la distanza media tra nodi periferici e il resto della rete per individuare gruppi meno accessibili.

# %%
def find_isolated_groups(G):
    # Dizionario per modularità locale e closeness inter-comunità
    community_isolation = {}

    # Raggruppa i nodi per comunità
    communities = defaultdict(list)
    for node, data in G.nodes(data=True):
        communities[data['modularity']].append(node)

    for community, nodes in communities.items():
        # Sottografo della comunità
        subgraph = G.subgraph(nodes)

        # 1. Calcolo della modularità locale
        intra_edges = subgraph.number_of_edges()  # Archi interni alla comunità
        total_edges = sum(G.degree(n) for n in nodes) / 2  # Archi totali coinvolgenti la comunità
        modularity_local = intra_edges / total_edges if total_edges > 0 else 0

        # 2. Calcolo della closeness inter-comunità
        closeness_sum = 0
        count = 0
        for node in nodes:
            # Calcola la distanza media verso nodi esterni alla comunità
            distances = nx.single_source_shortest_path_length(G, node)
            external_distances = [dist for target, dist in distances.items() if target not in nodes]
            if external_distances:
                closeness_sum += sum(external_distances) / len(external_distances)
                count += 1

        closeness_inter = (closeness_sum / count) if count > 0 else float('inf')

        # Aggiungi risultati per questa comunità
        community_isolation[community] = {
            "modularity_local": modularity_local,
            "closeness_inter": closeness_inter
        }

    return community_isolation


isolated_groups = find_isolated_groups(G)

# Stampa dei risultati
print("Gruppi isolati (ordinati per modularità locale):")
for community, measures in sorted(isolated_groups.items(), key=lambda x: x[1]['modularity_local'], reverse=True):
    print(f"Comunità {community} - Authority {resultsComunities[community]['Authority']}:")
    print(f"  Modularità locale: {measures['modularity_local']:.2f}")
    print(f"  Closeness inter-comunità: {measures['closeness_inter']:.2f}")
    print("-")
# Out:
# Gruppi isolati (ordinati per modularità locale):
# Comunità 14 - Authority Alleras:
#   Modularità locale: 0.90
#   Closeness inter-comunità: 4.90
# -
# Comunità 6 - Authority Barristan Selmy:
#   Modularità locale: 0.88
#   Closeness inter-comunità: 3.83
# -
# Comunità 11 - Authority Jon Snow:
#   Modularità locale: 0.86
#   Closeness inter-comunità: 3.54
# -
# Comunità 7 - Authority Balon Greyjoy:
#   Modularità locale: 0.82
#   Closeness inter-comunità: 3.92
# -
# Comunità 18 - Authority Waymar Royce:
#   Modularità locale: 0.75
#   Closeness inter-comunità: 3.91
# -
# Comunità 15 - Authority Myrcella Baratheon:
#   Modularità locale: 0.72
#   Closeness inter-comunità: 3.86
# -
# Comunità 5 - Authority Gerold Hightower:
#   Modularità locale: 0.72
#   Closeness inter-comunità: 4.23
# -
# Comunità 16 - Authority Jon Connington:
#   Modularità locale: 0.71
#   Closeness inter-comunità: 3.53
# -
# Comunità 1 - Authority Catelyn Stark:
#   Modularità locale: 0.71
#   Closeness inter-comunità: 3.37
# -
# Comunità 10 - Authority Tyrion Lannister:
#   Modularità locale: 0.71
#   Closeness inter-comunità: 3.31
# -
# Comunità 0 - Authority Arya Stark:
#   Modularità locale: 0.68
#   Closeness inter-comunità: 3.36
# -
# Comunità 4 - Authority Alys Arryn:
#   Modularità locale: 0.67
#   Closeness inter-comunità: 4.11
# -
# Comunità 12 - Authority Florian the Fool:
#   Modularità locale: 0.67
#   Closeness inter-comunità: 3.81
# -
# Comunità 8 - Authority Horas Redwyne:
#   Modularità locale: 0.67
#   Closeness inter-comunità: 3.80
# -
# Comunità 17 - Authority Raynard:
#   Modularità locale: 0.67
#   Closeness inter-comunità: 3.70
# -
# Comunità 2 - Authority Stannis Baratheon:
#   Modularità locale: 0.65
#   Closeness inter-comunità: 3.47
# -
# Comunità 3 - Authority Unella:
#   Modularità locale: 0.60
#   Closeness inter-comunità: 3.20
# -
# Comunità 19 - Authority Willem Lannister:
#   Modularità locale: 0.57
#   Closeness inter-comunità: 3.63
# -
# Comunità 9 - Authority Jaime Lannister:
#   Modularità locale: 0.53
#   Closeness inter-comunità: 3.37
# -
# Comunità 13 - Authority Alla Tyrell:
#   Modularità locale: 0.43
#   Closeness inter-comunità: 3.29
# -

# %% [markdown]
# #**Analisi delle dinamiche interne delle comunità**
# Come sono organizzati i legami interni di ogni comunità? Questa analisi è cruciale per individuare alleanze forti, sottogruppi o potenziali divisioni interne.
#
#
# Metriche usate:
# * **Coefficiente di clustering interno**: Misura la densità delle connessioni all'interno della comunità, utile per identificare strutture fortemente coese.
# * **Numero di triangoli**: Analizza i gruppi chiusi (triangoli) presenti all'interno della comunità, che rappresentano sottoreti di personaggi con legami forti e stabili.

# %%
def analyze_internal_links(group_df, group_edges):
    # Crea grafo temporaneo
    G_group = nx.Graph()

    # Aggiungi i nodi
    for idx, row in group_df.iterrows():
        G_group.add_node(row['Id'], label=row['Label'], community=row['modularity_class'])

    # Aggiungi gli archi
    for idx, row in group_edges.iterrows():
        source = row['Source']
        target = row['Target']
        G_group.add_edge(source, target)

    # Dizionario per salvare i risultati di ogni comunità
    community_internal_analysis = {}

    # 1. Coefficiente di clustering interno
    clustering_coefficients = nx.clustering(G_group)
    avg_clustering = sum(clustering_coefficients.values()) / len(clustering_coefficients)

    # 2. Numero di triangoli
    triangles = sum(nx.triangles(G_group).values()) // 3  # Ogni triangolo è conteggiato 3 volte

    # Salva i risultati
    community_internal_analysis[community] = {
        "avg_clustering": avg_clustering,
        "num_triangles": triangles
    }

    return community_internal_analysis

resultsInternalAnalysis = {}

for modularity_class in modularity:
    # Filtra il DataFrame per ciascun 'modularity_class'
    group_df = df[df['modularity_class'] == modularity_class]
    group_edges = df_edges[df_edges['Source'].isin(group_df['Id']) & df_edges['Target'].isin(group_df['Id'])]

    # Trova rappresentante con max authority
    rappresentante = group_df.loc[group_df['Authority'].idxmax()]

    # Salva i risultati per ogni classe
    resultsInternalAnalysis[modularity_class] = analyze_internal_links(group_df, group_edges)
    resultsInternalAnalysis[modularity_class]['Authority'] = rappresentante['Label']


print("Analisi dei legami interni di ogni comunità:")
for community in sorted(resultsInternalAnalysis.items(), key=lambda x: x[1].get('avg_clustering', 0), reverse=True):
    print(f"Comunità {community}:")
    avg_clustering = measures.get('avg_clustering', 0)
    num_triangles = measures.get('num_triangles', 0)
    authority = measures.get('Authority', "Nessun nodo")
    print(f"  Coefficiente di clustering medio: {avg_clustering:.2f}")
    print(f"  Numero di triangoli: {num_triangles}")
    print(f"  Rappresentante: {authority}")
    print("-")
# Out:
# Analisi dei legami interni di ogni comunità:
# Comunità (0, {13: {'avg_clustering': 0.5598038990636028, 'num_triangles': 308}, 'Authority': 'Arya Stark'}):
#   Coefficiente di clustering medio: 0.00
#   Numero di triangoli: 0
#   Rappresentante: Nessun nodo
# -
# Comunità (1, {13: {'avg_clustering': 0.5530773314277841, 'num_triangles': 354}, 'Authority': 'Catelyn Stark'}):
#   Coefficiente di clustering medio: 0.00
#   Numero di triangoli: 0
#   Rappresentante: Nessun nodo
# -
# Comunità (2, {13: {'avg_clustering': 0.4818305080985837, 'num_triangles': 95}, 'Authority': 'Stannis Baratheon'}):
#   Coefficiente di clustering medio: 0.00
#   Numero di triangoli: 0
#   Rappresentante: Nessun nodo
# -
# Comunità (3, {13: {'avg_clustering': 1.0, 'num_triangles': 1}, 'Authority': 'Unella'}):
#   Coefficiente di clustering medio: 0.00
#   Numero di triangoli: 0
#   Rappresentante: Nessun nodo
# -
# Comunità (4, {13: {'avg_clustering': 0.0, 'num_triangles': 0}, 'Authority': 'Alys Arryn'}):
#   Coefficiente di clustering medio: 0.00
#   Numero di triangoli: 0
#   Rappresentante: Nessun nodo
# -
# Comunità (5, {13: {'avg_clustering': 0.4523809523809524, 'num_triangles': 3}, 'Authority': 'Gerold Hightower'}):
#   Coefficiente di clustering medio: 0.00
#   Numero di triangoli: 0
#   Rappresentante: Nessun nodo
# -
# Comunità (6, {13: {'avg_clustering': 0.49226078585020483, 'num_triangles': 356}, 'Authority': 'Barristan Selmy'}):
#   Coefficiente di clustering medio: 0.00
#   Numero di triangoli: 0
#   Rappresentante: Nessun nodo
# -
# Comunità (7, {13: {'avg_clustering': 0.44713089940362666, 'num_triangles': 45}, 'Authority': 'Balon Greyjoy'}):
#   Coefficiente di clustering medio: 0.00
#   Numero di triangoli: 0
#   Rappresentante: Nessun nodo
# -
# Comunità (8, {13: {'avg_clustering': 0.0, 'num_triangles': 0}, 'Authority': 'Horas Redwyne'}):
#   Coefficiente di clustering medio: 0.00
#   Numero di triangoli: 0
#   Rappresentante: Nessun nodo
# -
# Comunità (9, {13: {'avg_clustering': 0.3990362916326405, 'num_triangles': 34}, 'Authority': 'Jaime Lannister'}):
#   Coefficiente di clustering medio: 0.00
#   Numero di triangoli: 0
#   Rappresentante: Nessun nodo
# -
# Comunità (10, {13: {'avg_clustering': 0.4829333181775194, 'num_triangles': 1025}, 'Authority': 'Tyrion Lannister'}):
#   Coefficiente di clustering medio: 0.00
#   Numero di triangoli: 0
#   Rappresentante: Nessun nodo
# -
# Comunità (11, {13: {'avg_clustering': 0.5132176719354661, 'num_triangles': 517}, 'Authority': 'Jon Snow'}):
#   Coefficiente di clustering medio: 0.00
#   Numero di triangoli: 0
#   Rappresentante: Nessun nodo
# -
# Comunità (12, {13: {'avg_clustering': 0.0, 'num_triangles': 0}, 'Authority': 'Florian the Fool'}):
#   Coefficiente di clustering medio: 0.00
#   Numero di triangoli: 0
#   Rappresentante: Nessun nodo
# -
# Comunità (13, {13: {'avg_clustering': 1.0, 'num_triangles': 1}, 'Authority': 'Alla Tyrell'}):
#   Coefficiente di clustering medio: 0.00
#   Numero di triangoli: 0
#   Rappresentante: Nessun nodo
# -
# Comunità (14, {13: {'avg_clustering': 0.4489177489177489, 'num_triangles': 13}, 'Authority': 'Alleras'}):
#   Coefficiente di clustering medio: 0.00
#   Numero di triangoli: 0
#   Rappresentante: Nessun nodo
# -
# Comunità (15, {13: {'avg_clustering': 0.49484126984126986, 'num_triangles': 49}, 'Authority': 'Myrcella Baratheon'}):
#   Coefficiente di clustering medio: 0.00
#   Numero di triangoli: 0
#   Rappresentante: Nessun nodo
# -
# Comunità (16, {13: {'avg_clustering': 0.44409722222222225, 'num_triangles': 33}, 'Authority': 'Jon Connington'}):
#   Coefficiente di clustering medio: 0.00
#   Numero di triangoli: 0
#   Rappresentante: Nessun nodo
# -
# Comunità (17, {13: {'avg_clustering': 0.0, 'num_triangles': 0}, 'Authority': 'Raynard'}):
#   Coefficiente di clustering medio: 0.00
#   Numero di triangoli: 0
#   Rappresentante: Nessun nodo
# -
# Comunità (18, {13: {'avg_clustering': 1.0, 'num_triangles': 1}, 'Authority': 'Waymar Royce'}):
#   Coefficiente di clustering medio: 0.00
#   Numero di triangoli: 0
#   Rappresentante: Nessun nodo
# -
# Comunità (19, {13: {'avg_clustering': 0.0, 'num_triangles': 0}, 'Authority': 'Willem Lannister'}):
#   Coefficiente di clustering medio: 0.00
#   Numero di triangoli: 0
#   Rappresentante: Nessun nodo
# -

# %% [markdown]
# # Modifica dataset per ottenere grafi per casate
